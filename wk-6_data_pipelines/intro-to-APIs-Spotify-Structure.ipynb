# %% [markdown]
# ## Sending requests
#
# 200: Success!
#
# 401: Unauthorized client error status: lack of valid authentication credentials
#
# 403: The server understood the request but refuses to authorize it

# %%
import requests

google = requests.get("https://developers.google.com")
print("Google:", google.status_code)

NBA = requests.get("https://api.sportsdata.io/api/nba/fantasy/json/CurrentSeason")
print("NBA:", NBA.status_code) 

rotten_tomato = requests.get("http://api.rottentomatoes.com/api/public/v1.0/lists/movies/box_office.json")
print("Rotten Tomatoes:", rotten_tomato.status_code)
# Out:
# Google: 200
# NBA: 401
# Rotten Tomatoes: 403

# %%
# install if needed
import json

response = requests.get("https://jsonplaceholder.typicode.com/todos")

# %%
resp_json = response.json()

# %%
resp_json
# Out:
# [{'userId': 1, 'id': 1, 'title': 'delectus aut autem', 'completed': False},
#  {'userId': 1,
#   'id': 2,
#   'title': 'quis ut nam facilis et officia qui',
#   'completed': False},
#  {'userId': 1, 'id': 3, 'title': 'fugiat veniam minus', 'completed': False},
#  {'userId': 1, 'id': 4, 'title': 'et porro tempora', 'completed': True},
#  {'userId': 1,
#   'id': 5,
#   'title': 'laboriosam mollitia et enim quasi adipisci quia provident illum',
#   'completed': False},
#  {'userId': 1,
#   'id': 6,
#   'title': 'qui ullam ratione quibusdam voluptatem quia omnis',
#   'completed': False},
#  {'userId': 1,
#   'id': 7,
#   'title': 'illo expedita consequatur quia in',
#   'completed': False},
#  {'userId': 1,
#   'id': 8,
#   'title': 'quo adipisci enim quam ut ab',
#   'completed': True},
#  {'userId': 1,
#   'id': 9,
#   'title': 'molestiae perspiciatis ipsa',
#   'completed': False},
#  {'userId': 1,
#   'id': 10,
#   'title': 'illo est ratione doloremque quia maiores aut',
#   'completed': True},
#  {'userId': 1,
#   'id': 11,
#   'title': 'vero rerum temporibus dolor',
#   'completed': True},
#  {'userId': 1,
#   'id': 12,
#   'title': 'ipsa repellendus fugit nisi',
#   'completed': True},
#  {'userId': 1, 'id': 13, 'title': 'et doloremque nulla', 'completed': False},
#  {'userId': 1,
#   'id': 14,
#   'title': 'repellendus sunt dolores architecto voluptatum',
#   'completed': True},
#  {'userId': 1,
#   'id': 15,
#   'title': 'ab voluptatum amet voluptas',
#   'completed': True},
#  {'userId': 1,
#   'id': 16,
#   'title': 'accusamus eos facilis sint et aut voluptatem',
#   'completed': True},
#  {'userId': 1,
#   'id': 17,
#   'title': 'quo laboriosam deleniti aut qui',
#   'completed': True},
#  {'userId': 1,
#   'id': 18,
#   'title': 'dolorum est consequatur ea mollitia in culpa',
#   'completed': False},
#  {'userId': 1,
#   'id': 19,
#   'title': 'molestiae ipsa aut voluptatibus pariatur dolor nihil',
#   'completed': True},
#  {'userId': 1,
#   'id': 20,
#   'title': 'ullam nobis libero sapiente ad optio sint',
#   'completed': True},
#  {'userId': 2,
#   'id': 21,
#   'title': 'suscipit repellat esse quibusdam voluptatem incidunt',
#   'completed': False},
#  {'userId': 2,
#   'id': 22,
#   'title': 'distinctio vitae autem nihil ut molestias quo',
#   'completed': True},
#  {'userId': 2,
#   'id': 23,
#   'title': 'et itaque necessitatibus maxime molestiae qui quas velit',
#   'completed': False},
#  {'userId': 2,
#   'id': 24,
#   'title': 'adipisci non ad dicta qui amet quaerat doloribus ea',
#   'completed': False},
#  {'userId': 2,
#   'id': 25,
#   'title': 'voluptas quo tenetur perspiciatis explicabo natus',
#   'completed': True},
#  {'userId': 2, 'id': 26, 'title': 'aliquam aut quasi', 'completed': True},
#  {'userId': 2,
#   'id': 27,
#   'title': 'veritatis pariatur delectus',
#   'completed': True},
#  {'userId': 2,
#   'id': 28,
#   'title': 'nesciunt totam sit blanditiis sit',
#   'completed': False},
#  {'userId': 2, 'id': 29, 'title': 'laborum aut in quam', 'completed': False},
#  {'userId': 2,
#   'id': 30,
#   'title': 'nemo perspiciatis repellat ut dolor libero commodi blanditiis omnis',
#   'completed': True},
#  {'userId': 2,
#   'id': 31,
#   'title': 'repudiandae totam in est sint facere fuga',
#   'completed': False},
#  {'userId': 2,
#   'id': 32,
#   'title': 'earum doloribus ea doloremque quis',
#   'completed': False},
#  {'userId': 2, 'id': 33, 'title': 'sint sit aut vero', 'completed': False},
#  {'userId': 2,
#   'id': 34,
#   'title': 'porro aut necessitatibus eaque distinctio',
#   'completed': False},
#  {'userId': 2,
#   'id': 35,
#   'title': 'repellendus veritatis molestias dicta incidunt',
#   'completed': True},
#  {'userId': 2,
#   'id': 36,
#   'title': 'excepturi deleniti adipisci voluptatem et neque optio illum ad',
#   'completed': True},
#  {'userId': 2, 'id': 37, 'title': 'sunt cum tempora', 'completed': False},
#  {'userId': 2, 'id': 38, 'title': 'totam quia non', 'completed': False},
#  {'userId': 2,
#   'id': 39,
#   'title': 'doloremque quibusdam asperiores libero corrupti illum qui omnis',
#   'completed': False},
#  {'userId': 2,
#   'id': 40,
#   'title': 'totam atque quo nesciunt',
#   'completed': True},
#  {'userId': 3,
#   'id': 41,
#   'title': 'aliquid amet impedit consequatur aspernatur placeat eaque fugiat suscipit',
#   'completed': False},
#  {'userId': 3,
#   'id': 42,
#   'title': 'rerum perferendis error quia ut eveniet',
#   'completed': False},
#  {'userId': 3,
#   'id': 43,
#   'title': 'tempore ut sint quis recusandae',
#   'completed': True},
#  {'userId': 3,
#   'id': 44,
#   'title': 'cum debitis quis accusamus doloremque ipsa natus sapiente omnis',
#   'completed': True},
#  {'userId': 3,
#   'id': 45,
#   'title': 'velit soluta adipisci molestias reiciendis harum',
#   'completed': False},
#  {'userId': 3,
#   'id': 46,
#   'title': 'vel voluptatem repellat nihil placeat corporis',
#   'completed': False},
#  {'userId': 3,
#   'id': 47,
#   'title': 'nam qui rerum fugiat accusamus',
#   'completed': False},
#  {'userId': 3,
#   'id': 48,
#   'title': 'sit reprehenderit omnis quia',
#   'completed': False},
#  {'userId': 3,
#   'id': 49,
#   'title': 'ut necessitatibus aut maiores debitis officia blanditiis velit et',
#   'completed': False},
#  {'userId': 3,
#   'id': 50,
#   'title': 'cupiditate necessitatibus ullam aut quis dolor voluptate',
#   'completed': True},
#  {'userId': 3,
#   'id': 51,
#   'title': 'distinctio exercitationem ab doloribus',
#   'completed': False},
#  {'userId': 3,
#   'id': 52,
#   'title': 'nesciunt dolorum quis recusandae ad pariatur ratione',
#   'completed': False},
#  {'userId': 3,
#   'id': 53,
#   'title': 'qui labore est occaecati recusandae aliquid quam',
#   'completed': False},
#  {'userId': 3,
#   'id': 54,
#   'title': 'quis et est ut voluptate quam dolor',
#   'completed': True},
#  {'userId': 3,
#   'id': 55,
#   'title': 'voluptatum omnis minima qui occaecati provident nulla voluptatem ratione',
#   'completed': True},
#  {'userId': 3,
#   'id': 56,
#   'title': 'deleniti ea temporibus enim',
#   'completed': True},
#  {'userId': 3,
#   'id': 57,
#   'title': 'pariatur et magnam ea doloribus similique voluptatem rerum quia',
#   'completed': False},
#  {'userId': 3,
#   'id': 58,
#   'title': 'est dicta totam qui explicabo doloribus qui dignissimos',
#   'completed': False},
#  {'userId': 3,
#   'id': 59,
#   'title': 'perspiciatis velit id laborum placeat iusto et aliquam odio',
#   'completed': False},
#  {'userId': 3,
#   'id': 60,
#   'title': 'et sequi qui architecto ut adipisci',
#   'completed': True},
#  {'userId': 4,
#   'id': 61,
#   'title': 'odit optio omnis qui sunt',
#   'completed': True},
#  {'userId': 4,
#   'id': 62,
#   'title': 'et placeat et tempore aspernatur sint numquam',
#   'completed': False},
#  {'userId': 4,
#   'id': 63,
#   'title': 'doloremque aut dolores quidem fuga qui nulla',
#   'completed': True},
#  {'userId': 4,
#   'id': 64,
#   'title': 'voluptas consequatur qui ut quia magnam nemo esse',
#   'completed': False},
#  {'userId': 4,
#   'id': 65,
#   'title': 'fugiat pariatur ratione ut asperiores necessitatibus magni',
#   'completed': False},
#  {'userId': 4,
#   'id': 66,
#   'title': 'rerum eum molestias autem voluptatum sit optio',
#   'completed': False},
#  {'userId': 4,
#   'id': 67,
#   'title': 'quia voluptatibus voluptatem quos similique maiores repellat',
#   'completed': False},
#  {'userId': 4,
#   'id': 68,
#   'title': 'aut id perspiciatis voluptatem iusto',
#   'completed': False},
#  {'userId': 4,
#   'id': 69,
#   'title': 'doloribus sint dolorum ab adipisci itaque dignissimos aliquam suscipit',
#   'completed': False},
#  {'userId': 4,
#   'id': 70,
#   'title': 'ut sequi accusantium et mollitia delectus sunt',
#   'completed': False},
#  {'userId': 4, 'id': 71, 'title': 'aut velit saepe ullam', 'completed': False},
#  {'userId': 4,
#   'id': 72,
#   'title': 'praesentium facilis facere quis harum voluptatibus voluptatem eum',
#   'completed': False},
#  {'userId': 4,
#   'id': 73,
#   'title': 'sint amet quia totam corporis qui exercitationem commodi',
#   'completed': True},
#  {'userId': 4,
#   'id': 74,
#   'title': 'expedita tempore nobis eveniet laborum maiores',
#   'completed': False},
#  {'userId': 4,
#   'id': 75,
#   'title': 'occaecati adipisci est possimus totam',
#   'completed': False},
#  {'userId': 4, 'id': 76, 'title': 'sequi dolorem sed', 'completed': True},
#  {'userId': 4,
#   'id': 77,
#   'title': 'maiores aut nesciunt delectus exercitationem vel assumenda eligendi at',
#   'completed': False},
#  {'userId': 4,
#   'id': 78,
#   'title': 'reiciendis est magnam amet nemo iste recusandae impedit quaerat',
#   'completed': False},
#  {'userId': 4, 'id': 79, 'title': 'eum ipsa maxime ut', 'completed': True},
#  {'userId': 4,
#   'id': 80,
#   'title': 'tempore molestias dolores rerum sequi voluptates ipsum consequatur',
#   'completed': True},
#  {'userId': 5, 'id': 81, 'title': 'suscipit qui totam', 'completed': True},
#  {'userId': 5,
#   'id': 82,
#   'title': 'voluptates eum voluptas et dicta',
#   'completed': False},
#  {'userId': 5,
#   'id': 83,
#   'title': 'quidem at rerum quis ex aut sit quam',
#   'completed': True},
#  {'userId': 5,
#   'id': 84,
#   'title': 'sunt veritatis ut voluptate',
#   'completed': False},
#  {'userId': 5, 'id': 85, 'title': 'et quia ad iste a', 'completed': True},
#  {'userId': 5,
#   'id': 86,
#   'title': 'incidunt ut saepe autem',
#   'completed': True},
#  {'userId': 5,
#   'id': 87,
#   'title': 'laudantium quae eligendi consequatur quia et vero autem',
#   'completed': True},
#  {'userId': 5,
#   'id': 88,
#   'title': 'vitae aut excepturi laboriosam sint aliquam et et accusantium',
#   'completed': False},
#  {'userId': 5, 'id': 89, 'title': 'sequi ut omnis et', 'completed': True},
#  {'userId': 5,
#   'id': 90,
#   'title': 'molestiae nisi accusantium tenetur dolorem et',
#   'completed': True},
#  {'userId': 5,
#   'id': 91,
#   'title': 'nulla quis consequatur saepe qui id expedita',
#   'completed': True},
#  {'userId': 5, 'id': 92, 'title': 'in omnis laboriosam', 'completed': True},
#  {'userId': 5,
#   'id': 93,
#   'title': 'odio iure consequatur molestiae quibusdam necessitatibus quia sint',
#   'completed': True},
#  {'userId': 5,
#   'id': 94,
#   'title': 'facilis modi saepe mollitia',
#   'completed': False},
#  {'userId': 5,
#   'id': 95,
#   'title': 'vel nihil et molestiae iusto assumenda nemo quo ut',
#   'completed': True},
#  {'userId': 5,
#   'id': 96,
#   'title': 'nobis suscipit ducimus enim asperiores voluptas',
#   'completed': False},
#  {'userId': 5,
#   'id': 97,
#   'title': 'dolorum laboriosam eos qui iure aliquam',
#   'completed': False},
#  {'userId': 5,
#   'id': 98,
#   'title': 'debitis accusantium ut quo facilis nihil quis sapiente necessitatibus',
#   'completed': True},
#  {'userId': 5,
#   'id': 99,
#   'title': 'neque voluptates ratione',
#   'completed': False},
#  {'userId': 5,
#   'id': 100,
#   'title': 'excepturi a et neque qui expedita vel voluptate',
#   'completed': False},
#  {'userId': 6,
#   'id': 101,
#   'title': 'explicabo enim cumque porro aperiam occaecati minima',
#   'completed': False},
#  {'userId': 6, 'id': 102, 'title': 'sed ab consequatur', 'completed': False},
#  {'userId': 6,
#   'id': 103,
#   'title': 'non sunt delectus illo nulla tenetur enim omnis',
#   'completed': False},
#  {'userId': 6,
#   'id': 104,
#   'title': 'excepturi non laudantium quo',
#   'completed': False},
#  {'userId': 6,
#   'id': 105,
#   'title': 'totam quia dolorem et illum repellat voluptas optio',
#   'completed': True},
#  {'userId': 6,
#   'id': 106,
#   'title': 'ad illo quis voluptatem temporibus',
#   'completed': True},
#  {'userId': 6,
#   'id': 107,
#   'title': 'praesentium facilis omnis laudantium fugit ad iusto nihil nesciunt',
#   'completed': False},
#  {'userId': 6,
#   'id': 108,
#   'title': 'a eos eaque nihil et exercitationem incidunt delectus',
#   'completed': True},
#  {'userId': 6,
#   'id': 109,
#   'title': 'autem temporibus harum quisquam in culpa',
#   'completed': True},
#  {'userId': 6, 'id': 110, 'title': 'aut aut ea corporis', 'completed': True},
#  {'userId': 6,
#   'id': 111,
#   'title': 'magni accusantium labore et id quis provident',
#   'completed': False},
#  {'userId': 6,
#   'id': 112,
#   'title': 'consectetur impedit quisquam qui deserunt non rerum consequuntur eius',
#   'completed': False},
#  {'userId': 6,
#   'id': 113,
#   'title': 'quia atque aliquam sunt impedit voluptatum rerum assumenda nisi',
#   'completed': False},
#  {'userId': 6,
#   'id': 114,
#   'title': 'cupiditate quos possimus corporis quisquam exercitationem beatae',
#   'completed': False},
#  {'userId': 6, 'id': 115, 'title': 'sed et ea eum', 'completed': False},
#  {'userId': 6,
#   'id': 116,
#   'title': 'ipsa dolores vel facilis ut',
#   'completed': True},
#  {'userId': 6,
#   'id': 117,
#   'title': 'sequi quae est et qui qui eveniet asperiores',
#   'completed': False},
#  {'userId': 6,
#   'id': 118,
#   'title': 'quia modi consequatur vero fugiat',
#   'completed': False},
#  {'userId': 6,
#   'id': 119,
#   'title': 'corporis ducimus ea perspiciatis iste',
#   'completed': False},
#  {'userId': 6,
#   'id': 120,
#   'title': 'dolorem laboriosam vel voluptas et aliquam quasi',
#   'completed': False},
#  {'userId': 7,
#   'id': 121,
#   'title': 'inventore aut nihil minima laudantium hic qui omnis',
#   'completed': True},
#  {'userId': 7,
#   'id': 122,
#   'title': 'provident aut nobis culpa',
#   'completed': True},
#  {'userId': 7,
#   'id': 123,
#   'title': 'esse et quis iste est earum aut impedit',
#   'completed': False},
#  {'userId': 7, 'id': 124, 'title': 'qui consectetur id', 'completed': False},
#  {'userId': 7,
#   'id': 125,
#   'title': 'aut quasi autem iste tempore illum possimus',
#   'completed': False},
#  {'userId': 7,
#   'id': 126,
#   'title': 'ut asperiores perspiciatis veniam ipsum rerum saepe',
#   'completed': True},
#  {'userId': 7,
#   'id': 127,
#   'title': 'voluptatem libero consectetur rerum ut',
#   'completed': True},
#  {'userId': 7,
#   'id': 128,
#   'title': 'eius omnis est qui voluptatem autem',
#   'completed': False},
#  {'userId': 7,
#   'id': 129,
#   'title': 'rerum culpa quis harum',
#   'completed': False},
#  {'userId': 7,
#   'id': 130,
#   'title': 'nulla aliquid eveniet harum laborum libero alias ut unde',
#   'completed': True},
#  {'userId': 7, 'id': 131, 'title': 'qui ea incidunt quis', 'completed': False},
#  {'userId': 7,
#   'id': 132,
#   'title': 'qui molestiae voluptatibus velit iure harum quisquam',
#   'completed': True},
#  {'userId': 7,
#   'id': 133,
#   'title': 'et labore eos enim rerum consequatur sunt',
#   'completed': True},
#  {'userId': 7,
#   'id': 134,
#   'title': 'molestiae doloribus et laborum quod ea',
#   'completed': False},
#  {'userId': 7,
#   'id': 135,
#   'title': 'facere ipsa nam eum voluptates reiciendis vero qui',
#   'completed': False},
#  {'userId': 7,
#   'id': 136,
#   'title': 'asperiores illo tempora fuga sed ut quasi adipisci',
#   'completed': False},
#  {'userId': 7, 'id': 137, 'title': 'qui sit non', 'completed': False},
#  {'userId': 7,
#   'id': 138,
#   'title': 'placeat minima consequatur rem qui ut',
#   'completed': True},
#  {'userId': 7,
#   'id': 139,
#   'title': 'consequatur doloribus id possimus voluptas a voluptatem',
#   'completed': False},
#  {'userId': 7,
#   'id': 140,
#   'title': 'aut consectetur in blanditiis deserunt quia sed laboriosam',
#   'completed': True},
#  {'userId': 8,
#   'id': 141,
#   'title': 'explicabo consectetur debitis voluptates quas quae culpa rerum non',
#   'completed': True},
#  {'userId': 8,
#   'id': 142,
#   'title': 'maiores accusantium architecto necessitatibus reiciendis ea aut',
#   'completed': True},
#  {'userId': 8,
#   'id': 143,
#   'title': 'eum non recusandae cupiditate animi',
#   'completed': False},
#  {'userId': 8,
#   'id': 144,
#   'title': 'ut eum exercitationem sint',
#   'completed': False},
#  {'userId': 8,
#   'id': 145,
#   'title': 'beatae qui ullam incidunt voluptatem non nisi aliquam',
#   'completed': False},
#  {'userId': 8,
#   'id': 146,
#   'title': 'molestiae suscipit ratione nihil odio libero impedit vero totam',
#   'completed': True},
#  {'userId': 8,
#   'id': 147,
#   'title': 'eum itaque quod reprehenderit et facilis dolor autem ut',
#   'completed': True},
#  {'userId': 8,
#   'id': 148,
#   'title': 'esse quas et quo quasi exercitationem',
#   'completed': False},
#  {'userId': 8,
#   'id': 149,
#   'title': 'animi voluptas quod perferendis est',
#   'completed': False},
#  {'userId': 8,
#   'id': 150,
#   'title': 'eos amet tempore laudantium fugit a',
#   'completed': False},
#  {'userId': 8,
#   'id': 151,
#   'title': 'accusamus adipisci dicta qui quo ea explicabo sed vero',
#   'completed': True},
#  {'userId': 8,
#   'id': 152,
#   'title': 'odit eligendi recusandae doloremque cumque non',
#   'completed': False},
#  {'userId': 8,
#   'id': 153,
#   'title': 'ea aperiam consequatur qui repellat eos',
#   'completed': False},
#  {'userId': 8, 'id': 154, 'title': 'rerum non ex sapiente', 'completed': True},
#  {'userId': 8,
#   'id': 155,
#   'title': 'voluptatem nobis consequatur et assumenda magnam',
#   'completed': True},
#  {'userId': 8,
#   'id': 156,
#   'title': 'nam quia quia nulla repellat assumenda quibusdam sit nobis',
#   'completed': True},
#  {'userId': 8,
#   'id': 157,
#   'title': 'dolorem veniam quisquam deserunt repellendus',
#   'completed': True},
#  {'userId': 8,
#   'id': 158,
#   'title': 'debitis vitae delectus et harum accusamus aut deleniti a',
#   'completed': True},
#  {'userId': 8,
#   'id': 159,
#   'title': 'debitis adipisci quibusdam aliquam sed dolore ea praesentium nobis',
#   'completed': True},
#  {'userId': 8,
#   'id': 160,
#   'title': 'et praesentium aliquam est',
#   'completed': False},
#  {'userId': 9,
#   'id': 161,
#   'title': 'ex hic consequuntur earum omnis alias ut occaecati culpa',
#   'completed': True},
#  {'userId': 9,
#   'id': 162,
#   'title': 'omnis laboriosam molestias animi sunt dolore',
#   'completed': True},
#  {'userId': 9,
#   'id': 163,
#   'title': 'natus corrupti maxime laudantium et voluptatem laboriosam odit',
#   'completed': False},
#  {'userId': 9,
#   'id': 164,
#   'title': 'reprehenderit quos aut aut consequatur est sed',
#   'completed': False},
#  {'userId': 9,
#   'id': 165,
#   'title': 'fugiat perferendis sed aut quidem',
#   'completed': False},
#  {'userId': 9,
#   'id': 166,
#   'title': 'quos quo possimus suscipit minima ut',
#   'completed': False},
#  {'userId': 9,
#   'id': 167,
#   'title': 'et quis minus quo a asperiores molestiae',
#   'completed': False},
#  {'userId': 9,
#   'id': 168,
#   'title': 'recusandae quia qui sunt libero',
#   'completed': False},
#  {'userId': 9,
#   'id': 169,
#   'title': 'ea odio perferendis officiis',
#   'completed': True},
#  {'userId': 9,
#   'id': 170,
#   'title': 'quisquam aliquam quia doloribus aut',
#   'completed': False},
#  {'userId': 9,
#   'id': 171,
#   'title': 'fugiat aut voluptatibus corrupti deleniti velit iste odio',
#   'completed': True},
#  {'userId': 9,
#   'id': 172,
#   'title': 'et provident amet rerum consectetur et voluptatum',
#   'completed': False},
#  {'userId': 9,
#   'id': 173,
#   'title': 'harum ad aperiam quis',
#   'completed': False},
#  {'userId': 9, 'id': 174, 'title': 'similique aut quo', 'completed': False},
#  {'userId': 9,
#   'id': 175,
#   'title': 'laudantium eius officia perferendis provident perspiciatis asperiores',
#   'completed': True},
#  {'userId': 9,
#   'id': 176,
#   'title': 'magni soluta corrupti ut maiores rem quidem',
#   'completed': False},
#  {'userId': 9,
#   'id': 177,
#   'title': 'et placeat temporibus voluptas est tempora quos quibusdam',
#   'completed': False},
#  {'userId': 9,
#   'id': 178,
#   'title': 'nesciunt itaque commodi tempore',
#   'completed': True},
#  {'userId': 9,
#   'id': 179,
#   'title': 'omnis consequuntur cupiditate impedit itaque ipsam quo',
#   'completed': True},
#  {'userId': 9,
#   'id': 180,
#   'title': 'debitis nisi et dolorem repellat et',
#   'completed': True},
#  {'userId': 10,
#   'id': 181,
#   'title': 'ut cupiditate sequi aliquam fuga maiores',
#   'completed': False},
#  {'userId': 10,
#   'id': 182,
#   'title': 'inventore saepe cumque et aut illum enim',
#   'completed': True},
#  {'userId': 10,
#   'id': 183,
#   'title': 'omnis nulla eum aliquam distinctio',
#   'completed': True},
#  {'userId': 10,
#   'id': 184,
#   'title': 'molestias modi perferendis perspiciatis',
#   'completed': False},
#  {'userId': 10,
#   'id': 185,
#   'title': 'voluptates dignissimos sed doloribus animi quaerat aut',
#   'completed': False},
#  {'userId': 10,
#   'id': 186,
#   'title': 'explicabo odio est et',
#   'completed': False},
#  {'userId': 10,
#   'id': 187,
#   'title': 'consequuntur animi possimus',
#   'completed': False},
#  {'userId': 10, 'id': 188, 'title': 'vel non beatae est', 'completed': True},
#  {'userId': 10,
#   'id': 189,
#   'title': 'culpa eius et voluptatem et',
#   'completed': True},
#  {'userId': 10,
#   'id': 190,
#   'title': 'accusamus sint iusto et voluptatem exercitationem',
#   'completed': True},
#  {'userId': 10,
#   'id': 191,
#   'title': 'temporibus atque distinctio omnis eius impedit tempore molestias pariatur',
#   'completed': True},
#  {'userId': 10,
#   'id': 192,
#   'title': 'ut quas possimus exercitationem sint voluptates',
#   'completed': False},
#  {'userId': 10,
#   'id': 193,
#   'title': 'rerum debitis voluptatem qui eveniet tempora distinctio a',
#   'completed': True},
#  {'userId': 10,
#   'id': 194,
#   'title': 'sed ut vero sit molestiae',
#   'completed': False},
#  {'userId': 10,
#   'id': 195,
#   'title': 'rerum ex veniam mollitia voluptatibus pariatur',
#   'completed': True},
#  {'userId': 10,
#   'id': 196,
#   'title': 'consequuntur aut ut fugit similique',
#   'completed': True},
#  {'userId': 10,
#   'id': 197,
#   'title': 'dignissimos quo nobis earum saepe',
#   'completed': True},
#  {'userId': 10,
#   'id': 198,
#   'title': 'quis eius est sint explicabo',
#   'completed': True},
#  {'userId': 10,
#   'id': 199,
#   'title': 'numquam repellendus a magnam',
#   'completed': True},
#  {'userId': 10,
#   'id': 200,
#   'title': 'ipsam aperiam voluptates qui',
#   'completed': False}]

# %%
import pandas as pd
# json to pandas dataframe
pd.DataFrame(resp_json)
# Out:
#      userId   id                                              title  completed
# 0         1    1                                 delectus aut autem      False
# 1         1    2                 quis ut nam facilis et officia qui      False
# 2         1    3                                fugiat veniam minus      False
# 3         1    4                                   et porro tempora       True
# 4         1    5  laboriosam mollitia et enim quasi adipisci qui...      False
# ..      ...  ...                                                ...        ...
# 195      10  196                consequuntur aut ut fugit similique       True
# 196      10  197                  dignissimos quo nobis earum saepe       True
# 197      10  198                       quis eius est sint explicabo       True
# 198      10  199                       numquam repellendus a magnam       True
# 199      10  200                       ipsam aperiam voluptates qui      False
#
# [200 rows x 4 columns]

# %% [markdown]
# ### GitHub API
#
# Docs here: https://docs.github.com/en/free-pro-team@latest/rest/reference/activity

# %%
requests.get("https://api.github.com/zen").text
# Out:
# 'Half measures are as bad as nothing at all.'

# %%
response = requests.get('https://api.github.com/events')

# %%
# get the .json from the response

github_response = response.json()

# %%
github_response
# Out:
# [{'id': '19011607535',
#   'type': 'IssueCommentEvent',
#   'actor': {'id': 22429695,
#    'login': 'codecov[bot]',
#    'display_login': 'codecov',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/codecov[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/22429695?'},
#   'repo': {'id': 241303276,
#    'name': 'studiometa/js-toolkit',
#    'url': 'https://api.github.com/repos/studiometa/js-toolkit'},
#   'payload': {'action': 'created',
#    'issue': {'url': 'https://api.github.com/repos/studiometa/js-toolkit/issues/167',
#     'repository_url': 'https://api.github.com/repos/studiometa/js-toolkit',
#     'labels_url': 'https://api.github.com/repos/studiometa/js-toolkit/issues/167/labels{/name}',
#     'comments_url': 'https://api.github.com/repos/studiometa/js-toolkit/issues/167/comments',
#     'events_url': 'https://api.github.com/repos/studiometa/js-toolkit/issues/167/events',
#     'html_url': 'https://github.com/studiometa/js-toolkit/pull/167',
#     'id': 1061036164,
#     'node_id': 'PR_kwDODmH-7M4u5aWD',
#     'number': 167,
#     'title': '[Hotfix] 2.0.0-beta.3 ',
#     'user': {'login': 'titouanmathis',
#      'id': 250145,
#      'node_id': 'MDQ6VXNlcjI1MDE0NQ==',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/250145?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/titouanmathis',
#      'html_url': 'https://github.com/titouanmathis',
#      'followers_url': 'https://api.github.com/users/titouanmathis/followers',
#      'following_url': 'https://api.github.com/users/titouanmathis/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/titouanmathis/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/titouanmathis/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/titouanmathis/subscriptions',
#      'organizations_url': 'https://api.github.com/users/titouanmathis/orgs',
#      'repos_url': 'https://api.github.com/users/titouanmathis/repos',
#      'events_url': 'https://api.github.com/users/titouanmathis/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/titouanmathis/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'labels': [],
#     'state': 'open',
#     'locked': False,
#     'assignee': {'login': 'titouanmathis',
#      'id': 250145,
#      'node_id': 'MDQ6VXNlcjI1MDE0NQ==',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/250145?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/titouanmathis',
#      'html_url': 'https://github.com/titouanmathis',
#      'followers_url': 'https://api.github.com/users/titouanmathis/followers',
#      'following_url': 'https://api.github.com/users/titouanmathis/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/titouanmathis/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/titouanmathis/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/titouanmathis/subscriptions',
#      'organizations_url': 'https://api.github.com/users/titouanmathis/orgs',
#      'repos_url': 'https://api.github.com/users/titouanmathis/repos',
#      'events_url': 'https://api.github.com/users/titouanmathis/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/titouanmathis/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'assignees': [{'login': 'titouanmathis',
#       'id': 250145,
#       'node_id': 'MDQ6VXNlcjI1MDE0NQ==',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/250145?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/titouanmathis',
#       'html_url': 'https://github.com/titouanmathis',
#       'followers_url': 'https://api.github.com/users/titouanmathis/followers',
#       'following_url': 'https://api.github.com/users/titouanmathis/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/titouanmathis/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/titouanmathis/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/titouanmathis/subscriptions',
#       'organizations_url': 'https://api.github.com/users/titouanmathis/orgs',
#       'repos_url': 'https://api.github.com/users/titouanmathis/repos',
#       'events_url': 'https://api.github.com/users/titouanmathis/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/titouanmathis/received_events',
#       'type': 'User',
#       'site_admin': False}],
#     'milestone': None,
#     'comments': 1,
#     'created_at': '2021-11-23T09:54:17Z',
#     'updated_at': '2021-11-23T09:55:56Z',
#     'closed_at': None,
#     'author_association': 'CONTRIBUTOR',
#     'active_lock_reason': None,
#     'draft': False,
#     'pull_request': {'url': 'https://api.github.com/repos/studiometa/js-toolkit/pulls/167',
#      'html_url': 'https://github.com/studiometa/js-toolkit/pull/167',
#      'diff_url': 'https://github.com/studiometa/js-toolkit/pull/167.diff',
#      'patch_url': 'https://github.com/studiometa/js-toolkit/pull/167.patch',
#      'merged_at': None},
#     'body': '## Fixed\r\n- Fix changelog generation in release action (8226d9a)',
#     'reactions': {'url': 'https://api.github.com/repos/studiometa/js-toolkit/issues/167/reactions',
#      'total_count': 0,
#      '+1': 0,
#      '-1': 0,
#      'laugh': 0,
#      'hooray': 0,
#      'confused': 0,
#      'heart': 0,
#      'rocket': 0,
#      'eyes': 0},
#     'timeline_url': 'https://api.github.com/repos/studiometa/js-toolkit/issues/167/timeline',
#     'performed_via_github_app': None},
#    'comment': {'url': 'https://api.github.com/repos/studiometa/js-toolkit/issues/comments/976352888',
#     'html_url': 'https://github.com/studiometa/js-toolkit/pull/167#issuecomment-976352888',
#     'issue_url': 'https://api.github.com/repos/studiometa/js-toolkit/issues/167',
#     'id': 976352888,
#     'node_id': 'IC_kwDODmH-7M46MfZ4',
#     'user': {'login': 'codecov[bot]',
#      'id': 22429695,
#      'node_id': 'MDM6Qm90MjI0Mjk2OTU=',
#      'avatar_url': 'https://avatars.githubusercontent.com/in/254?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/codecov%5Bbot%5D',
#      'html_url': 'https://github.com/apps/codecov',
#      'followers_url': 'https://api.github.com/users/codecov%5Bbot%5D/followers',
#      'following_url': 'https://api.github.com/users/codecov%5Bbot%5D/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/codecov%5Bbot%5D/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/codecov%5Bbot%5D/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/codecov%5Bbot%5D/subscriptions',
#      'organizations_url': 'https://api.github.com/users/codecov%5Bbot%5D/orgs',
#      'repos_url': 'https://api.github.com/users/codecov%5Bbot%5D/repos',
#      'events_url': 'https://api.github.com/users/codecov%5Bbot%5D/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/codecov%5Bbot%5D/received_events',
#      'type': 'Bot',
#      'site_admin': False},
#     'created_at': '2021-11-23T09:55:56Z',
#     'updated_at': '2021-11-23T09:55:56Z',
#     'author_association': 'NONE',
#     'body': "# [Codecov](https://codecov.io/gh/studiometa/js-toolkit/pull/167?src=pr&el=h1&utm_medium=referral&utm_source=github&utm_content=comment&utm_campaign=pr+comments&utm_term=studiometa) Report\n> Merging [#167](https://codecov.io/gh/studiometa/js-toolkit/pull/167?src=pr&el=desc&utm_medium=referral&utm_source=github&utm_content=comment&utm_campaign=pr+comments&utm_term=studiometa) (8226d9a) into [master](https://codecov.io/gh/studiometa/js-toolkit/commit/b74b80c8c64e99b0f84cf09968750143614a99cb?el=desc&utm_medium=referral&utm_source=github&utm_content=comment&utm_campaign=pr+comments&utm_term=studiometa) (b74b80c) will **not change** coverage.\n> The diff coverage is `n/a`.\n\n[![Impacted file tree graph](https://codecov.io/gh/studiometa/js-toolkit/pull/167/graphs/tree.svg?width=650&height=150&src=pr&token=37K1XD0UJ0&utm_medium=referral&utm_source=github&utm_content=comment&utm_campaign=pr+comments&utm_term=studiometa)](https://codecov.io/gh/studiometa/js-toolkit/pull/167?src=pr&el=tree&utm_medium=referral&utm_source=github&utm_content=comment&utm_campaign=pr+comments&utm_term=studiometa)\n\n```diff\n@@           Coverage Diff           @@\n##           master     #167   +/-   ##\n=======================================\n  Coverage   99.59%   99.59%           \n=======================================\n  Files          65       65           \n  Lines        1467     1467           \n  Branches      330      330           \n=======================================\n  Hits         1461     1461           \n  Misses          6        6           \n```\n\n| Flag | Coverage Δ | |\n|---|---|---|\n| unittests | `99.59% <ø> (ø)` | |\n\nFlags with carried forward coverage won't be shown. [Click here](https://docs.codecov.io/docs/carryforward-flags?utm_medium=referral&utm_source=github&utm_content=comment&utm_campaign=pr+comments&utm_term=studiometa#carryforward-flags-in-the-pull-request-comment) to find out more.\n\n\n------\n\n[Continue to review full report at Codecov](https://codecov.io/gh/studiometa/js-toolkit/pull/167?src=pr&el=continue&utm_medium=referral&utm_source=github&utm_content=comment&utm_campaign=pr+comments&utm_term=studiometa).\n> **Legend** - [Click here to learn more](https://docs.codecov.io/docs/codecov-delta?utm_medium=referral&utm_source=github&utm_content=comment&utm_campaign=pr+comments&utm_term=studiometa)\n> `Δ = absolute <relative> (impact)`, `ø = not affected`, `? = missing data`\n> Powered by [Codecov](https://codecov.io/gh/studiometa/js-toolkit/pull/167?src=pr&el=footer&utm_medium=referral&utm_source=github&utm_content=comment&utm_campaign=pr+comments&utm_term=studiometa). Last update [b74b80c...8226d9a](https://codecov.io/gh/studiometa/js-toolkit/pull/167?src=pr&el=lastupdated&utm_medium=referral&utm_source=github&utm_content=comment&utm_campaign=pr+comments&utm_term=studiometa). Read the [comment docs](https://docs.codecov.io/docs/pull-request-comments?utm_medium=referral&utm_source=github&utm_content=comment&utm_campaign=pr+comments&utm_term=studiometa).\n",
#     'reactions': {'url': 'https://api.github.com/repos/studiometa/js-toolkit/issues/comments/976352888/reactions',
#      'total_count': 0,
#      '+1': 0,
#      '-1': 0,
#      'laugh': 0,
#      'hooray': 0,
#      'confused': 0,
#      'heart': 0,
#      'rocket': 0,
#      'eyes': 0},
#     'performed_via_github_app': None}},
#   'public': True,
#   'created_at': '2021-11-23T09:55:56Z',
#   'org': {'id': 428408,
#    'login': 'studiometa',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/studiometa',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/428408?'}},
#  {'id': '19011607516',
#   'type': 'PullRequestEvent',
#   'actor': {'id': 205231,
#    'login': 'tvanier',
#    'display_login': 'tvanier',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/tvanier',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/205231?'},
#   'repo': {'id': 336891826,
#    'name': 'tvanier/sport-visioner',
#    'url': 'https://api.github.com/repos/tvanier/sport-visioner'},
#   'payload': {'action': 'closed',
#    'number': 174,
#    'pull_request': {'url': 'https://api.github.com/repos/tvanier/sport-visioner/pulls/174',
#     'id': 786254111,
#     'node_id': 'PR_kwDOFBSPss4u3Ukf',
#     'html_url': 'https://github.com/tvanier/sport-visioner/pull/174',
#     'diff_url': 'https://github.com/tvanier/sport-visioner/pull/174.diff',
#     'patch_url': 'https://github.com/tvanier/sport-visioner/pull/174.patch',
#     'issue_url': 'https://api.github.com/repos/tvanier/sport-visioner/issues/174',
#     'number': 174,
#     'state': 'closed',
#     'locked': False,
#     'title': 'chore(deps-dev): bump @babel/preset-env from 7.16.0 to 7.16.4',
#     'user': {'login': 'dependabot[bot]',
#      'id': 49699333,
#      'node_id': 'MDM6Qm90NDk2OTkzMzM=',
#      'avatar_url': 'https://avatars.githubusercontent.com/in/29110?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/dependabot%5Bbot%5D',
#      'html_url': 'https://github.com/apps/dependabot',
#      'followers_url': 'https://api.github.com/users/dependabot%5Bbot%5D/followers',
#      'following_url': 'https://api.github.com/users/dependabot%5Bbot%5D/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/dependabot%5Bbot%5D/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/dependabot%5Bbot%5D/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/dependabot%5Bbot%5D/subscriptions',
#      'organizations_url': 'https://api.github.com/users/dependabot%5Bbot%5D/orgs',
#      'repos_url': 'https://api.github.com/users/dependabot%5Bbot%5D/repos',
#      'events_url': 'https://api.github.com/users/dependabot%5Bbot%5D/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/dependabot%5Bbot%5D/received_events',
#      'type': 'Bot',
#      'site_admin': False},
#     'body': 'Bumps [@babel/preset-env](https://github.com/babel/babel/tree/HEAD/packages/babel-preset-env) from 7.16.0 to 7.16.4.\n<details>\n<summary>Release notes</summary>\n<p><em>Sourced from <a href="https://github.com/babel/babel/releases"><code>@\u200bbabel/preset-env</code>\'s releases</a>.</em></p>\n<blockquote>\n<h2>v7.16.4 (2021-11-16)</h2>\n<h4>:eyeglasses: Spec Compliance</h4>\n<ul>\n<li><code>babel-helper-remap-async-to-generator</code>, <code>babel-plugin-transform-async-to-generator</code>\n<ul>\n<li><a href="https://github-redirect.dependabot.com/babel/babel/pull/13961">#13961</a> Wait the correct number of ticks on nested <code>await</code> (<a href="https://github.com/nicolo-ribaudo"><code>@\u200bnicolo-ribaudo</code></a>)</li>\n</ul>\n</li>\n<li><code>babel-parser</code>\n<ul>\n<li><a href="https://github-redirect.dependabot.com/babel/babel/pull/13929">#13929</a> Refactor bindingProperty parsing (<a href="https://github.com/JLHwung"><code>@\u200bJLHwung</code></a>)</li>\n</ul>\n</li>\n</ul>\n<h4>:bug: Bug Fix</h4>\n<ul>\n<li><code>babel-parser</code>\n<ul>\n<li><a href="https://github-redirect.dependabot.com/babel/babel/pull/13957">#13957</a> Add <code>assertions</code> to <code>ExportNamedDeclaration</code> without <code>from</code> (<a href="https://github.com/sosukesuzuki"><code>@\u200bsosukesuzuki</code></a>)</li>\n<li><a href="https://github-redirect.dependabot.com/babel/babel/pull/13951">#13951</a> Throw on duplicate <code>__proto__</code> props followed by assignment (<a href="https://github.com/The-x-Theorist"><code>@\u200bThe-x-Theorist</code></a>)</li>\n</ul>\n</li>\n<li><code>babel-plugin-proposal-async-generator-functions</code>, <code>babel-plugin-proposal-decorators</code>, <code>babel-plugin-transform-runtime</code>, <code>babel-preset-env</code>\n<ul>\n<li><a href="https://github-redirect.dependabot.com/babel/babel/pull/12827">#12827</a> Add file extension when using <code>absoluteRuntime</code> (<a href="https://github.com/mbehzad"><code>@\u200bmbehzad</code></a>)</li>\n</ul>\n</li>\n</ul>\n<h4>:nail_care: Polish</h4>\n<ul>\n<li><code>babel-parser</code>\n<ul>\n<li><a href="https://github-redirect.dependabot.com/babel/babel/pull/13960">#13960</a> Always expose <code>expressionValue</code> in <code>DirectiveLiteral</code> nodes (<a href="https://github.com/tolmasky"><code>@\u200btolmasky</code></a>)</li>\n</ul>\n</li>\n</ul>\n<h4>Committers: 7</h4>\n<ul>\n<li>Babel Bot (<a href="https://github.com/babel-bot"><code>@\u200bbabel-bot</code></a>)</li>\n<li>Francisco Ryan Tolmasky I (<a href="https://github.com/tolmasky"><code>@\u200btolmasky</code></a>)</li>\n<li>Huáng Jùnliàng (<a href="https://github.com/JLHwung"><code>@\u200bJLHwung</code></a>)</li>\n<li>M Behzad (<a href="https://github.com/mbehzad"><code>@\u200bmbehzad</code></a>)</li>\n<li>Nicolò Ribaudo (<a href="https://github.com/nicolo-ribaudo"><code>@\u200bnicolo-ribaudo</code></a>)</li>\n<li>Sneh Khatri (<a href="https://github.com/The-x-Theorist"><code>@\u200bThe-x-Theorist</code></a>)</li>\n<li>Sosuke Suzuki (<a href="https://github.com/sosukesuzuki"><code>@\u200bsosukesuzuki</code></a>)</li>\n</ul>\n<h2>v7.16.3 (2021-11-09)</h2>\n<p>Thanks <a href="https://github.com/The-x-Theorist"><code>@\u200bThe-x-Theorist</code></a> for your first PR!</p>\n<h4>:bug: Bug Fix</h4>\n<ul>\n<li><code>babel-helpers</code>\n<ul>\n<li><a href="https://github-redirect.dependabot.com/babel/babel/pull/13862">#13862</a> fix(helpers): match <code>Reflect.get</code> behaviour (<a href="https://github.com/lightmare"><code>@\u200blightmare</code></a>)</li>\n</ul>\n</li>\n<li><code>babel-plugin-transform-parameters</code>, <code>babel-traverse</code>\n<ul>\n<li><a href="https://github-redirect.dependabot.com/babel/babel/pull/13941">#13941</a> Support transforming params of arrow functions in class fields (<a href="https://github.com/nicolo-ribaudo"><code>@\u200bnicolo-ribaudo</code></a>)</li>\n</ul>\n</li>\n<li><code>babel-parser</code>\n<ul>\n<li><a href="ht ...
#     'created_at': '2021-11-22T17:06:05Z',
#     'updated_at': '2021-11-23T09:55:56Z',
#     'closed_at': '2021-11-23T09:55:56Z',
#     'merged_at': '2021-11-23T09:55:56Z',
#     'merge_commit_sha': '8f4f0b43ccfd046e3e8dd04f4099137ed3db1ad0',
#     'assignee': None,
#     'assignees': [],
#     'requested_reviewers': [],
#     'requested_teams': [],
#     'labels': [{'id': 2737842269,
#       'node_id': 'MDU6TGFiZWwyNzM3ODQyMjY5',
#       'url': 'https://api.github.com/repos/tvanier/sport-visioner/labels/dependencies',
#       'name': 'dependencies',
#       'color': '0366d6',
#       'default': False,
#       'description': 'Pull requests that update a dependency file'}],
#     'milestone': None,
#     'draft': False,
#     'commits_url': 'https://api.github.com/repos/tvanier/sport-visioner/pulls/174/commits',
#     'review_comments_url': 'https://api.github.com/repos/tvanier/sport-visioner/pulls/174/comments',
#     'review_comment_url': 'https://api.github.com/repos/tvanier/sport-visioner/pulls/comments{/number}',
#     'comments_url': 'https://api.github.com/repos/tvanier/sport-visioner/issues/174/comments',
#     'statuses_url': 'https://api.github.com/repos/tvanier/sport-visioner/statuses/dfa8ab7b8cb06ba2e08c06af029e0ff446462673',
#     'head': {'label': 'tvanier:dependabot/npm_and_yarn/babel/preset-env-7.16.4',
#      'ref': 'dependabot/npm_and_yarn/babel/preset-env-7.16.4',
#      'sha': 'dfa8ab7b8cb06ba2e08c06af029e0ff446462673',
#      'user': {'login': 'tvanier',
#       'id': 205231,
#       'node_id': 'MDQ6VXNlcjIwNTIzMQ==',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/205231?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/tvanier',
#       'html_url': 'https://github.com/tvanier',
#       'followers_url': 'https://api.github.com/users/tvanier/followers',
#       'following_url': 'https://api.github.com/users/tvanier/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/tvanier/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/tvanier/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/tvanier/subscriptions',
#       'organizations_url': 'https://api.github.com/users/tvanier/orgs',
#       'repos_url': 'https://api.github.com/users/tvanier/repos',
#       'events_url': 'https://api.github.com/users/tvanier/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/tvanier/received_events',
#       'type': 'User',
#       'site_admin': False},
#      'repo': {'id': 336891826,
#       'node_id': 'MDEwOlJlcG9zaXRvcnkzMzY4OTE4MjY=',
#       'name': 'sport-visioner',
#       'full_name': 'tvanier/sport-visioner',
#       'private': False,
#       'owner': {'login': 'tvanier',
#        'id': 205231,
#        'node_id': 'MDQ6VXNlcjIwNTIzMQ==',
#        'avatar_url': 'https://avatars.githubusercontent.com/u/205231?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/tvanier',
#        'html_url': 'https://github.com/tvanier',
#        'followers_url': 'https://api.github.com/users/tvanier/followers',
#        'following_url': 'https://api.github.com/users/tvanier/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/tvanier/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/tvanier/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/tvanier/subscriptions',
#        'organizations_url': 'https://api.github.com/users/tvanier/orgs',
#        'repos_url': 'https://api.github.com/users/tvanier/repos',
#        'events_url': 'https://api.github.com/users/tvanier/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/tvanier/received_events',
#        'type': 'User',
#        'site_admin': False},
#       'html_url': 'https://github.com/tvanier/sport-visioner',
#       'description': 'A sample app based on the Sport Vision API',
#       'fork': False,
#       'url': 'https://api.github.com/repos/tvanier/sport-visioner',
#       'forks_url': 'https://api.github.com/repos/tvanier/sport-visioner/forks',
#       'keys_url': 'https://api.github.com/repos/tvanier/sport-visioner/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/tvanier/sport-visioner/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/tvanier/sport-visioner/teams',
#       'hooks_url': 'https://api.github.com/repos/tvanier/sport-visioner/hooks',
#       'issue_events_url': 'https://api.github.com/repos/tvanier/sport-visioner/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/tvanier/sport-visioner/events',
#       'assignees_url': 'https://api.github.com/repos/tvanier/sport-visioner/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/tvanier/sport-visioner/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/tvanier/sport-visioner/tags',
#       'blobs_url': 'https://api.github.com/repos/tvanier/sport-visioner/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/tvanier/sport-visioner/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/tvanier/sport-visioner/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/tvanier/sport-visioner/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/tvanier/sport-visioner/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/tvanier/sport-visioner/languages',
#       'stargazers_url': 'https://api.github.com/repos/tvanier/sport-visioner/stargazers',
#       'contributors_url': 'https://api.github.com/repos/tvanier/sport-visioner/contributors',
#       'subscribers_url': 'https://api.github.com/repos/tvanier/sport-visioner/subscribers',
#       'subscription_url': 'https://api.github.com/repos/tvanier/sport-visioner/subscription',
#       'commits_url': 'https://api.github.com/repos/tvanier/sport-visioner/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/tvanier/sport-visioner/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/tvanier/sport-visioner/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/tvanier/sport-visioner/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/tvanier/sport-visioner/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/tvanier/sport-visioner/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/tvanier/sport-visioner/merges',
#       'archive_url': 'https://api.github.com/repos/tvanier/sport-visioner/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/tvanier/sport-visioner/downloads',
#       'issues_url': 'https://api.github.com/repos/tvanier/sport-visioner/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/tvanier/sport-visioner/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/tvanier/sport-visioner/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/tvanier/sport-visioner/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/tvanier/sport-visioner/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/tvanier/sport-visioner/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/tvanier/sport-visioner/deployments',
#       'created_at': '2021-02-07T21:17:37Z',
#       'updated_at': '2021-11-15T19:04:51Z',
#       'pushed_at': '2021-11-23T09:55:56Z',
#       'git_url': 'git://github.com/tvanier/sport-visioner.git',
#       'ssh_url': 'git@github.com:tvanier/sport-visioner.git',
#       'clone_url': 'https://github.com/tvanier/sport-visioner.git',
#       'svn_url': 'https://github.com/tvanier/sport-visioner',
#       'homepage': 'https://tvanier.netlify.app/sport-visioner/',
#       'size': 7674,
#       'stargazers_count': 0,
#       'watchers_count': 0,
#       'language': 'Svelte',
#       'has_issues': True,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'forks_count': 0,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 4,
#       'license': {'key': 'mit',
#        'name': 'MIT License',
#        'spdx_id': 'MIT',
#        'url': 'https://api.github.com/licenses/mit',
#        'node_id': 'MDc6TGljZW5zZTEz'},
#       'allow_forking': True,
#       'is_template': False,
#       'topics': ['decathlon', 'esm', 'vite'],
#       'visibility': 'public',
#       'forks': 0,
#       'open_issues': 4,
#       'watchers': 0,
#       'default_branch': 'main'}},
#     'base': {'label': 'tvanier:main',
#      'ref': 'main',
#      'sha': '90b5c382da02212d15b412610038d448700619c7',
#      'user': {'login': 'tvanier',
#       'id': 205231,
#       'node_id': 'MDQ6VXNlcjIwNTIzMQ==',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/205231?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/tvanier',
#       'html_url': 'https://github.com/tvanier',
#       'followers_url': 'https://api.github.com/users/tvanier/followers',
#       'following_url': 'https://api.github.com/users/tvanier/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/tvanier/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/tvanier/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/tvanier/subscriptions',
#       'organizations_url': 'https://api.github.com/users/tvanier/orgs',
#       'repos_url': 'https://api.github.com/users/tvanier/repos',
#       'events_url': 'https://api.github.com/users/tvanier/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/tvanier/received_events',
#       'type': 'User',
#       'site_admin': False},
#      'repo': {'id': 336891826,
#       'node_id': 'MDEwOlJlcG9zaXRvcnkzMzY4OTE4MjY=',
#       'name': 'sport-visioner',
#       'full_name': 'tvanier/sport-visioner',
#       'private': False,
#       'owner': {'login': 'tvanier',
#        'id': 205231,
#        'node_id': 'MDQ6VXNlcjIwNTIzMQ==',
#        'avatar_url': 'https://avatars.githubusercontent.com/u/205231?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/tvanier',
#        'html_url': 'https://github.com/tvanier',
#        'followers_url': 'https://api.github.com/users/tvanier/followers',
#        'following_url': 'https://api.github.com/users/tvanier/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/tvanier/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/tvanier/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/tvanier/subscriptions',
#        'organizations_url': 'https://api.github.com/users/tvanier/orgs',
#        'repos_url': 'https://api.github.com/users/tvanier/repos',
#        'events_url': 'https://api.github.com/users/tvanier/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/tvanier/received_events',
#        'type': 'User',
#        'site_admin': False},
#       'html_url': 'https://github.com/tvanier/sport-visioner',
#       'description': 'A sample app based on the Sport Vision API',
#       'fork': False,
#       'url': 'https://api.github.com/repos/tvanier/sport-visioner',
#       'forks_url': 'https://api.github.com/repos/tvanier/sport-visioner/forks',
#       'keys_url': 'https://api.github.com/repos/tvanier/sport-visioner/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/tvanier/sport-visioner/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/tvanier/sport-visioner/teams',
#       'hooks_url': 'https://api.github.com/repos/tvanier/sport-visioner/hooks',
#       'issue_events_url': 'https://api.github.com/repos/tvanier/sport-visioner/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/tvanier/sport-visioner/events',
#       'assignees_url': 'https://api.github.com/repos/tvanier/sport-visioner/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/tvanier/sport-visioner/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/tvanier/sport-visioner/tags',
#       'blobs_url': 'https://api.github.com/repos/tvanier/sport-visioner/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/tvanier/sport-visioner/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/tvanier/sport-visioner/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/tvanier/sport-visioner/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/tvanier/sport-visioner/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/tvanier/sport-visioner/languages',
#       'stargazers_url': 'https://api.github.com/repos/tvanier/sport-visioner/stargazers',
#       'contributors_url': 'https://api.github.com/repos/tvanier/sport-visioner/contributors',
#       'subscribers_url': 'https://api.github.com/repos/tvanier/sport-visioner/subscribers',
#       'subscription_url': 'https://api.github.com/repos/tvanier/sport-visioner/subscription',
#       'commits_url': 'https://api.github.com/repos/tvanier/sport-visioner/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/tvanier/sport-visioner/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/tvanier/sport-visioner/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/tvanier/sport-visioner/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/tvanier/sport-visioner/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/tvanier/sport-visioner/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/tvanier/sport-visioner/merges',
#       'archive_url': 'https://api.github.com/repos/tvanier/sport-visioner/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/tvanier/sport-visioner/downloads',
#       'issues_url': 'https://api.github.com/repos/tvanier/sport-visioner/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/tvanier/sport-visioner/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/tvanier/sport-visioner/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/tvanier/sport-visioner/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/tvanier/sport-visioner/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/tvanier/sport-visioner/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/tvanier/sport-visioner/deployments',
#       'created_at': '2021-02-07T21:17:37Z',
#       'updated_at': '2021-11-15T19:04:51Z',
#       'pushed_at': '2021-11-23T09:55:56Z',
#       'git_url': 'git://github.com/tvanier/sport-visioner.git',
#       'ssh_url': 'git@github.com:tvanier/sport-visioner.git',
#       'clone_url': 'https://github.com/tvanier/sport-visioner.git',
#       'svn_url': 'https://github.com/tvanier/sport-visioner',
#       'homepage': 'https://tvanier.netlify.app/sport-visioner/',
#       'size': 7674,
#       'stargazers_count': 0,
#       'watchers_count': 0,
#       'language': 'Svelte',
#       'has_issues': True,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'forks_count': 0,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 4,
#       'license': {'key': 'mit',
#        'name': 'MIT License',
#        'spdx_id': 'MIT',
#        'url': 'https://api.github.com/licenses/mit',
#        'node_id': 'MDc6TGljZW5zZTEz'},
#       'allow_forking': True,
#       'is_template': False,
#       'topics': ['decathlon', 'esm', 'vite'],
#       'visibility': 'public',
#       'forks': 0,
#       'open_issues': 4,
#       'watchers': 0,
#       'default_branch': 'main'}},
#     '_links': {'self': {'href': 'https://api.github.com/repos/tvanier/sport-visioner/pulls/174'},
#      'html': {'href': 'https://github.com/tvanier/sport-visioner/pull/174'},
#      'issue': {'href': 'https://api.github.com/repos/tvanier/sport-visioner/issues/174'},
#      'comments': {'href': 'https://api.github.com/repos/tvanier/sport-visioner/issues/174/comments'},
#      'review_comments': {'href': 'https://api.github.com/repos/tvanier/sport-visioner/pulls/174/comments'},
#      'review_comment': {'href': 'https://api.github.com/repos/tvanier/sport-visioner/pulls/comments{/number}'},
#      'commits': {'href': 'https://api.github.com/repos/tvanier/sport-visioner/pulls/174/commits'},
#      'statuses': {'href': 'https://api.github.com/repos/tvanier/sport-visioner/statuses/dfa8ab7b8cb06ba2e08c06af029e0ff446462673'}},
#     'author_association': 'CONTRIBUTOR',
#     'auto_merge': None,
#     'active_lock_reason': None,
#     'merged': True,
#     'mergeable': None,
#     'rebaseable': None,
#     'mergeable_state': 'unknown',
#     'merged_by': {'login': 'tvanier',
#      'id': 205231,
#      'node_id': 'MDQ6VXNlcjIwNTIzMQ==',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/205231?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/tvanier',
#      'html_url': 'https://github.com/tvanier',
#      'followers_url': 'https://api.github.com/users/tvanier/followers',
#      'following_url': 'https://api.github.com/users/tvanier/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/tvanier/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/tvanier/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/tvanier/subscriptions',
#      'organizations_url': 'https://api.github.com/users/tvanier/orgs',
#      'repos_url': 'https://api.github.com/users/tvanier/repos',
#      'events_url': 'https://api.github.com/users/tvanier/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/tvanier/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'comments': 0,
#     'review_comments': 0,
#     'maintainer_can_modify': False,
#     'commits': 1,
#     'additions': 170,
#     'deletions': 108,
#     'changed_files': 2}},
#   'public': True,
#   'created_at': '2021-11-23T09:55:56Z'},
#  {'id': '19011607522',
#   'type': 'CreateEvent',
#   'actor': {'id': 94898847,
#    'login': 'Kairileen',
#    'display_login': 'Kairileen',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Kairileen',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/94898847?'},
#   'repo': {'id': 431040252,
#    'name': 'Kairileen/Code',
#    'url': 'https://api.github.com/repos/Kairileen/Code'},
#   'payload': {'ref': 'master',
#    'ref_type': 'branch',
#    'master_branch': 'master',
#    'description': None,
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2021-11-23T09:55:56Z'},
#  {'id': '19011607481',
#   'type': 'PushEvent',
#   'actor': {'id': 92996093,
#    'login': 'denizkr',
#    'display_login': 'denizkr',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/denizkr',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/92996093?'},
#   'repo': {'id': 431011169,
#    'name': 'denizkr/gb-python7',
#    'url': 'https://api.github.com/repos/denizkr/gb-python7'},
#   'payload': {'push_id': 8451849561,
#    'size': 0,
#    'distinct_size': 0,
#    'ref': 'refs/heads/gb-python7',
#    'head': '8a32b3aed000accd513b9bafb258828b600a5903',
#    'before': '8a32b3aed000accd513b9bafb258828b600a5903',
#    'commits': []},
#   'public': True,
#   'created_at': '2021-11-23T09:55:56Z'},
#  {'id': '19011607478',
#   'type': 'PushEvent',
#   'actor': {'id': 63054031,
#    'login': 'stackbit-projects',
#    'display_login': 'stackbit-projects',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/stackbit-projects',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/63054031?'},
#   'repo': {'id': 431039000,
#    'name': 'stackbit-projects/unique-pluto-cb544',
#    'url': 'https://api.github.com/repos/stackbit-projects/unique-pluto-cb544'},
#   'payload': {'push_id': 8451849576,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/preview',
#    'head': '021ab14b38eb02180c86d842c841b745c4165703',
#    'before': 'b520261bd89b17e6dbf1d6ff2e01bb4ab08561fe',
#    'commits': [{'sha': '021ab14b38eb02180c86d842c841b745c4165703',
#      'author': {'email': 'stackbittest@gmail.com', 'name': 'stackbitAutotest'},
#      'message': 'style.json: updated complementary',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/stackbit-projects/unique-pluto-cb544/commits/021ab14b38eb02180c86d842c841b745c4165703'}]},
#   'public': True,
#   'created_at': '2021-11-23T09:55:56Z'},
#  {'id': '19011607431',
#   'type': 'ReleaseEvent',
#   'actor': {'id': 41898282,
#    'login': 'github-actions[bot]',
#    'display_login': 'github-actions',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/github-actions[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/41898282?'},
#   'repo': {'id': 235106543,
#    'name': 'microsoft/react-native-test-app',
#    'url': 'https://api.github.com/repos/microsoft/react-native-test-app'},
#   'payload': {'action': 'published',
#    'release': {'url': 'https://api.github.com/repos/microsoft/react-native-test-app/releases/53901041',
#     'assets_url': 'https://api.github.com/repos/microsoft/react-native-test-app/releases/53901041/assets',
#     'upload_url': 'https://uploads.github.com/repos/microsoft/react-native-test-app/releases/53901041/assets{?name,label}',
#     'html_url': 'https://github.com/microsoft/react-native-test-app/releases/tag/0.9.15',
#     'id': 53901041,
#     'author': {'login': 'github-actions[bot]',
#      'id': 41898282,
#      'node_id': 'MDM6Qm90NDE4OTgyODI=',
#      'avatar_url': 'https://avatars.githubusercontent.com/in/15368?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/github-actions%5Bbot%5D',
#      'html_url': 'https://github.com/apps/github-actions',
#      'followers_url': 'https://api.github.com/users/github-actions%5Bbot%5D/followers',
#      'following_url': 'https://api.github.com/users/github-actions%5Bbot%5D/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/github-actions%5Bbot%5D/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/github-actions%5Bbot%5D/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/github-actions%5Bbot%5D/subscriptions',
#      'organizations_url': 'https://api.github.com/users/github-actions%5Bbot%5D/orgs',
#      'repos_url': 'https://api.github.com/users/github-actions%5Bbot%5D/repos',
#      'events_url': 'https://api.github.com/users/github-actions%5Bbot%5D/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/github-actions%5Bbot%5D/received_events',
#      'type': 'Bot',
#      'site_admin': False},
#     'node_id': 'RE_kwDODgNw784DNnbx',
#     'tag_name': '0.9.15',
#     'target_commitish': 'trunk',
#     'name': '0.9.15',
#     'draft': False,
#     'prerelease': False,
#     'created_at': '2021-11-23T09:35:29Z',
#     'published_at': '2021-11-23T09:55:56Z',
#     'assets': [],
#     'tarball_url': 'https://api.github.com/repos/microsoft/react-native-test-app/tarball/0.9.15',
#     'zipball_url': 'https://api.github.com/repos/microsoft/react-native-test-app/zipball/0.9.15',
#     'body': '## [0.9.15](https://github.com/microsoft/react-native-test-app/compare/0.9.14...0.9.15) (2021-11-23)\n\n\n### Bug Fixes\n\n* **android:** additional config to better support Kotlin modules ([#605](https://github.com/microsoft/react-native-test-app/issues/605)) ([21d34d7](https://github.com/microsoft/react-native-test-app/commit/21d34d7dbdb19f0dfd743fd7733ef95c0514da2a))\n\n\n\n',
#     'short_description_html': '<h2>\n<a href="https://github.com/microsoft/react-native-test-app/compare/0.9.14...0.9.15">0.9.15</a> (2021-11-23)</h2>\n<h3>Bug Fixes</h3>\n<ul>\n<li>\n<strong>android:</strong> additional config to better support Kotlin modules (<a href="https://github.com/microsoft/react-native-test-app/issues/605" data-hovercard-type="pull_request" data-hovercard-url="/microsoft/react-native-test-app/pull/605/hovercard">#605</a>) (<a href="https://github.com/microsoft/react-native-test-app/commit/21d34d7dbdb19f0dfd743fd7733ef95c0514da2a">21d34d7</a>)</li>\n</ul>',
#     'is_short_description_html_truncated': False}},
#   'public': True,
#   'created_at': '2021-11-23T09:55:56Z',
#   'org': {'id': 6154722,
#    'login': 'microsoft',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/microsoft',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/6154722?'}},
#  {'id': '19011607470',
#   'type': 'CreateEvent',
#   'actor': {'id': 37951488,
#    'login': '745184532',
#    'display_login': '745184532',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/745184532',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/37951488?'},
#   'repo': {'id': 431045403,
#    'name': '745184532/seafile',
#    'url': 'https://api.github.com/repos/745184532/seafile'},
#   'payload': {'ref': '5.1',
#    'ref_type': 'branch',
#    'master_branch': 'master',
#    'description': '团队协作',
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2021-11-23T09:55:56Z'},
#  {'id': '19011607486',
#   'type': 'ForkEvent',
#   'actor': {'id': 30213558,
#    'login': 'victory460',
#    'display_login': 'victory460',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/victory460',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/30213558?'},
#   'repo': {'id': 241576270,
#    'name': 'labuladong/fucking-algorithm',
#    'url': 'https://api.github.com/repos/labuladong/fucking-algorithm'},
#   'payload': {'forkee': {'id': 431046195,
#     'node_id': 'R_kgDOGbE-Mw',
#     'name': 'fucking-algorithm',
#     'full_name': 'victory460/fucking-algorithm',
#     'private': False,
#     'owner': {'login': 'victory460',
#      'id': 30213558,
#      'node_id': 'MDQ6VXNlcjMwMjEzNTU4',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/30213558?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/victory460',
#      'html_url': 'https://github.com/victory460',
#      'followers_url': 'https://api.github.com/users/victory460/followers',
#      'following_url': 'https://api.github.com/users/victory460/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/victory460/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/victory460/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/victory460/subscriptions',
#      'organizations_url': 'https://api.github.com/users/victory460/orgs',
#      'repos_url': 'https://api.github.com/users/victory460/repos',
#      'events_url': 'https://api.github.com/users/victory460/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/victory460/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'html_url': 'https://github.com/victory460/fucking-algorithm',
#     'description': '刷算法全靠套路，认准 labuladong 就够了！English version supported! Crack LeetCode, not only how, but also why. ',
#     'fork': True,
#     'url': 'https://api.github.com/repos/victory460/fucking-algorithm',
#     'forks_url': 'https://api.github.com/repos/victory460/fucking-algorithm/forks',
#     'keys_url': 'https://api.github.com/repos/victory460/fucking-algorithm/keys{/key_id}',
#     'collaborators_url': 'https://api.github.com/repos/victory460/fucking-algorithm/collaborators{/collaborator}',
#     'teams_url': 'https://api.github.com/repos/victory460/fucking-algorithm/teams',
#     'hooks_url': 'https://api.github.com/repos/victory460/fucking-algorithm/hooks',
#     'issue_events_url': 'https://api.github.com/repos/victory460/fucking-algorithm/issues/events{/number}',
#     'events_url': 'https://api.github.com/repos/victory460/fucking-algorithm/events',
#     'assignees_url': 'https://api.github.com/repos/victory460/fucking-algorithm/assignees{/user}',
#     'branches_url': 'https://api.github.com/repos/victory460/fucking-algorithm/branches{/branch}',
#     'tags_url': 'https://api.github.com/repos/victory460/fucking-algorithm/tags',
#     'blobs_url': 'https://api.github.com/repos/victory460/fucking-algorithm/git/blobs{/sha}',
#     'git_tags_url': 'https://api.github.com/repos/victory460/fucking-algorithm/git/tags{/sha}',
#     'git_refs_url': 'https://api.github.com/repos/victory460/fucking-algorithm/git/refs{/sha}',
#     'trees_url': 'https://api.github.com/repos/victory460/fucking-algorithm/git/trees{/sha}',
#     'statuses_url': 'https://api.github.com/repos/victory460/fucking-algorithm/statuses/{sha}',
#     'languages_url': 'https://api.github.com/repos/victory460/fucking-algorithm/languages',
#     'stargazers_url': 'https://api.github.com/repos/victory460/fucking-algorithm/stargazers',
#     'contributors_url': 'https://api.github.com/repos/victory460/fucking-algorithm/contributors',
#     'subscribers_url': 'https://api.github.com/repos/victory460/fucking-algorithm/subscribers',
#     'subscription_url': 'https://api.github.com/repos/victory460/fucking-algorithm/subscription',
#     'commits_url': 'https://api.github.com/repos/victory460/fucking-algorithm/commits{/sha}',
#     'git_commits_url': 'https://api.github.com/repos/victory460/fucking-algorithm/git/commits{/sha}',
#     'comments_url': 'https://api.github.com/repos/victory460/fucking-algorithm/comments{/number}',
#     'issue_comment_url': 'https://api.github.com/repos/victory460/fucking-algorithm/issues/comments{/number}',
#     'contents_url': 'https://api.github.com/repos/victory460/fucking-algorithm/contents/{+path}',
#     'compare_url': 'https://api.github.com/repos/victory460/fucking-algorithm/compare/{base}...{head}',
#     'merges_url': 'https://api.github.com/repos/victory460/fucking-algorithm/merges',
#     'archive_url': 'https://api.github.com/repos/victory460/fucking-algorithm/{archive_format}{/ref}',
#     'downloads_url': 'https://api.github.com/repos/victory460/fucking-algorithm/downloads',
#     'issues_url': 'https://api.github.com/repos/victory460/fucking-algorithm/issues{/number}',
#     'pulls_url': 'https://api.github.com/repos/victory460/fucking-algorithm/pulls{/number}',
#     'milestones_url': 'https://api.github.com/repos/victory460/fucking-algorithm/milestones{/number}',
#     'notifications_url': 'https://api.github.com/repos/victory460/fucking-algorithm/notifications{?since,all,participating}',
#     'labels_url': 'https://api.github.com/repos/victory460/fucking-algorithm/labels{/name}',
#     'releases_url': 'https://api.github.com/repos/victory460/fucking-algorithm/releases{/id}',
#     'deployments_url': 'https://api.github.com/repos/victory460/fucking-algorithm/deployments',
#     'created_at': '2021-11-23T09:55:56Z',
#     'updated_at': '2021-11-23T09:17:55Z',
#     'pushed_at': '2021-11-22T05:02:26Z',
#     'git_url': 'git://github.com/victory460/fucking-algorithm.git',
#     'ssh_url': 'git@github.com:victory460/fucking-algorithm.git',
#     'clone_url': 'https://github.com/victory460/fucking-algorithm.git',
#     'svn_url': 'https://github.com/victory460/fucking-algorithm',
#     'homepage': 'https://labuladong.gitee.io/algo/',
#     'size': 109849,
#     'stargazers_count': 0,
#     'watchers_count': 0,
#     'language': None,
#     'has_issues': False,
#     'has_projects': True,
#     'has_downloads': True,
#     'has_wiki': True,
#     'has_pages': False,
#     'forks_count': 0,
#     'mirror_url': None,
#     'archived': False,
#     'disabled': False,
#     'open_issues_count': 0,
#     'license': None,
#     'allow_forking': True,
# ...
#       'collaborators_url': 'https://api.github.com/repos/Componolit/RecordFlux-parser/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/Componolit/RecordFlux-parser/teams',
#       'hooks_url': 'https://api.github.com/repos/Componolit/RecordFlux-parser/hooks',
#       'issue_events_url': 'https://api.github.com/repos/Componolit/RecordFlux-parser/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/Componolit/RecordFlux-parser/events',
#       'assignees_url': 'https://api.github.com/repos/Componolit/RecordFlux-parser/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/Componolit/RecordFlux-parser/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/Componolit/RecordFlux-parser/tags',
#       'blobs_url': 'https://api.github.com/repos/Componolit/RecordFlux-parser/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/Componolit/RecordFlux-parser/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/Componolit/RecordFlux-parser/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/Componolit/RecordFlux-parser/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/Componolit/RecordFlux-parser/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/Componolit/RecordFlux-parser/languages',
#       'stargazers_url': 'https://api.github.com/repos/Componolit/RecordFlux-parser/stargazers',
#       'contributors_url': 'https://api.github.com/repos/Componolit/RecordFlux-parser/contributors',
#       'subscribers_url': 'https://api.github.com/repos/Componolit/RecordFlux-parser/subscribers',
#       'subscription_url': 'https://api.github.com/repos/Componolit/RecordFlux-parser/subscription',
#       'commits_url': 'https://api.github.com/repos/Componolit/RecordFlux-parser/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/Componolit/RecordFlux-parser/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/Componolit/RecordFlux-parser/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/Componolit/RecordFlux-parser/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/Componolit/RecordFlux-parser/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/Componolit/RecordFlux-parser/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/Componolit/RecordFlux-parser/merges',
#       'archive_url': 'https://api.github.com/repos/Componolit/RecordFlux-parser/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/Componolit/RecordFlux-parser/downloads',
#       'issues_url': 'https://api.github.com/repos/Componolit/RecordFlux-parser/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/Componolit/RecordFlux-parser/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/Componolit/RecordFlux-parser/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/Componolit/RecordFlux-parser/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/Componolit/RecordFlux-parser/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/Componolit/RecordFlux-parser/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/Componolit/RecordFlux-parser/deployments',
#       'created_at': '2020-10-23T20:20:25Z',
#       'updated_at': '2021-11-10T08:47:51Z',
#       'pushed_at': '2021-11-19T15:25:18Z',
#       'git_url': 'git://github.com/Componolit/RecordFlux-parser.git',
#       'ssh_url': 'git@github.com:Componolit/RecordFlux-parser.git',
#       'clone_url': 'https://github.com/Componolit/RecordFlux-parser.git',
#       'svn_url': 'https://github.com/Componolit/RecordFlux-parser',
#       'homepage': None,
#       'size': 462,
#       'stargazers_count': 2,
#       'watchers_count': 2,
#       'language': 'Python',
#       'has_issues': True,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': False,
#       'has_pages': False,
#       'forks_count': 0,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 5,
#       'license': {'key': 'agpl-3.0',
#        'name': 'GNU Affero General Public License v3.0',
#        'spdx_id': 'AGPL-3.0',
#        'url': 'https://api.github.com/licenses/agpl-3.0',
#        'node_id': 'MDc6TGljZW5zZTE='},
#       'allow_forking': True,
#       'is_template': False,
#       'topics': [],
#       'visibility': 'public',
#       'forks': 0,
#       'open_issues': 5,
#       'watchers': 2,
#       'default_branch': 'main'}},
#     '_links': {'self': {'href': 'https://api.github.com/repos/Componolit/RecordFlux-parser/pulls/52'},
#      'html': {'href': 'https://github.com/Componolit/RecordFlux-parser/pull/52'},
#      'issue': {'href': 'https://api.github.com/repos/Componolit/RecordFlux-parser/issues/52'},
#      'comments': {'href': 'https://api.github.com/repos/Componolit/RecordFlux-parser/issues/52/comments'},
#      'review_comments': {'href': 'https://api.github.com/repos/Componolit/RecordFlux-parser/pulls/52/comments'},
#      'review_comment': {'href': 'https://api.github.com/repos/Componolit/RecordFlux-parser/pulls/comments{/number}'},
#      'commits': {'href': 'https://api.github.com/repos/Componolit/RecordFlux-parser/pulls/52/commits'},
#      'statuses': {'href': 'https://api.github.com/repos/Componolit/RecordFlux-parser/statuses/a643d03ec3731347269e03d7456c8b5e8788314a'}},
#     'author_association': 'MEMBER',
#     'auto_merge': None,
#     'active_lock_reason': None}},
#   'public': True,
#   'created_at': '2021-11-23T09:55:56Z',
#   'org': {'id': 27442500,
#    'login': 'Componolit',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/Componolit',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/27442500?'}},
#  {'id': '19011607423',
#   'type': 'CreateEvent',
#   'actor': {'id': 71175495,
#    'login': 'tayalholding',
#    'display_login': 'tayalholding',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/tayalholding',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/71175495?'},
#   'repo': {'id': 431046186,
#    'name': 'Part-Time-Investing/PartTimeInvesting.github.io',
#    'url': 'https://api.github.com/repos/Part-Time-Investing/PartTimeInvesting.github.io'},
#   'payload': {'ref': 'main',
#    'ref_type': 'branch',
#    'master_branch': 'main',
#    'description': None,
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2021-11-23T09:55:56Z',
#   'org': {'id': 94899875,
#    'login': 'Part-Time-Investing',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/Part-Time-Investing',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/94899875?'}},
#  {'id': '19011607359',
#   'type': 'PushEvent',
#   'actor': {'id': 87541280,
#    'login': 'WolseyBankWitness',
#    'display_login': 'WolseyBankWitness',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/WolseyBankWitness',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/87541280?'},
#   'repo': {'id': 411743137,
#    'name': 'WolseyBankWitness/mhutchinson-distributor',
#    'url': 'https://api.github.com/repos/WolseyBankWitness/mhutchinson-distributor'},
#   'payload': {'push_id': 8451849482,
#    'size': 4,
#    'distinct_size': 0,
#    'ref': 'refs/heads/witness_wolsey-bank-alfred_github_com_AlCutter_serverless-test_log',
#    'head': '37ae8973437404eb419e3ebf137aaf5624bd9177',
#    'before': 'd20364768d89b8c6f21191189a91e6edc114d7c8',
#    'commits': [{'sha': '874135bb14ffeeeef808d3b520f054e8a37477ee',
#      'author': {'email': '87541280+WolseyBankWitness@users.noreply.github.com',
#       'name': 'Wolsey Bank Witness'},
#      'message': 'Witness checkpoint@881525',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/WolseyBankWitness/mhutchinson-distributor/commits/874135bb14ffeeeef808d3b520f054e8a37477ee'},
#     {'sha': 'db4cfda51d7010cfc4030c8c860355f2d7e832b6',
#      'author': {'email': 'actions@github.com', 'name': 'Serverless Bot'},
#      'message': 'Automatically merge witness signatures',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/WolseyBankWitness/mhutchinson-distributor/commits/db4cfda51d7010cfc4030c8c860355f2d7e832b6'},
#     {'sha': '40af4a93c9374347fe466d1367dcd046bcecee1e',
#      'author': {'email': 'mhutchinson@gmail.com', 'name': 'Martin Hutchinson'},
#      'message': 'Witness checkpoint@8073188',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/WolseyBankWitness/mhutchinson-distributor/commits/40af4a93c9374347fe466d1367dcd046bcecee1e'},
#     {'sha': '37ae8973437404eb419e3ebf137aaf5624bd9177',
#      'author': {'email': 'mhutchinson@gmail.com', 'name': 'Martin Hutchinson'},
#      'message': 'Witness checkpoint@881525',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/WolseyBankWitness/mhutchinson-distributor/commits/37ae8973437404eb419e3ebf137aaf5624bd9177'}]},
#   'public': True,
#   'created_at': '2021-11-23T09:55:56Z'},
#  {'id': '19011607386',
#   'type': 'PushEvent',
#   'actor': {'id': 88928058,
#    'login': 'ClementBLV',
#    'display_login': 'ClementBLV',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/ClementBLV',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/88928058?'},
#   'repo': {'id': 418910125,
#    'name': 'ClementBLV/oppia',
#    'url': 'https://api.github.com/repos/ClementBLV/oppia'},
#   'payload': {'push_id': 8451849522,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/mypy-annotation-3-files',
#    'head': '5aa66cd044c5babbe0320f0ec057ba3db0b92b67',
#    'before': '1403d5bc86c41fe605a03dd8db1cbac25f48209c',
#    'commits': [{'sha': '5aa66cd044c5babbe0320f0ec057ba3db0b92b67',
#      'author': {'email': '88928058+ClementBLV@users.noreply.github.com',
#       'name': 'ClementBLV'},
#      'message': 'Add files via upload\n\nCommit add mypy annotations',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/ClementBLV/oppia/commits/5aa66cd044c5babbe0320f0ec057ba3db0b92b67'}]},
#   'public': True,
#   'created_at': '2021-11-23T09:55:56Z'},
#  {'id': '19011607376',
#   'type': 'PushEvent',
#   'actor': {'id': 66836116,
#    'login': 'Mindula-Dilthushan',
#    'display_login': 'Mindula-Dilthushan',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Mindula-Dilthushan',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/66836116?'},
#   'repo': {'id': 331303368,
#    'name': 'Mindula-Dilthushan/Mindula-Dilthushan',
#    'url': 'https://api.github.com/repos/Mindula-Dilthushan/Mindula-Dilthushan'},
#   'payload': {'push_id': 8451849521,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': 'b0b551c55c67ee2abfab07c0418c2d60cf49c4a1',
#    'before': '4ac052def072f0d083e3870cf18b34242a639cd6',
#    'commits': [{'sha': 'b0b551c55c67ee2abfab07c0418c2d60cf49c4a1',
#      'author': {'email': 'minduladilthushan1@gmail.com',
#       'name': 'Mindula-Dilthushan'},
#      'message': 'chart update',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/Mindula-Dilthushan/Mindula-Dilthushan/commits/b0b551c55c67ee2abfab07c0418c2d60cf49c4a1'}]},
#   'public': True,
#   'created_at': '2021-11-23T09:55:56Z'},
#  {'id': '19011607378',
#   'type': 'PushEvent',
#   'actor': {'id': 41898282,
#    'login': 'github-actions[bot]',
#    'display_login': 'github-actions',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/github-actions[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/41898282?'},
#   'repo': {'id': 348589618,
#    'name': 'jackylee1/weibo-daily-hot-search',
#    'url': 'https://api.github.com/repos/jackylee1/weibo-daily-hot-search'},
#   'payload': {'push_id': 8451849510,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': 'f7ba4ba7c266d9ed8b857ac581de51640305f5b0',
#    'before': '69ce25bd7c268552d2c75462934c8ec98535a0f4',
#    'commits': [{'sha': 'f7ba4ba7c266d9ed8b857ac581de51640305f5b0',
#      'author': {'email': 'EMAIL', 'name': 'USER_NAME'},
#      'message': '-update by github action;',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/jackylee1/weibo-daily-hot-search/commits/f7ba4ba7c266d9ed8b857ac581de51640305f5b0'}]},
#   'public': True,
#   'created_at': '2021-11-23T09:55:56Z'},
#  {'id': '19011607384',
#   'type': 'PushEvent',
#   'actor': {'id': 8517910,
#    'login': 'LombiqBot',
#    'display_login': 'LombiqBot',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/LombiqBot',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8517910?'},
#   'repo': {'id': 265094381,
#    'name': 'Lombiq/Testing-Toolbox',
#    'url': 'https://api.github.com/repos/Lombiq/Testing-Toolbox'},
#   'payload': {'push_id': 8451849508,
#    'size': 0,
#    'distinct_size': 0,
#    'ref': 'refs/heads/issue/FINI-431',
#    'head': 'ac67e914a133dc8fd4bdfae17b3c8ea01e3ae3ba',
#    'before': 'ac67e914a133dc8fd4bdfae17b3c8ea01e3ae3ba',
#    'commits': []},
#   'public': True,
#   'created_at': '2021-11-23T09:55:56Z',
#   'org': {'id': 8158177,
#    'login': 'Lombiq',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/Lombiq',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8158177?'}},
#  {'id': '19011607348',
#   'type': 'IssuesEvent',
#   'actor': {'id': 1379068,
#    'login': 'lenormf',
#    'display_login': 'lenormf',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/lenormf',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/1379068?'},
#   'repo': {'id': 311211647,
#    'name': 'fiatjaf/nostr',
#    'url': 'https://api.github.com/repos/fiatjaf/nostr'},
#   'payload': {'action': 'opened',
#    'issue': {'url': 'https://api.github.com/repos/fiatjaf/nostr/issues/30',
#     'repository_url': 'https://api.github.com/repos/fiatjaf/nostr',
#     'labels_url': 'https://api.github.com/repos/fiatjaf/nostr/issues/30/labels{/name}',
#     'comments_url': 'https://api.github.com/repos/fiatjaf/nostr/issues/30/comments',
#     'events_url': 'https://api.github.com/repos/fiatjaf/nostr/issues/30/events',
#     'html_url': 'https://github.com/fiatjaf/nostr/issues/30',
#     'id': 1061037780,
#     'node_id': 'I_kwDOEoy2f84_PibU',
#     'number': 30,
#     'title': '[NIP-01] `NOTICE`s may be redundant with encrypted direct messages (NIP-04)',
#     'user': {'login': 'lenormf',
#      'id': 1379068,
#      'node_id': 'MDQ6VXNlcjEzNzkwNjg=',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/1379068?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/lenormf',
#      'html_url': 'https://github.com/lenormf',
#      'followers_url': 'https://api.github.com/users/lenormf/followers',
#      'following_url': 'https://api.github.com/users/lenormf/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/lenormf/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/lenormf/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/lenormf/subscriptions',
#      'organizations_url': 'https://api.github.com/users/lenormf/orgs',
#      'repos_url': 'https://api.github.com/users/lenormf/repos',
#      'events_url': 'https://api.github.com/users/lenormf/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/lenormf/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'labels': [],
#     'state': 'open',
#     'locked': False,
#     'assignee': None,
#     'assignees': [],
#     'milestone': None,
#     'comments': 0,
#     'created_at': '2021-11-23T09:55:55Z',
#     'updated_at': '2021-11-23T09:55:55Z',
#     'closed_at': None,
#     'author_association': 'NONE',
#     'active_lock_reason': None,
#     'body': 'Notices could be direct messages sent by the relay’s identity.',
#     'reactions': {'url': 'https://api.github.com/repos/fiatjaf/nostr/issues/30/reactions',
#      'total_count': 0,
#      '+1': 0,
#      '-1': 0,
#      'laugh': 0,
#      'hooray': 0,
#      'confused': 0,
#      'heart': 0,
#      'rocket': 0,
#      'eyes': 0},
#     'timeline_url': 'https://api.github.com/repos/fiatjaf/nostr/issues/30/timeline',
#     'performed_via_github_app': None}},
#   'public': True,
#   'created_at': '2021-11-23T09:55:56Z'}]

# %%
from IPython.display import JSON
JSON(response.json())

# %%
len(github_response)
# Out:
# 30

# %%
#login
github_response[3]["actor"]["login"]
# Out:
# 'denizkr'

# %% [markdown]
# ### Exercise:
#
# Extract the "login", the repo name and the event type for each event.

# %%
for resp in github_response[:3]:
    login = resp["actor"]["login"]
    repo_name = resp["repo"]["name"]
    event_type = resp["type"]
    print(login, ' - ', repo_name, ' - ', event_type,'\n')
# Out:
# codecov[bot]  -  studiometa/js-toolkit  -  IssueCommentEvent
#
# tvanier  -  tvanier/sport-visioner  -  PullRequestEvent
#
# Kairileen  -  Kairileen/Code  -  CreateEvent

# %% [markdown]
# ### Intenational Space Station
#
# Send a simple `get` request to know where the ISS is right now.
#
# Docs here: http://open-notify.org/Open-Notify-API/ISS-Location-Now/

# %%
url = "http://api.open-notify.org/iss-now.json"

# %%
response = requests.get(url)

# %%
response.json()
# Out:
# {'iss_position': {'latitude': '31.5721', 'longitude': '-148.8193'},
#  'message': 'success',
#  'timestamp': 1637662188}

# %% [markdown]
# ## Spotipy
#
# Spotify has an API that allows users to gather information about songs and even interact with other users and playlists. To make their usage in Python easier, someone created `spotipy`, a library with some convenient functions to send requests and collect data.
#
# Create / log into an Spotify account (https://developer.spotify.com/dashboard/login) and follow these steps (only the "Register your App" section): https://developer.spotify.com/documentation/general/guides/authorization/app-settings/

# %% [markdown]
# #### Authentification
#
# Follow the wrapper for the API docs: https://spotipy.readthedocs.io/en/2.16.1/

# %%
# !pip install spotipy
# Out:
# Collecting spotipy
#   Downloading spotipy-2.19.0-py3-none-any.whl (27 kB)
# Requirement already satisfied: urllib3>=1.26.0 in /home/donal/anaconda3/lib/python3.8/site-packages (from spotipy) (1.26.7)
# Requirement already satisfied: six>=1.15.0 in /home/donal/anaconda3/lib/python3.8/site-packages (from spotipy) (1.16.0)
# Requirement already satisfied: requests>=2.25.0 in /home/donal/anaconda3/lib/python3.8/site-packages (from spotipy) (2.26.0)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /home/donal/anaconda3/lib/python3.8/site-packages (from requests>=2.25.0->spotipy) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /home/donal/anaconda3/lib/python3.8/site-packages (from requests>=2.25.0->spotipy) (3.2)
# Requirement already satisfied: certifi>=2017.4.17 in /home/donal/anaconda3/lib/python3.8/site-packages (from requests>=2.25.0->spotipy) (2021.10.8)
# Installing collected packages: spotipy
# Successfully installed spotipy-2.19.0

# %%
# import libraries
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

# %%
#Initialize SpotiPy with user credentias
sp = spotipy.Spotify(
    client_credentials_manager=SpotifyClientCredentials(
    client_id="49f6445c89284159816847313b09af34",
    client_secret="3b701fdbaec44b73b5c29901680c3fab"))

# %% [markdown]
# #### Searching songs with 'queries' with `sp.search`
#
# This function allows you to find songs with using Spotify's search engine. That's convenient when you don't have the exact "id" of a song.

# %%
results = sp.search(q="Lady Gaga", limit = 10)

# %% [markdown]
# Explore the object returned by the request. As it's a dictionary (with nested dictionaries inside), using `.keys` is a great way to see what's in there:

# %%
JSON(results)

# %%
results.keys()
# Out:
# dict_keys(['tracks'])

# %%
results["tracks"].keys()
# Out:
# dict_keys(['href', 'items', 'limit', 'next', 'offset', 'previous', 'total'])

# %% [markdown]
# This is the url of your request:

# %%
results["tracks"]["href"]
# Out:
# 'https://api.spotify.com/v1/search?query=Lady+Gaga&type=track&offset=0&limit=10'

# %% [markdown]
# This is the name of the first song returned by the API:

# %%
results["tracks"]["items"][0]["name"]
# Out:
# 'Bad Romance'

# %% [markdown]
# As one song can have many artists, the artists are returned as a list: you know that because the dictionary is wrapped by square brackets.

# %%
results["tracks"]["items"][0]["artists"]
# Out:
# [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1HY2Jd0NmPuamShAr6KMms'},
#   'href': 'https://api.spotify.com/v1/artists/1HY2Jd0NmPuamShAr6KMms',
#   'id': '1HY2Jd0NmPuamShAr6KMms',
#   'name': 'Lady Gaga',
#   'type': 'artist',
#   'uri': 'spotify:artist:1HY2Jd0NmPuamShAr6KMms'}]

# %% [markdown]
# There are some other interesting features:

# %%
results["tracks"]["items"][0]["popularity"]
# Out:
# 81

# %% [markdown]
# This is how Spotify identifies individual songs: with an `uri`. (the `id` and the `url` are also ways to identify uniquely each song).

# %%
results["tracks"]["items"][0]["uri"]
# Out:
# 'spotify:track:0SiywuOBRcynK0uKGWdCnn'

# %% [markdown]
# Here we look for 10 songs by the Red Hot Chilli Peppers and store the `uri` of the songs and their names.

# %%
# send request and store the response
red_hot = sp.search(q="Red hot chili peppers", limit=10)

# initialize empty lists to store stuff later
list_of_uri = []
list_of_song_names = []

# iterate through the "items" (the songs), and append
# the "uri" and the "name" to the lists we created
for item in red_hot["tracks"]["items"]:
    list_of_uri.append(item["uri"])
    list_of_song_names.append(item["name"])

# print results
print(list_of_uri)
print("\n")
print(list_of_song_names)
# Out:
# ['spotify:track:3d9DChrdc6BOeFsbrZ3Is0', 'spotify:track:3xJu5hrOU9OvFQSGLQiwQS', 'spotify:track:1Y6DGcTCuMAtw8KB3h4W3q', 'spotify:track:3ZOEytgrvLwQaqXreDs2Jx', 'spotify:track:0Kojfmpnf0A2yC1zyv39Zx', 'spotify:track:1XxCiPw07rd1ytYnE7SoJI', 'spotify:track:48UPSzbZjgc449aqz8bxox', 'spotify:track:4nRi0PlIpoy9SyySD1IDGY', 'spotify:track:2aibwv5hGXSgw7Yru8IYTO', 'spotify:track:4dzbGvxqQ1DsF6m6RUlPwg']
#
#
# ['Under the Bridge', 'Anthony Kiedis', 'Around the World', "Can't Stop", 'Buried Alive', "Road Trippin'", 'Californication', 'By the Way - Live', 'Snow (Hey Oh)', 'Pedigree']

# %% [markdown]
# #### Searching multiple artists
#
# Here we first create a list of artists we want to gather songs from. Then we iterate through them and append the results into a big list called `results`.

# %%
artists = ["Red hot chili peppers", "SCARR", "Whitney Houston"]

# %%
results = []

for artist in artists:
    results.append(sp.search(q=artist, limit=10))

# %%
results
# Out:
# [{'tracks': {'href': 'https://api.spotify.com/v1/search?query=Red+hot+chili+peppers&type=track&offset=0&limit=10',
#    'items': [{'album': {'album_type': 'album',
#       'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0L8ExT028jH3ddEcZwqJJ5'},
#         'href': 'https://api.spotify.com/v1/artists/0L8ExT028jH3ddEcZwqJJ5',
#         'id': '0L8ExT028jH3ddEcZwqJJ5',
#         'name': 'Red Hot Chili Peppers',
#         'type': 'artist',
#         'uri': 'spotify:artist:0L8ExT028jH3ddEcZwqJJ5'}],
#       'available_markets': ['AD',
#        'AE',
#        'AG',
#        'AL',
#        'AM',
#        'AO',
#        'AR',
#        'AT',
#        'AU',
#        'AZ',
#        'BA',
#        'BB',
#        'BD',
#        'BE',
#        'BF',
#        'BG',
#        'BH',
#        'BI',
#        'BJ',
#        'BN',
#        'BO',
#        'BR',
#        'BS',
#        'BW',
#        'BY',
#        'BZ',
#        'CA',
#        'CD',
#        'CG',
#        'CH',
#        'CI',
#        'CL',
#        'CM',
#        'CO',
#        'CR',
#        'CV',
#        'CW',
#        'CY',
#        'CZ',
#        'DE',
#        'DJ',
#        'DK',
#        'DM',
#        'DO',
#        'DZ',
#        'EC',
#        'EE',
#        'EG',
#        'ES',
#        'FI',
#        'FJ',
#        'FM',
#        'FR',
#        'GA',
#        'GB',
#        'GD',
#        'GH',
#        'GM',
#        'GN',
#        'GQ',
#        'GR',
#        'GT',
#        'GW',
#        'HK',
#        'HN',
#        'HR',
#        'HT',
#        'HU',
#        'ID',
#        'IE',
#        'IL',
#        'IN',
#        'IQ',
#        'IS',
#        'IT',
#        'JM',
#        'JO',
#        'JP',
#        'KE',
#        'KG',
#        'KH',
#        'KM',
#        'KN',
#        'KR',
#        'KW',
#        'KZ',
#        'LA',
#        'LB',
#        'LC',
#        'LI',
#        'LK',
#        'LR',
#        'LS',
#        'LT',
#        'LU',
#        'LV',
#        'LY',
#        'MA',
#        'MC',
#        'MD',
#        'ME',
#        'MG',
#        'MK',
#        'ML',
#        'MN',
#        'MO',
#        'MR',
#        'MT',
#        'MU',
#        'MV',
#        'MW',
#        'MX',
#        'MY',
#        'MZ',
#        'NA',
#        'NE',
#        'NG',
#        'NI',
#        'NL',
#        'NO',
#        'NP',
#        'NZ',
#        'OM',
#        'PA',
#        'PE',
#        'PG',
#        'PH',
#        'PK',
#        'PL',
#        'PS',
#        'PT',
#        'PY',
#        'QA',
#        'RO',
#        'RS',
#        'RU',
#        'RW',
#        'SA',
#        'SC',
#        'SE',
#        'SG',
#        'SI',
#        'SK',
#        'SL',
#        'SM',
#        'SN',
#        'ST',
#        'SV',
#        'SZ',
#        'TD',
#        'TG',
#        'TH',
#        'TJ',
#        'TL',
#        'TN',
#        'TR',
#        'TT',
#        'TW',
#        'TZ',
#        'UA',
#        'UG',
#        'US',
#        'UY',
#        'UZ',
#        'VC',
#        'VE',
#        'VN',
#        'XK',
#        'ZA',
#        'ZM',
#        'ZW'],
#       'external_urls': {'spotify': 'https://open.spotify.com/album/30Perjew8HyGkdSmqguYyg'},
#       'href': 'https://api.spotify.com/v1/albums/30Perjew8HyGkdSmqguYyg',
#       'id': '30Perjew8HyGkdSmqguYyg',
#       'images': [{'height': 640,
#         'url': 'https://i.scdn.co/image/ab67616d0000b273153d79816d853f2694b2cc70',
#         'width': 640},
#        {'height': 300,
#         'url': 'https://i.scdn.co/image/ab67616d00001e02153d79816d853f2694b2cc70',
#         'width': 300},
#        {'height': 64,
#         'url': 'https://i.scdn.co/image/ab67616d00004851153d79816d853f2694b2cc70',
#         'width': 64}],
#       'name': 'Blood Sugar Sex Magik (Deluxe Edition)',
#       'release_date': '1991-09-24',
#       'release_date_precision': 'day',
#       'total_tracks': 19,
#       'type': 'album',
#       'uri': 'spotify:album:30Perjew8HyGkdSmqguYyg'},
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0L8ExT028jH3ddEcZwqJJ5'},
#        'href': 'https://api.spotify.com/v1/artists/0L8ExT028jH3ddEcZwqJJ5',
#        'id': '0L8ExT028jH3ddEcZwqJJ5',
#        'name': 'Red Hot Chili Peppers',
#        'type': 'artist',
#        'uri': 'spotify:artist:0L8ExT028jH3ddEcZwqJJ5'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'RW',
#       'SA',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TR',
#       'TT',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'disc_number': 1,
#      'duration_ms': 264306,
#      'explicit': False,
#      'external_ids': {'isrc': 'USWB19901576'},
#      'external_urls': {'spotify': 'https://open.spotify.com/track/3d9DChrdc6BOeFsbrZ3Is0'},
#      'href': 'https://api.spotify.com/v1/tracks/3d9DChrdc6BOeFsbrZ3Is0',
#      'id': '3d9DChrdc6BOeFsbrZ3Is0',
#      'is_local': False,
#      'name': 'Under the Bridge',
#      'popularity': 81,
#      'preview_url': 'https://p.scdn.co/mp3-preview/90e41778392f27b6f7dd82db4c90916b3727aa6a?cid=49f6445c89284159816847313b09af34',
#      'track_number': 11,
#      'type': 'track',
#      'uri': 'spotify:track:3d9DChrdc6BOeFsbrZ3Is0'},
#     {'album': {'album_type': 'album',
#       'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0NB5HROxc8dDBXpkIi1v3d'},
#         'href': 'https://api.spotify.com/v1/artists/0NB5HROxc8dDBXpkIi1v3d',
#         'id': '0NB5HROxc8dDBXpkIi1v3d',
#         'name': 'Remi Wolf',
#         'type': 'artist',
#         'uri': 'spotify:artist:0NB5HROxc8dDBXpkIi1v3d'}],
#       'available_markets': ['AD',
#        'AE',
#        'AG',
#        'AL',
#        'AM',
#        'AO',
#        'AR',
#        'AT',
#        'AU',
#        'AZ',
#        'BA',
#        'BB',
#        'BD',
#        'BE',
#        'BF',
#        'BG',
#        'BH',
#        'BI',
#        'BJ',
#        'BN',
#        'BO',
#        'BR',
#        'BS',
#        'BT',
#        'BW',
#        'BY',
#        'BZ',
#        'CA',
#        'CD',
#        'CG',
#        'CH',
#        'CI',
#        'CL',
#        'CM',
#        'CO',
#        'CR',
#        'CV',
#        'CW',
#        'CY',
#        'CZ',
#        'DE',
#        'DJ',
#        'DK',
#        'DM',
#        'DO',
#        'DZ',
#        'EC',
#        'EE',
#        'EG',
#        'ES',
#        'FI',
#        'FJ',
#        'FM',
#        'FR',
#        'GA',
#        'GB',
#        'GD',
#        'GE',
#        'GH',
#        'GM',
#        'GN',
#        'GQ',
#        'GR',
#        'GT',
#        'GW',
#        'GY',
#        'HK',
#        'HN',
#        'HR',
#        'HT',
#        'HU',
#        'ID',
#        'IE',
#        'IL',
#        'IN',
#        'IQ',
#        'IS',
#        'IT',
#        'JM',
#        'JO',
#        'JP',
#        'KE',
#        'KG',
#        'KH',
#        'KI',
#        'KM',
#        'KN',
#        'KR',
#        'KW',
#        'KZ',
#        'LA',
#        'LB',
#        'LC',
#        'LI',
#        'LK',
#        'LR',
#        'LS',
#        'LT',
#        'LU',
#        'LV',
#        'LY',
#        'MA',
#        'MC',
#        'MD',
#        'ME',
#        'MG',
#        'MH',
#        'MK',
#        'ML',
#        'MN',
#        'MO',
#        'MR',
#        'MT',
#        'MU',
#        'MV',
#        'MW',
#        'MX',
#        'MY',
#        'MZ',
#        'NA',
#        'NE',
#        'NG',
#        'NI',
#        'NL',
#        'NO',
#        'NP',
#        'NR',
#        'NZ',
#        'OM',
#        'PA',
#        'PE',
#        'PG',
#        'PH',
#        'PK',
#        'PL',
#        'PS',
#        'PT',
#        'PW',
#        'PY',
#        'QA',
#        'RO',
#        'RS',
#        'RU',
#        'RW',
#        'SA',
#        'SB',
#        'SC',
#        'SE',
#        'SG',
#        'SI',
#        'SK',
#        'SL',
#        'SM',
#        'SN',
#        'SR',
#        'ST',
#        'SV',
#        'SZ',
#        'TD',
#        'TG',
#        'TH',
#        'TJ',
#        'TL',
#        'TN',
#        'TO',
#        'TR',
#        'TT',
#        'TV',
#        'TW',
#        'TZ',
#        'UA',
#        'UG',
#        'US',
#        'UY',
#        'UZ',
#        'VC',
#        'VE',
#        'VN',
#        'VU',
#        'WS',
#        'XK',
#        'ZA',
#        'ZM',
#        'ZW'],
#       'external_urls': {'spotify': 'https://open.spotify.com/album/7tJ8Wtej161vR0uCbGDiDR'},
#       'href': 'https://api.spotify.com/v1/albums/7tJ8Wtej161vR0uCbGDiDR',
#       'id': '7tJ8Wtej161vR0uCbGDiDR',
#       'images': [{'height': 640,
#         'url': 'https://i.scdn.co/image/ab67616d0000b27316a6cb93e32bf2ae66b1f5b2',
#         'width': 640},
#        {'height': 300,
#         'url': 'https://i.scdn.co/image/ab67616d00001e0216a6cb93e32bf2ae66b1f5b2',
#         'width': 300},
#        {'height': 64,
#         'url': 'https://i.scdn.co/image/ab67616d0000485116a6cb93e32bf2ae66b1f5b2',
#         'width': 64}],
#       'name': 'Juno',
#       'release_date': '2021-10-15',
#       'release_date_precision': 'day',
#       'total_tracks': 13,
#       'type': 'album',
#       'uri': 'spotify:album:7tJ8Wtej161vR0uCbGDiDR'},
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0NB5HROxc8dDBXpkIi1v3d'},
#        'href': 'https://api.spotify.com/v1/artists/0NB5HROxc8dDBXpkIi1v3d',
#        'id': '0NB5HROxc8dDBXpkIi1v3d',
#        'name': 'Remi Wolf',
#        'type': 'artist',
#        'uri': 'spotify:artist:0NB5HROxc8dDBXpkIi1v3d'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'disc_number': 1,
#      'duration_ms': 171897,
#      'explicit': False,
#      'external_ids': {'isrc': 'USUG12103572'},
#      'external_urls': {'spotify': 'https://open.spotify.com/track/3xJu5hrOU9OvFQSGLQiwQS'},
#      'href': 'https://api.spotify.com/v1/tracks/3xJu5hrOU9OvFQSGLQiwQS',
#      'id': '3xJu5hrOU9OvFQSGLQiwQS',
#      'is_local': False,
#      'name': 'Anthony Kiedis',
#      'popularity': 60,
#      'preview_url': None,
#      'track_number': 2,
#      'type': 'track',
#      'uri': 'spotify:track:3xJu5hrOU9OvFQSGLQiwQS'},
#     {'album': {'album_type': 'album',
#       'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0L8ExT028jH3ddEcZwqJJ5'},
#         'href': 'https://api.spotify.com/v1/artists/0L8ExT028jH3ddEcZwqJJ5',
#         'id': '0L8ExT028jH3ddEcZwqJJ5',
#         'name': 'Red Hot Chili Peppers',
#         'type': 'artist',
#         'uri': 'spotify:artist:0L8ExT028jH3ddEcZwqJJ5'}],
#       'available_markets': ['AD',
#        'AE',
#        'AG',
#        'AL',
#        'AM',
#        'AO',
#        'AR',
#        'AT',
#        'AU',
#        'AZ',
#        'BA',
#        'BB',
#        'BD',
#        'BE',
#        'BF',
#        'BG',
#        'BH',
#        'BI',
#        'BJ',
#        'BN',
#        'BO',
#        'BR',
#        'BS',
#        'BW',
#        'BY',
#        'BZ',
#        'CA',
#        'CD',
#        'CG',
#        'CH',
#        'CI',
#        'CL',
#        'CM',
#        'CO',
#        'CR',
#        'CV',
#        'CW',
#        'CY',
#        'CZ',
#        'DE',
#        'DJ',
#        'DK',
#        'DM',
#        'DO',
#        'DZ',
#        'EC',
#        'EE',
#        'EG',
#        'ES',
#        'FI',
#        'FJ',
#        'FM',
#        'FR',
#        'GA',
#        'GB',
#        'GD',
#        'GH',
#        'GM',
#        'GN',
#        'GQ',
#        'GR',
#        'GT',
#        'GW',
#        'HK',
#        'HN',
#        'HR',
#        'HT',
#        'HU',
#        'ID',
#        'IE',
#        'IL',
#        'IN',
#        'IQ',
#        'IS',
#        'IT',
#        'JM',
#        'JO',
#        'JP',
#        'KE',
#        'KG',
#        'KH',
#        'KM',
#        'KN',
#        'KR',
#        'KW',
#        'KZ',
#        'LA',
#        'LB',
#        'LC',
#        'LK',
#        'LR',
#        'LS',
#        'LT',
#        'LU',
#        'LV',
#        'LY',
#        'MA',
#        'MC',
#        'MD',
#        'ME',
#        'MG',
#        'MK',
#        'ML',
#        'MN',
#        'MO',
#        'MR',
#        'MT',
#        'MU',
#        'MW',
#        'MX',
#        'MY',
#        'MZ',
#        'NA',
#        'NE',
#        'NG',
#        'NI',
#        'NL',
#        'NO',
#        'NP',
#        'NZ',
#        'OM',
#        'PA',
#        'PE',
#        'PG',
#        'PH',
#        'PK',
#        'PL',
#        'PT',
#        'PY',
#        'QA',
#        'RO',
#        'RS',
#        'RU',
#        'RW',
#        'SA',
#        'SC',
#        'SE',
#        'SG',
#        'SI',
#        'SK',
#        'SL',
#        'SM',
#        'SN',
#        'ST',
#        'SV',
#        'SZ',
#        'TD',
#        'TG',
#        'TH',
#        'TJ',
#        'TL',
#        'TN',
#        'TR',
#        'TT',
#        'TW',
#        'TZ',
#        'UA',
#        'UG',
#        'US',
#        'UY',
#        'UZ',
#        'VC',
#        'VE',
#        'VN',
#        'XK',
#        'ZA',
#        'ZM',
#        'ZW'],
#       'external_urls': {'spotify': 'https://open.spotify.com/album/0fLhefnjlIV3pGNF9Wo8CD'},
#       'href': 'https://api.spotify.com/v1/albums/0fLhefnjlIV3pGNF9Wo8CD',
#       'id': '0fLhefnjlIV3pGNF9Wo8CD',
#       'images': [{'height': 640,
#         'url': 'https://i.scdn.co/image/ab67616d0000b273a9249ebb15ca7a5b75f16a90',
#         'width': 640},
#        {'height': 300,
#         'url': 'https://i.scdn.co/image/ab67616d00001e02a9249ebb15ca7a5b75f16a90',
#         'width': 300},
#        {'height': 64,
#         'url': 'https://i.scdn.co/image/ab67616d00004851a9249ebb15ca7a5b75f16a90',
#         'width': 64}],
#       'name': 'Californication',
#       'release_date': '1999-06-08',
#       'release_date_precision': 'day',
#       'total_tracks': 15,
#       'type': 'album',
#       'uri': 'spotify:album:0fLhefnjlIV3pGNF9Wo8CD'},
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0L8ExT028jH3ddEcZwqJJ5'},
#        'href': 'https://api.spotify.com/v1/artists/0L8ExT028jH3ddEcZwqJJ5',
#        'id': '0L8ExT028jH3ddEcZwqJJ5',
#        'name': 'Red Hot Chili Peppers',
#        'type': 'artist',
#        'uri': 'spotify:artist:0L8ExT028jH3ddEcZwqJJ5'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'RW',
#       'SA',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TR',
#       'TT',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'disc_number': 1,
#      'duration_ms': 239213,
#      'explicit': False,
#      'external_ids': {'isrc': 'USWB19900687'},
#      'external_urls': {'spotify': 'https://open.spotify.com/track/1Y6DGcTCuMAtw8KB3h4W3q'},
#      'href': 'https://api.spotify.com/v1/tracks/1Y6DGcTCuMAtw8KB3h4W3q',
#      'id': '1Y6DGcTCuMAtw8KB3h4W3q',
#      'is_local': False,
#      'name': 'Around the World',
#      'popularity': 51,
#      'preview_url': 'https://p.scdn.co/mp3-preview/79ddc3851069cf64e6b11574b7414477ddf275d6?cid=49f6445c89284159816847313b09af34',
#      'track_number': 1,
#      'type': 'track',
#      'uri': 'spotify:track:1Y6DGcTCuMAtw8KB3h4W3q'},
#     {'album': {'album_type': 'album',
#       'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0L8ExT028jH3ddEcZwqJJ5'},
#         'href': 'https://api.spotify.com/v1/artists/0L8ExT028jH3ddEcZwqJJ5',
#         'id': '0L8ExT028jH3ddEcZwqJJ5',
#         'name': 'Red Hot Chili Peppers',
#         'type': 'artist',
#         'uri': 'spotify:artist:0L8ExT028jH3ddEcZwqJJ5'}],
#       'available_markets': ['AD',
#        'AE',
#        'AG',
#        'AL',
#        'AM',
#        'AO',
#        'AR',
#        'AT',
#        'AU',
#        'AZ',
#        'BA',
#        'BB',
#        'BD',
#        'BE',
#        'BF',
#        'BG',
#        'BH',
#        'BI',
#        'BJ',
#        'BN',
#        'BO',
#        'BR',
#        'BS',
#        'BW',
#        'BY',
#        'BZ',
#        'CA',
#        'CD',
#        'CG',
#        'CH',
#        'CI',
#        'CL',
#        'CM',
#        'CO',
#        'CR',
#        'CV',
#        'CW',
#        'CY',
#        'CZ',
#        'DE',
#        'DJ',
#        'DK',
#        'DM',
#        'DO',
#        'DZ',
#        'EC',
#        'EE',
#        'EG',
#        'ES',
#        'FI',
#        'FJ',
#        'FM',
#        'FR',
#        'GA',
#        'GB',
#        'GD',
#        'GH',
#        'GM',
#        'GN',
#        'GQ',
#        'GR',
#        'GT',
#        'GW',
#        'HK',
#        'HN',
#        'HR',
#        'HT',
#        'HU',
#        'ID',
#        'IE',
#        'IL',
#        'IN',
#        'IQ',
#        'IS',
#        'IT',
#        'JM',
#        'JO',
#        'JP',
#        'KE',
#        'KG',
#        'KH',
#        'KM',
#        'KN',
#        'KR',
#        'KW',
#        'KZ',
#        'LA',
#        'LB',
#        'LC',
#        'LK',
#        'LR',
#        'LS',
#        'LT',
#        'LU',
#        'LV',
#        'LY',
#        'MA',
#        'MC',
#        'MD',
#        'ME',
#        'MG',
#        'MK',
#        'ML',
#        'MN',
#        'MO',
#        'MR',
#        'MT',
#        'MU',
#        'MW',
#        'MX',
#        'MY',
#        'MZ',
#        'NA',
#        'NE',
#        'NG',
#        'NI',
#        'NL',
#        'NO',
#        'NP',
#        'NZ',
#        'OM',
#        'PA',
#        'PE',
#        'PG',
#        'PH',
#        'PK',
#        'PL',
#        'PT',
#        'PY',
#        'QA',
#        'RO',
#        'RS',
#        'RW',
#        'SA',
#        'SC',
#        'SE',
#        'SG',
#        'SI',
#        'SK',
#        'SL',
#        'SM',
#        'SN',
#        'ST',
#        'SV',
#        'SZ',
#        'TD',
#        'TG',
#        'TH',
#        'TJ',
#        'TL',
#        'TN',
#        'TR',
#        'TT',
#        'TW',
#        'TZ',
#        'UA',
#        'UG',
#        'US',
#        'UY',
#        'UZ',
#        'VC',
#        'VE',
#        'VN',
#        'XK',
#        'ZA',
#        'ZM',
#        'ZW'],
#       'external_urls': {'spotify': 'https://open.spotify.com/album/6deiaArbeoqp1xPEGdEKp1'},
#       'href': 'https://api.spotify.com/v1/albums/6deiaArbeoqp1xPEGdEKp1',
#       'id': '6deiaArbeoqp1xPEGdEKp1',
#       'images': [{'height': 640,
#         'url': 'https://i.scdn.co/image/ab67616d0000b273de1af2785a83cc660155a0c4',
#         'width': 640},
#        {'height': 300,
#         'url': 'https://i.scdn.co/image/ab67616d00001e02de1af2785a83cc660155a0c4',
#         'width': 300},
#        {'height': 64,
#         'url': 'https://i.scdn.co/image/ab67616d00004851de1af2785a83cc660155a0c4',
#         'width': 64}],
#       'name': 'By the Way (Deluxe Edition)',
#       'release_date': '2002-07-09',
#       'release_date_precision': 'day',
#       'total_tracks': 18,
#       'type': 'album',
#       'uri': 'spotify:album:6deiaArbeoqp1xPEGdEKp1'},
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0L8ExT028jH3ddEcZwqJJ5'},
#        'href': 'https://api.spotify.com/v1/artists/0L8ExT028jH3ddEcZwqJJ5',
#        'id': '0L8ExT028jH3ddEcZwqJJ5',
#        'name': 'Red Hot Chili Peppers',
#        'type': 'artist',
#        'uri': 'spotify:artist:0L8ExT028jH3ddEcZwqJJ5'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RW',
#       'SA',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TR',
#       'TT',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'disc_number': 1,
#      'duration_ms': 269000,
#      'explicit': False,
#      'external_ids': {'isrc': 'USWB10201694'},
#      'external_urls': {'spotify': 'https://open.spotify.com/track/3ZOEytgrvLwQaqXreDs2Jx'},
#      'href': 'https://api.spotify.com/v1/tracks/3ZOEytgrvLwQaqXreDs2Jx',
#      'id': '3ZOEytgrvLwQaqXreDs2Jx',
#      'is_local': False,
#      'name': "Can't Stop",
#      'popularity': 80,
#      'preview_url': 'https://p.scdn.co/mp3-preview/076f7d75404dfd18964d60da63d1855b192f3e62?cid=49f6445c89284159816847313b09af34',
#      'track_number': 7,
#      'type': 'track',
#      'uri': 'spotify:track:3ZOEytgrvLwQaqXreDs2Jx'},
#     {'album': {'album_type': 'album',
#       'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4xRYI6VqpkE3UwrDrAZL8L'},
#         'href': 'https://api.spotify.com/v1/artists/4xRYI6VqpkE3UwrDrAZL8L',
#         'id': '4xRYI6VqpkE3UwrDrAZL8L',
#         'name': 'Logic',
#         'type': 'artist',
#         'uri': 'spotify:artist:4xRYI6VqpkE3UwrDrAZL8L'}],
#       'available_markets': ['AD',
#        'AE',
#        'AG',
#        'AL',
#        'AM',
#        'AO',
#        'AR',
#        'AT',
#        'AU',
#        'AZ',
#        'BA',
#        'BB',
#        'BD',
#        'BE',
#        'BF',
#        'BG',
#        'BH',
#        'BI',
#        'BJ',
#        'BN',
#        'BO',
#        'BR',
#        'BS',
#        'BT',
#        'BW',
#        'BY',
#        'BZ',
#        'CA',
#        'CD',
#        'CG',
#        'CH',
#        'CI',
#        'CL',
#        'CM',
#        'CO',
#        'CR',
#        'CV',
#        'CY',
#        'CZ',
#        'DE',
#        'DJ',
#        'DK',
#        'DM',
#        'DO',
#        'DZ',
#        'EC',
#        'EE',
#        'EG',
#        'ES',
#        'FI',
#        'FJ',
#        'FM',
#        'FR',
#        'GA',
#        'GB',
#        'GD',
#        'GE',
#        'GH',
#        'GM',
#        'GN',
#        'GQ',
#        'GR',
#        'GT',
#        'GW',
#        'GY',
#        'HK',
#        'HN',
#        'HR',
#        'HT',
#        'HU',
#        'ID',
#        'IE',
#        'IL',
#        'IN',
#        'IQ',
#        'IS',
#        'IT',
#        'JM',
#        'JO',
#        'JP',
#        'KE',
#        'KG',
#        'KH',
#        'KI',
#        'KM',
#        'KN',
#        'KR',
#        'KW',
#        'KZ',
#        'LA',
#        'LB',
#        'LC',
#        'LI',
#        'LK',
#        'LR',
#        'LS',
#        'LT',
#        'LU',
#        'LV',
#        'LY',
#        'MA',
#        'MC',
#        'MD',
#        'ME',
#        'MG',
#        'MH',
#        'MK',
#        'ML',
#        'MN',
#        'MO',
#        'MR',
#        'MT',
#        'MU',
#        'MV',
#        'MW',
#        'MX',
#        'MY',
#        'MZ',
#        'NA',
#        'NE',
#        'NG',
#        'NI',
#        'NL',
#        'NO',
#        'NP',
#        'NR',
#        'NZ',
#        'OM',
#        'PA',
#        'PE',
#        'PG',
#        'PH',
#        'PK',
#        'PL',
#        'PS',
#        'PT',
#        'PW',
#        'PY',
#        'QA',
#        'RO',
#        'RS',
#        'RU',
#        'RW',
#        'SA',
#        'SB',
#        'SC',
#        'SE',
#        'SG',
#        'SI',
#        'SK',
#        'SL',
#        'SM',
#        'SN',
#        'SR',
#        'ST',
#        'SV',
#        'SZ',
#        'TD',
#        'TG',
#        'TH',
#        'TJ',
#        'TL',
#        'TN',
#        'TO',
#        'TR',
#        'TT',
#        'TV',
#        'TW',
#        'TZ',
#        'UA',
#        'UG',
#        'US',
#        'UY',
#        'UZ',
#        'VC',
#        'VE',
#        'VN',
#        'VU',
#        'WS',
#        'XK',
#        'ZA',
#        'ZM',
#        'ZW'],
#       'external_urls': {'spotify': 'https://open.spotify.com/album/1Mk7Lei0Ra3hawezqmad5V'},
#       'href': 'https://api.spotify.com/v1/albums/1Mk7Lei0Ra3hawezqmad5V',
#       'id': '1Mk7Lei0Ra3hawezqmad5V',
#       'images': [{'height': 640,
#         'url': 'https://i.scdn.co/image/ab67616d0000b273a4c35326f6fe6676c10e31ac',
#         'width': 640},
#        {'height': 300,
#         'url': 'https://i.scdn.co/image/ab67616d00001e02a4c35326f6fe6676c10e31ac',
#         'width': 300},
#        {'height': 64,
#         'url': 'https://i.scdn.co/image/ab67616d00004851a4c35326f6fe6676c10e31ac',
#         'width': 64}],
#       'name': 'Under Pressure (Deluxe)',
#       'release_date': '2014-10-21',
#       'release_date_precision': 'day',
#       'total_tracks': 15,
#       'type': 'album',
#       'uri': 'spotify:album:1Mk7Lei0Ra3hawezqmad5V'},
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4xRYI6VqpkE3UwrDrAZL8L'},
#        'href': 'https://api.spotify.com/v1/artists/4xRYI6VqpkE3UwrDrAZL8L',
#        'id': '4xRYI6VqpkE3UwrDrAZL8L',
#        'name': 'Logic',
#        'type': 'artist',
#        'uri': 'spotify:artist:4xRYI6VqpkE3UwrDrAZL8L'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'disc_number': 1,
#      'duration_ms': 337746,
#      'explicit': True,
#      'external_ids': {'isrc': 'USUM71414218'},
#      'external_urls': {'spotify': 'https://open.spotify.com/track/0Kojfmpnf0A2yC1zyv39Zx'},
#      'href': 'https://api.spotify.com/v1/tracks/0Kojfmpnf0A2yC1zyv39Zx',
#      'id': '0Kojfmpnf0A2yC1zyv39Zx',
#      'is_local': False,
#      'name': 'Buried Alive',
#      'popularity': 53,
#      'preview_url': None,
#      'track_number': 5,
#      'type': 'track',
#      'uri': 'spotify:track:0Kojfmpnf0A2yC1zyv39Zx'},
#     {'album': {'album_type': 'album',
#       'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0L8ExT028jH3ddEcZwqJJ5'},
#         'href': 'https://api.spotify.com/v1/artists/0L8ExT028jH3ddEcZwqJJ5',
#         'id': '0L8ExT028jH3ddEcZwqJJ5',
#         'name': 'Red Hot Chili Peppers',
#         'type': 'artist',
#         'uri': 'spotify:artist:0L8ExT028jH3ddEcZwqJJ5'}],
#       'available_markets': ['AD',
#        'AE',
#        'AG',
#        'AL',
#        'AM',
#        'AO',
#        'AR',
#        'AT',
#        'AU',
#        'AZ',
#        'BA',
#        'BB',
#        'BD',
#        'BE',
#        'BF',
#        'BG',
#        'BH',
#        'BI',
#        'BJ',
#        'BN',
#        'BO',
#        'BR',
#        'BS',
#        'BW',
#        'BY',
#        'BZ',
#        'CA',
#        'CD',
#        'CG',
#        'CH',
#        'CI',
#        'CL',
#        'CM',
#        'CO',
#        'CR',
#        'CV',
#        'CW',
#        'CY',
#        'CZ',
#        'DE',
#        'DJ',
#        'DK',
#        'DM',
#        'DO',
#        'DZ',
#        'EC',
#        'EE',
#        'EG',
#        'ES',
#        'FI',
#        'FJ',
#        'FM',
#        'FR',
#        'GA',
#        'GB',
#        'GD',
#        'GH',
#        'GM',
#        'GN',
#        'GQ',
#        'GR',
#        'GT',
#        'GW',
#        'HK',
#        'HN',
#        'HR',
#        'HT',
#        'HU',
#        'ID',
#        'IE',
#        'IL',
#        'IN',
#        'IQ',
#        'IS',
#        'IT',
#        'JM',
#        'JO',
#        'JP',
#        'KE',
#        'KG',
#        'KH',
#        'KM',
#        'KN',
#        'KR',
#        'KW',
#        'KZ',
#        'LA',
#        'LB',
#        'LC',
#        'LK',
#        'LR',
#        'LS',
#        'LT',
#        'LU',
#        'LV',
#        'LY',
#        'MA',
#        'MC',
#        'MD',
#        'ME',
#        'MG',
#        'MK',
#        'ML',
#        'MN',
#        'MO',
#        'MR',
#        'MT',
#        'MU',
#        'MW',
#        'MX',
#        'MY',
#        'MZ',
#        'NA',
#        'NE',
#        'NG',
#        'NI',
#        'NL',
#        'NO',
#        'NP',
#        'NZ',
#        'OM',
#        'PA',
#        'PE',
#        'PG',
#        'PH',
#        'PK',
#        'PL',
#        'PT',
#        'PY',
#        'QA',
#        'RO',
#        'RS',
#        'RW',
#        'SA',
#        'SC',
#        'SE',
#        'SG',
#        'SI',
#        'SK',
#        'SL',
#        'SM',
#        'SN',
#        'ST',
#        'SV',
#        'SZ',
#        'TD',
#        'TG',
#        'TH',
#        'TJ',
#        'TL',
#        'TN',
#        'TR',
#        'TT',
#        'TW',
#        'TZ',
#        'UA',
#        'UG',
#        'US',
#        'UY',
#        'UZ',
#        'VC',
#        'VE',
#        'VN',
#        'XK',
#        'ZA',
#        'ZM',
#        'ZW'],
#       'external_urls': {'spotify': 'https://open.spotify.com/album/2Y9IRtehByVkegoD7TcLfi'},
#       'href': 'https://api.spotify.com/v1/albums/2Y9IRtehByVkegoD7TcLfi',
#       'id': '2Y9IRtehByVkegoD7TcLfi',
#       'images': [{'height': 640,
#         'url': 'https://i.scdn.co/image/ab67616d0000b27394d08ab63e57b0cae74e8595',
#         'width': 640},
#        {'height': 300,
#         'url': 'https://i.scdn.co/image/ab67616d00001e0294d08ab63e57b0cae74e8595',
#         'width': 300},
#        {'height': 64,
#         'url': 'https://i.scdn.co/image/ab67616d0000485194d08ab63e57b0cae74e8595',
#         'width': 64}],
#       'name': 'Californication (Deluxe Edition)',
#       'release_date': '1999-06-08',
#       'release_date_precision': 'day',
#       'total_tracks': 18,
#       'type': 'album',
#       'uri': 'spotify:album:2Y9IRtehByVkegoD7TcLfi'},
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0L8ExT028jH3ddEcZwqJJ5'},
#        'href': 'https://api.spotify.com/v1/artists/0L8ExT028jH3ddEcZwqJJ5',
#        'id': '0L8ExT028jH3ddEcZwqJJ5',
#        'name': 'Red Hot Chili Peppers',
#        'type': 'artist',
#        'uri': 'spotify:artist:0L8ExT028jH3ddEcZwqJJ5'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RW',
#       'SA',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TR',
#       'TT',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'disc_number': 1,
#      'duration_ms': 204973,
#      'explicit': False,
#      'external_ids': {'isrc': 'USWB19900700'},
#      'external_urls': {'spotify': 'https://open.spotify.com/track/1XxCiPw07rd1ytYnE7SoJI'},
#      'href': 'https://api.spotify.com/v1/tracks/1XxCiPw07rd1ytYnE7SoJI',
#      'id': '1XxCiPw07rd1ytYnE7SoJI',
#      'is_local': False,
#      'name': "Road Trippin'",
#      'popularity': 61,
#      'preview_url': 'https://p.scdn.co/mp3-preview/44653117c32f12cb2af30093736571893ff4c694?cid=49f6445c89284159816847313b09af34',
#      'track_number': 15,
#      'type': 'track',
#      'uri': 'spotify:track:1XxCiPw07rd1ytYnE7SoJI'},
#     {'album': {'album_type': 'album',
#       'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0L8ExT028jH3ddEcZwqJJ5'},
#         'href': 'https://api.spotify.com/v1/artists/0L8ExT028jH3ddEcZwqJJ5',
#         'id': '0L8ExT028jH3ddEcZwqJJ5',
#         'name': 'Red Hot Chili Peppers',
#         'type': 'artist',
#         'uri': 'spotify:artist:0L8ExT028jH3ddEcZwqJJ5'}],
#       'available_markets': ['AD',
#        'AE',
#        'AG',
#        'AL',
#        'AM',
#        'AO',
#        'AR',
#        'AT',
#        'AU',
#        'AZ',
#        'BA',
#        'BB',
#        'BD',
#        'BE',
#        'BF',
#        'BG',
#        'BH',
#        'BI',
#        'BJ',
#        'BN',
#        'BO',
#        'BR',
#        'BS',
#        'BW',
#        'BY',
#        'BZ',
#        'CA',
#        'CD',
#        'CG',
#        'CH',
#        'CI',
#        'CL',
#        'CM',
#        'CO',
#        'CR',
#        'CV',
#        'CW',
#        'CY',
#        'CZ',
#        'DE',
#        'DJ',
#        'DK',
#        'DM',
#        'DO',
#        'DZ',
#        'EC',
#        'EE',
#        'EG',
#        'ES',
#        'FI',
#        'FJ',
#        'FM',
#        'FR',
#        'GA',
#        'GB',
#        'GD',
#        'GH',
#        'GM',
#        'GN',
#        'GQ',
#        'GR',
#        'GT',
#        'GW',
#        'HK',
#        'HN',
#        'HR',
#        'HT',
#        'HU',
#        'ID',
#        'IE',
#        'IL',
#        'IN',
#        'IQ',
#        'IS',
#        'IT',
#        'JM',
#        'JO',
#        'JP',
#        'KE',
#        'KG',
#        'KH',
#        'KM',
#        'KN',
#        'KR',
#        'KW',
#        'KZ',
#        'LA',
#        'LB',
#        'LC',
#        'LK',
#        'LR',
#        'LS',
#        'LT',
#        'LU',
#        'LV',
#        'LY',
#        'MA',
#        'MC',
#        'MD',
#        'ME',
#        'MG',
#        'MK',
#        'ML',
#        'MN',
#        'MO',
#        'MR',
#        'MT',
#        'MU',
#        'MW',
#        'MX',
#        'MY',
#        'MZ',
#        'NA',
#        'NE',
#        'NG',
#        'NI',
#        'NL',
#        'NO',
#        'NP',
#        'NZ',
#        'OM',
#        'PA',
#        'PE',
#        'PG',
#        'PH',
#        'PK',
#        'PL',
#        'PT',
#        'PY',
#        'QA',
#        'RO',
#        'RS',
#        'RW',
#        'SA',
#        'SC',
#        'SE',
#        'SG',
#        'SI',
#        'SK',
#        'SL',
#        'SM',
#        'SN',
#        'ST',
#        'SV',
#        'SZ',
#        'TD',
#        'TG',
#        'TH',
#        'TJ',
#        'TL',
#        'TN',
#        'TR',
#        'TT',
#        'TW',
#        'TZ',
#        'UA',
#        'UG',
#        'US',
#        'UY',
#        'UZ',
#        'VC',
#        'VE',
#        'VN',
#        'XK',
#        'ZA',
#        'ZM',
#        'ZW'],
#       'external_urls': {'spotify': 'https://open.spotify.com/album/2Y9IRtehByVkegoD7TcLfi'},
#       'href': 'https://api.spotify.com/v1/albums/2Y9IRtehByVkegoD7TcLfi',
#       'id': '2Y9IRtehByVkegoD7TcLfi',
#       'images': [{'height': 640,
#         'url': 'https://i.scdn.co/image/ab67616d0000b27394d08ab63e57b0cae74e8595',
#         'width': 640},
#        {'height': 300,
#         'url': 'https://i.scdn.co/image/ab67616d00001e0294d08ab63e57b0cae74e8595',
#         'width': 300},
#        {'height': 64,
#         'url': 'https://i.scdn.co/image/ab67616d0000485194d08ab63e57b0cae74e8595',
#         'width': 64}],
#       'name': 'Californication (Deluxe Edition)',
#       'release_date': '1999-06-08',
#       'release_date_precision': 'day',
#       'total_tracks': 18,
#       'type': 'album',
#       'uri': 'spotify:album:2Y9IRtehByVkegoD7TcLfi'},
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0L8ExT028jH3ddEcZwqJJ5'},
#        'href': 'https://api.spotify.com/v1/artists/0L8ExT028jH3ddEcZwqJJ5',
#        'id': '0L8ExT028jH3ddEcZwqJJ5',
#        'name': 'Red Hot Chili Peppers',
#        'type': 'artist',
#        'uri': 'spotify:artist:0L8ExT028jH3ddEcZwqJJ5'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RW',
#       'SA',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TR',
#       'TT',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'disc_number': 1,
#      'duration_ms': 329733,
#      'explicit': False,
#      'external_ids': {'isrc': 'USWB19900690'},
#      'external_urls': {'spotify': 'https://open.spotify.com/track/48UPSzbZjgc449aqz8bxox'},
#      'href': 'https://api.spotify.com/v1/tracks/48UPSzbZjgc449aqz8bxox',
#      'id': '48UPSzbZjgc449aqz8bxox',
#      'is_local': False,
#      'name': 'Californication',
#      'popularity': 81,
#      'preview_url': 'https://p.scdn.co/mp3-preview/175ce440229d2fb5361756f3e68c9647b86a8eee?cid=49f6445c89284159816847313b09af34',
#      'track_number': 6,
#      'type': 'track',
#      'uri': 'spotify:track:48UPSzbZjgc449aqz8bxox'},
#     {'album': {'album_type': 'compilation',
#       'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0LyfQWJT6nXafLPZqxe9Of'},
#         'href': 'https://api.spotify.com/v1/artists/0LyfQWJT6nXafLPZqxe9Of',
#         'id': '0LyfQWJT6nXafLPZqxe9Of',
#         'name': 'Various Artists',
#         'type': 'artist',
#         'uri': 'spotify:artist:0LyfQWJT6nXafLPZqxe9Of'}],
#       'available_markets': ['CA', 'US'],
#       'external_urls': {'spotify': 'https://open.spotify.com/album/4US5ARBYbzQI177Tc5J37t'},
#       'href': 'https://api.spotify.com/v1/albums/4US5ARBYbzQI177Tc5J37t',
#       'id': '4US5ARBYbzQI177Tc5J37t',
#       'images': [{'height': 640,
#         'url': 'https://i.scdn.co/image/ab67616d0000b273c2244fca50540dc4df3b6bbf',
#         'width': 640},
#        {'height': 300,
#         'url': 'https://i.scdn.co/image/ab67616d00001e02c2244fca50540dc4df3b6bbf',
#         'width': 300},
#        {'height': 64,
#         'url': 'https://i.scdn.co/image/ab67616d00004851c2244fca50540dc4df3b6bbf',
#         'width': 64}],
#       'name': 'The Rock & Roll Hall Of Fame: In Concert 2012 & 2013 (Live)',
#       'release_date': '2018-04-24',
#       'release_date_precision': 'day',
#       'total_tracks': 22,
#       'type': 'album',
#       'uri': 'spotify:album:4US5ARBYbzQI177Tc5J37t'},
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0L8ExT028jH3ddEcZwqJJ5'},
#        'href': 'https://api.spotify.com/v1/artists/0L8ExT028jH3ddEcZwqJJ5',
#        'id': '0L8ExT028jH3ddEcZwqJJ5',
#        'name': 'Red Hot Chili Peppers',
#        'type': 'artist',
#        'uri': 'spotify:artist:0L8ExT028jH3ddEcZwqJJ5'}],
#      'available_markets': ['CA', 'US'],
#      'disc_number': 1,
#      'duration_ms': 217351,
#      'explicit': False,
#      'external_ids': {'isrc': 'USYRC1800031'},
#      'external_urls': {'spotify': 'https://open.spotify.com/track/4nRi0PlIpoy9SyySD1IDGY'},
#      'href': 'https://api.spotify.com/v1/tracks/4nRi0PlIpoy9SyySD1IDGY',
#      'id': '4nRi0PlIpoy9SyySD1IDGY',
#      'is_local': False,
#      'name': 'By the Way - Live',
#      'popularity': 10,
#      'preview_url': 'https://p.scdn.co/mp3-preview/e073ea994d91d77841fee33c8db3e1d76850beea?cid=49f6445c89284159816847313b09af34',
#      'track_number': 10,
#      'type': 'track',
#      'uri': 'spotify:track:4nRi0PlIpoy9SyySD1IDGY'},
#     {'album': {'album_type': 'album',
# ...
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'disc_number': 1,
#      'duration_ms': 277240,
#      'explicit': False,
#      'external_ids': {'isrc': 'USAR18500147'},
#      'external_urls': {'spotify': 'https://open.spotify.com/track/0t6DdFmFQhQYWhmfa5FJer'},
#      'href': 'https://api.spotify.com/v1/tracks/0t6DdFmFQhQYWhmfa5FJer',
#      'id': '0t6DdFmFQhQYWhmfa5FJer',
#      'is_local': False,
#      'name': 'You Give Good Love',
#      'popularity': 52,
#      'preview_url': 'https://p.scdn.co/mp3-preview/dc77dfeffba6def27cfaec208623ab82cc33cacc?cid=49f6445c89284159816847313b09af34',
#      'track_number': 1,
#      'type': 'track',
#      'uri': 'spotify:track:0t6DdFmFQhQYWhmfa5FJer'},
#     {'album': {'album_type': 'album',
#       'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6XpaIBNiVzIetEPCWDvAFP'},
#         'href': 'https://api.spotify.com/v1/artists/6XpaIBNiVzIetEPCWDvAFP',
#         'id': '6XpaIBNiVzIetEPCWDvAFP',
#         'name': 'Whitney Houston',
#         'type': 'artist',
#         'uri': 'spotify:artist:6XpaIBNiVzIetEPCWDvAFP'}],
#       'available_markets': ['AD',
#        'AE',
#        'AG',
#        'AL',
#        'AM',
#        'AO',
#        'AR',
#        'AT',
#        'AU',
#        'AZ',
#        'BA',
#        'BB',
#        'BD',
#        'BE',
#        'BF',
#        'BG',
#        'BH',
#        'BI',
#        'BJ',
#        'BN',
#        'BO',
#        'BR',
#        'BS',
#        'BT',
#        'BW',
#        'BY',
#        'BZ',
#        'CA',
#        'CD',
#        'CG',
#        'CH',
#        'CI',
#        'CL',
#        'CM',
#        'CO',
#        'CR',
#        'CV',
#        'CW',
#        'CY',
#        'CZ',
#        'DE',
#        'DJ',
#        'DK',
#        'DM',
#        'DO',
#        'DZ',
#        'EC',
#        'EE',
#        'EG',
#        'ES',
#        'FI',
#        'FJ',
#        'FM',
#        'FR',
#        'GA',
#        'GB',
#        'GD',
#        'GE',
#        'GH',
#        'GM',
#        'GN',
#        'GQ',
#        'GR',
#        'GT',
#        'GW',
#        'GY',
#        'HK',
#        'HN',
#        'HR',
#        'HT',
#        'HU',
#        'ID',
#        'IE',
#        'IL',
#        'IN',
#        'IQ',
#        'IS',
#        'IT',
#        'JM',
#        'JO',
#        'JP',
#        'KE',
#        'KG',
#        'KH',
#        'KI',
#        'KM',
#        'KN',
#        'KR',
#        'KW',
#        'KZ',
#        'LA',
#        'LB',
#        'LC',
#        'LI',
#        'LK',
#        'LR',
#        'LS',
#        'LT',
#        'LU',
#        'LV',
#        'LY',
#        'MA',
#        'MC',
#        'MD',
#        'ME',
#        'MG',
#        'MH',
#        'MK',
#        'ML',
#        'MN',
#        'MO',
#        'MR',
#        'MT',
#        'MU',
#        'MV',
#        'MW',
#        'MX',
#        'MY',
#        'MZ',
#        'NA',
#        'NE',
#        'NG',
#        'NI',
#        'NL',
#        'NO',
#        'NP',
#        'NR',
#        'NZ',
#        'OM',
#        'PA',
#        'PE',
#        'PG',
#        'PH',
#        'PK',
#        'PL',
#        'PS',
#        'PT',
#        'PW',
#        'PY',
#        'QA',
#        'RO',
#        'RS',
#        'RU',
#        'RW',
#        'SA',
#        'SB',
#        'SC',
#        'SE',
#        'SG',
#        'SI',
#        'SK',
#        'SL',
#        'SM',
#        'SN',
#        'SR',
#        'ST',
#        'SV',
#        'SZ',
#        'TD',
#        'TG',
#        'TH',
#        'TJ',
#        'TL',
#        'TN',
#        'TO',
#        'TR',
#        'TT',
#        'TV',
#        'TW',
#        'TZ',
#        'UA',
#        'UG',
#        'US',
#        'UY',
#        'UZ',
#        'VC',
#        'VE',
#        'VN',
#        'VU',
#        'WS',
#        'XK',
#        'ZA',
#        'ZM',
#        'ZW'],
#       'external_urls': {'spotify': 'https://open.spotify.com/album/2MH37enG6IPvNK5QFLyKes'},
#       'href': 'https://api.spotify.com/v1/albums/2MH37enG6IPvNK5QFLyKes',
#       'id': '2MH37enG6IPvNK5QFLyKes',
#       'images': [{'height': 640,
#         'url': 'https://i.scdn.co/image/ab67616d0000b2732ae4fcec560ab559d6f5dc88',
#         'width': 640},
#        {'height': 300,
#         'url': 'https://i.scdn.co/image/ab67616d00001e022ae4fcec560ab559d6f5dc88',
#         'width': 300},
#        {'height': 64,
#         'url': 'https://i.scdn.co/image/ab67616d000048512ae4fcec560ab559d6f5dc88',
#         'width': 64}],
#       'name': 'Whitney Houston',
#       'release_date': '1985-02-14',
#       'release_date_precision': 'day',
#       'total_tracks': 10,
#       'type': 'album',
#       'uri': 'spotify:album:2MH37enG6IPvNK5QFLyKes'},
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6XpaIBNiVzIetEPCWDvAFP'},
#        'href': 'https://api.spotify.com/v1/artists/6XpaIBNiVzIetEPCWDvAFP',
#        'id': '6XpaIBNiVzIetEPCWDvAFP',
#        'name': 'Whitney Houston',
#        'type': 'artist',
#        'uri': 'spotify:artist:6XpaIBNiVzIetEPCWDvAFP'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'disc_number': 1,
#      'duration_ms': 275533,
#      'explicit': False,
#      'external_ids': {'isrc': 'USAR18500150'},
#      'external_urls': {'spotify': 'https://open.spotify.com/track/5tdKaKLnC4SgtDZ6RlWeal'},
#      'href': 'https://api.spotify.com/v1/tracks/5tdKaKLnC4SgtDZ6RlWeal',
#      'id': '5tdKaKLnC4SgtDZ6RlWeal',
#      'is_local': False,
#      'name': 'How Will I Know',
#      'popularity': 70,
#      'preview_url': 'https://p.scdn.co/mp3-preview/4cfd0ab2b770e37313275d37788f687992b0ee17?cid=49f6445c89284159816847313b09af34',
#      'track_number': 6,
#      'type': 'track',
#      'uri': 'spotify:track:5tdKaKLnC4SgtDZ6RlWeal'},
#     {'album': {'album_type': 'album',
#       'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6XpaIBNiVzIetEPCWDvAFP'},
#         'href': 'https://api.spotify.com/v1/artists/6XpaIBNiVzIetEPCWDvAFP',
#         'id': '6XpaIBNiVzIetEPCWDvAFP',
#         'name': 'Whitney Houston',
#         'type': 'artist',
#         'uri': 'spotify:artist:6XpaIBNiVzIetEPCWDvAFP'}],
#       'available_markets': ['AD',
#        'AE',
#        'AG',
#        'AL',
#        'AM',
#        'AO',
#        'AR',
#        'AT',
#        'AU',
#        'AZ',
#        'BA',
#        'BB',
#        'BD',
#        'BE',
#        'BF',
#        'BG',
#        'BH',
#        'BI',
#        'BJ',
#        'BN',
#        'BO',
#        'BR',
#        'BS',
#        'BT',
#        'BW',
#        'BY',
#        'BZ',
#        'CA',
#        'CD',
#        'CG',
#        'CH',
#        'CI',
#        'CL',
#        'CM',
#        'CO',
#        'CR',
#        'CV',
#        'CW',
#        'CY',
#        'CZ',
#        'DE',
#        'DJ',
#        'DK',
#        'DM',
#        'DO',
#        'DZ',
#        'EC',
#        'EE',
#        'EG',
#        'ES',
#        'FI',
#        'FJ',
#        'FM',
#        'FR',
#        'GA',
#        'GB',
#        'GD',
#        'GE',
#        'GH',
#        'GM',
#        'GN',
#        'GQ',
#        'GR',
#        'GT',
#        'GW',
#        'GY',
#        'HK',
#        'HN',
#        'HR',
#        'HT',
#        'HU',
#        'ID',
#        'IE',
#        'IL',
#        'IN',
#        'IQ',
#        'IS',
#        'IT',
#        'JM',
#        'JO',
#        'JP',
#        'KE',
#        'KG',
#        'KH',
#        'KI',
#        'KM',
#        'KN',
#        'KR',
#        'KW',
#        'KZ',
#        'LA',
#        'LB',
#        'LC',
#        'LI',
#        'LK',
#        'LR',
#        'LS',
#        'LT',
#        'LU',
#        'LV',
#        'LY',
#        'MA',
#        'MC',
#        'MD',
#        'ME',
#        'MG',
#        'MH',
#        'MK',
#        'ML',
#        'MN',
#        'MO',
#        'MR',
#        'MT',
#        'MU',
#        'MV',
#        'MW',
#        'MX',
#        'MY',
#        'MZ',
#        'NA',
#        'NE',
#        'NG',
#        'NI',
#        'NL',
#        'NO',
#        'NP',
#        'NR',
#        'NZ',
#        'OM',
#        'PA',
#        'PE',
#        'PG',
#        'PH',
#        'PK',
#        'PL',
#        'PS',
#        'PT',
#        'PW',
#        'PY',
#        'QA',
#        'RO',
#        'RS',
#        'RU',
#        'RW',
#        'SA',
#        'SB',
#        'SC',
#        'SE',
#        'SG',
#        'SI',
#        'SK',
#        'SL',
#        'SM',
#        'SN',
#        'SR',
#        'ST',
#        'SV',
#        'SZ',
#        'TD',
#        'TG',
#        'TH',
#        'TJ',
#        'TL',
#        'TN',
#        'TO',
#        'TR',
#        'TT',
#        'TV',
#        'TW',
#        'TZ',
#        'UA',
#        'UG',
#        'US',
#        'UY',
#        'UZ',
#        'VC',
#        'VE',
#        'VN',
#        'VU',
#        'WS',
#        'XK',
#        'ZA',
#        'ZM',
#        'ZW'],
#       'external_urls': {'spotify': 'https://open.spotify.com/album/5Vdzprr5cOqXQo44eHeV7t'},
#       'href': 'https://api.spotify.com/v1/albums/5Vdzprr5cOqXQo44eHeV7t',
#       'id': '5Vdzprr5cOqXQo44eHeV7t',
#       'images': [{'height': 640,
#         'url': 'https://i.scdn.co/image/ab67616d0000b273cc57e9b00b87dd0f6e868347',
#         'width': 640},
#        {'height': 300,
#         'url': 'https://i.scdn.co/image/ab67616d00001e02cc57e9b00b87dd0f6e868347',
#         'width': 300},
#        {'height': 64,
#         'url': 'https://i.scdn.co/image/ab67616d00004851cc57e9b00b87dd0f6e868347',
#         'width': 64}],
#       'name': 'Whitney',
#       'release_date': '1987-06-02',
#       'release_date_precision': 'day',
#       'total_tracks': 11,
#       'type': 'album',
#       'uri': 'spotify:album:5Vdzprr5cOqXQo44eHeV7t'},
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6XpaIBNiVzIetEPCWDvAFP'},
#        'href': 'https://api.spotify.com/v1/artists/6XpaIBNiVzIetEPCWDvAFP',
#        'id': '6XpaIBNiVzIetEPCWDvAFP',
#        'name': 'Whitney Houston',
#        'type': 'artist',
#        'uri': 'spotify:artist:6XpaIBNiVzIetEPCWDvAFP'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'disc_number': 1,
#      'duration_ms': 305066,
#      'explicit': False,
#      'external_ids': {'isrc': 'USAR18700115'},
#      'external_urls': {'spotify': 'https://open.spotify.com/track/19wadMw1A8XejDV4p5wMt1'},
#      'href': 'https://api.spotify.com/v1/tracks/19wadMw1A8XejDV4p5wMt1',
#      'id': '19wadMw1A8XejDV4p5wMt1',
#      'is_local': False,
#      'name': "Didn't We Almost Have It All",
#      'popularity': 61,
#      'preview_url': 'https://p.scdn.co/mp3-preview/7411cc6a36f98f46a2890f6f322605021db0f3c2?cid=49f6445c89284159816847313b09af34',
#      'track_number': 4,
#      'type': 'track',
#      'uri': 'spotify:track:19wadMw1A8XejDV4p5wMt1'}],
#    'limit': 10,
#    'next': 'https://api.spotify.com/v1/search?query=Whitney+Houston&type=track&offset=10&limit=10',
#    'offset': 0,
#    'previous': None,
#    'total': 5827}}]

# %% [markdown]
# We can iterate through the `results` list and get the names of all the songs:

# %%
song_names = []

for result in results:
    for item in result["tracks"]["items"]:
        song_names.append(item["name"])

# %%
song_names
# Out:
# ['Under the Bridge',
#  'Anthony Kiedis',
#  'Around the World',
#  "Can't Stop",
#  'Buried Alive',
#  "Road Trippin'",
#  'Californication',
#  'By the Way - Live',
#  'Snow (Hey Oh)',
#  'Pedigree',
#  'Scarred From Love',
#  'Emotionally Scarred',
#  'SCARR',
#  'Scarred',
#  'SoIcyBoyz 2 (feat. Pooh Shiesty, Foogiano & Tay Keith)',
#  'Scarred Island',
#  'SoIcyBoyz 2 (feat. Pooh Shiesty, Foogiano & Tay Keith)',
#  'Scarred',
#  'Rolling Loud (feat. Big Scarr, BigWalkDog)',
#  'Free Smoke (feat. Big Scarr)',
#  'I Wanna Dance with Somebody (Who Loves Me)',
#  'The Star Spangled Banner (feat. The Florida Orchestra) - Live from Super Bowl XXV',
#  'Higher Love',
#  'I Look to You',
#  'I Will Always Love You',
#  'Exhale (Shoop Shoop) - from "Waiting to Exhale" - Original Soundtrack',
#  'I Have Nothing',
#  'You Give Good Love',
#  'How Will I Know',
#  "Didn't We Almost Have It All"]

# %% [markdown]
# #### Exploring the tracks

# %%
# Get artist id's for all the tracks you found

query = "Despacito"

Despacito = sp.search(q = query, limit = 50)

# %%
Despacito_artists = set()

for item in Despacito["tracks"]["items"]:
    for artist in item["artists"]:
        Despacito_artists.add(artist["uri"])

# %%
Despacito["tracks"]["items"][2]["artists"][0]["name"]
# Out:
# 'Luis Fonsi'

# %%
Despacito_artists
# Out:
# {'spotify:artist:0NxhAEPOSeCg6vypFr7yjU',
#  'spotify:artist:0QNakySWugkMvfwbDoaY9L',
#  'spotify:artist:0fIdQWpwzU2oEtsoyArDOL',
#  'spotify:artist:0r3y7sISJoUIfT5E85AYII',
#  'spotify:artist:1NiC1V6xc8OR1ERiIoCvtx',
#  'spotify:artist:1Uz4WPsI4VylKT6lhJiDO5',
#  'spotify:artist:1emgbX82aLN8eCS3AnXFfC',
#  'spotify:artist:1mX1TWKpNxDSAH16LgDfiR',
#  'spotify:artist:1qwVM2JnEMXbKgvZESGsRn',
#  'spotify:artist:1rVo9h17cHhWerDiZj0yXH',
#  'spotify:artist:1sJhbiQRSIKZeTYEZfzBSV',
#  'spotify:artist:1uNFoZAHBGtllmzznpCI3s',
#  'spotify:artist:1uj8EOCKAXn4w2TR7CVnQb',
#  'spotify:artist:26AHtbjWKiwYzsoGoUZq53',
#  'spotify:artist:2T06whb4s6UiufL1j5Qtz9',
#  'spotify:artist:2VAjBQ6cM2faT2UKxONV93',
#  'spotify:artist:3YfvowVavHTzXLKmKaYM1c',
#  'spotify:artist:3YrM00mKs7wqOtBPmeSoEo',
#  'spotify:artist:3vOJJbGGUOtC9csissiL0G',
#  'spotify:artist:4KLOMib6zqzNayKwLWTs2Q',
#  'spotify:artist:4L5SLCIDWPPNGzrLraYCOS',
#  'spotify:artist:4N5fp4zhTsVITZTVfsXpc2',
#  'spotify:artist:4V8Sr092TqfHkfAA5fXXqG',
#  'spotify:artist:4VMYDCV2IEDYJArk749S6m',
#  'spotify:artist:4fdxbJLSNRIMkMGbLs5QPF',
#  'spotify:artist:4j4Lq1ut4h3H3eTIubtyog',
#  'spotify:artist:5DsbNI5ZIDIWjmsAdaYvZ2',
#  'spotify:artist:5HPu6u2rDA0f6jp51xZAEq',
#  'spotify:artist:5KWOCu1saEHAhPiLKlOLIy',
#  'spotify:artist:5tqJLLaSDpdhDAwqWgAdXM',
#  'spotify:artist:62rnGiDozQmBBk5yM21yOC',
#  'spotify:artist:6Fi8CHfO8WGtu3yO8c2Mc4',
#  'spotify:artist:6MERXsiRbur2oJZFgYRDKz',
#  'spotify:artist:6QtqvuYuaOJy4te3nfkHKK',
#  'spotify:artist:6RTlv2UCWtRggV0rIo5TrN',
#  'spotify:artist:6U3ybJ9UHNKEdsH7ktGBZ7',
#  'spotify:artist:6dBIk14xcZqU0cRsyjXNkX',
#  'spotify:artist:6mU8ucezzms5I2kNH6HNlu',
#  'spotify:artist:6wBOZ9D65AcqUlfKUqsQ7R',
#  'spotify:artist:72iuahEAHKaMzDXKVw6e8P',
#  'spotify:artist:738wLrAtLtCtFOLvQBXOXp',
#  'spotify:artist:7CQwac16i1W5ej8YpuL3dv',
#  'spotify:artist:7dTPvuNcEXLkQ1XiAuiWIP',
#  'spotify:artist:7p3ipw2PvGG0X2x6zL1DLO',
#  'spotify:artist:7y33enVLfDvft6HGNmcxdV'}

# %% [markdown]
# ### Playlists

# %%
my_playlist = sp.user_playlist_tracks(user="spotify",
                                      playlist_id="https://open.spotify.com/playlist/24T3swe0HN7JWLfsDcakHw?si=ce24270cef314a9a")

# %% [markdown]
# Extract all songs IDs from a playlist

# %%
my_playlist
# Out:
# {'href': 'https://api.spotify.com/v1/playlists/0ce6Rmxf7QXroqa1wzjWY8/tracks?offset=0&limit=100&additional_types=track',
#  'items': [{'added_at': '2021-09-22T07:34:05Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/gperdigo'},
#     'href': 'https://api.spotify.com/v1/users/gperdigo',
#     'id': 'gperdigo',
#     'type': 'user',
#     'uri': 'spotify:user:gperdigo'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/579T5fNgfbDetyamUTAetw'},
#        'href': 'https://api.spotify.com/v1/artists/579T5fNgfbDetyamUTAetw',
#        'id': '579T5fNgfbDetyamUTAetw',
#        'name': 'S+C+A+R+R',
#        'type': 'artist',
#        'uri': 'spotify:artist:579T5fNgfbDetyamUTAetw'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/5ZwTPVgvwIMxJh2GAdsaaP'},
#      'href': 'https://api.spotify.com/v1/albums/5ZwTPVgvwIMxJh2GAdsaaP',
#      'id': '5ZwTPVgvwIMxJh2GAdsaaP',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27331df83ec065ed0a42cc82670',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0231df83ec065ed0a42cc82670',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485131df83ec065ed0a42cc82670',
#        'width': 64}],
#      'name': 'You\'re the One (From "I Lost My Body")',
#      'release_date': '2019-10-31',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:5ZwTPVgvwIMxJh2GAdsaaP'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/579T5fNgfbDetyamUTAetw'},
#       'href': 'https://api.spotify.com/v1/artists/579T5fNgfbDetyamUTAetw',
#       'id': '579T5fNgfbDetyamUTAetw',
#       'name': 'S+C+A+R+R',
#       'type': 'artist',
#       'uri': 'spotify:artist:579T5fNgfbDetyamUTAetw'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 167986,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'FR6F31902770'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/5Tnx4R7Gwj1LZsfssfzchh'},
#     'href': 'https://api.spotify.com/v1/tracks/5Tnx4R7Gwj1LZsfssfzchh',
#     'id': '5Tnx4R7Gwj1LZsfssfzchh',
#     'is_local': False,
#     'name': 'You\'re the One - From "I Lost My Body"',
#     'popularity': 37,
#     'preview_url': 'https://p.scdn.co/mp3-preview/95301c6db23d3e35deda12970ef6bdc9f2d71579?cid=faab70f9c2b24a689a326c3e0be9e549',
#     'track': True,
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:5Tnx4R7Gwj1LZsfssfzchh'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2021-09-22T07:35:32Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/gperdigo'},
#     'href': 'https://api.spotify.com/v1/users/gperdigo',
#     'id': 'gperdigo',
#     'type': 'user',
#     'uri': 'spotify:user:gperdigo'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5wFXmYsg3KFJ8BDsQudJ4f'},
#        'href': 'https://api.spotify.com/v1/artists/5wFXmYsg3KFJ8BDsQudJ4f',
#        'id': '5wFXmYsg3KFJ8BDsQudJ4f',
#        'name': 'Manchester Orchestra',
#        'type': 'artist',
#        'uri': 'spotify:artist:5wFXmYsg3KFJ8BDsQudJ4f'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/4hruYceqit29o6m4arpAql'},
#      'href': 'https://api.spotify.com/v1/albums/4hruYceqit29o6m4arpAql',
#      'id': '4hruYceqit29o6m4arpAql',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2736827146a676dafc0357fa665',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e026827146a676dafc0357fa665',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048516827146a676dafc0357fa665',
#        'width': 64}],
#      'name': 'A Black Mile To The Surface',
#      'release_date': '2017-07-28',
#      'release_date_precision': 'day',
#      'total_tracks': 11,
#      'type': 'album',
#      'uri': 'spotify:album:4hruYceqit29o6m4arpAql'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5wFXmYsg3KFJ8BDsQudJ4f'},
#       'href': 'https://api.spotify.com/v1/artists/5wFXmYsg3KFJ8BDsQudJ4f',
#       'id': '5wFXmYsg3KFJ8BDsQudJ4f',
#       'name': 'Manchester Orchestra',
#       'type': 'artist',
#       'uri': 'spotify:artist:5wFXmYsg3KFJ8BDsQudJ4f'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 328933,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'USC4R1702133'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/5eKfpH2dQ7FltCqb7LWEGJ'},
#     'href': 'https://api.spotify.com/v1/tracks/5eKfpH2dQ7FltCqb7LWEGJ',
#     'id': '5eKfpH2dQ7FltCqb7LWEGJ',
#     'is_local': False,
#     'name': 'The Alien',
#     'popularity': 47,
#     'preview_url': None,
#     'track': True,
#     'track_number': 5,
#     'type': 'track',
#     'uri': 'spotify:track:5eKfpH2dQ7FltCqb7LWEGJ'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2021-09-22T07:35:42Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/gperdigo'},
#     'href': 'https://api.spotify.com/v1/users/gperdigo',
#     'id': 'gperdigo',
#     'type': 'user',
#     'uri': 'spotify:user:gperdigo'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4YwaTXvuTkyUrGPbz4jEYg'},
#        'href': 'https://api.spotify.com/v1/artists/4YwaTXvuTkyUrGPbz4jEYg',
#        'id': '4YwaTXvuTkyUrGPbz4jEYg',
#        'name': 'Nina And Frederik',
#        'type': 'artist',
#        'uri': 'spotify:artist:4YwaTXvuTkyUrGPbz4jEYg'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RU',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/63obBSI5HlMFoawrrq8RDG'},
#      'href': 'https://api.spotify.com/v1/albums/63obBSI5HlMFoawrrq8RDG',
#      'id': '63obBSI5HlMFoawrrq8RDG',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273a287436c88bfedf3892dcaea',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02a287436c88bfedf3892dcaea',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851a287436c88bfedf3892dcaea',
#        'width': 64}],
#      'name': 'Vintage World Nº10- EPs Collectors "Oh, Pecador" "Oh, Sinner Man"',
#      'release_date': '1958-05-06',
#      'release_date_precision': 'day',
#      'total_tracks': 4,
#      'type': 'album',
#      'uri': 'spotify:album:63obBSI5HlMFoawrrq8RDG'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4YwaTXvuTkyUrGPbz4jEYg'},
#       'href': 'https://api.spotify.com/v1/artists/4YwaTXvuTkyUrGPbz4jEYg',
#       'id': '4YwaTXvuTkyUrGPbz4jEYg',
#       'name': 'Nina And Frederik',
#       'type': 'artist',
#       'uri': 'spotify:artist:4YwaTXvuTkyUrGPbz4jEYg'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RU',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 145773,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'USA560979249'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/0R3OcHrzq3f8raukyZgTAc'},
#     'href': 'https://api.spotify.com/v1/tracks/0R3OcHrzq3f8raukyZgTAc',
#     'id': '0R3OcHrzq3f8raukyZgTAc',
#     'is_local': False,
#     'name': 'Oh, Pecador (Oh, Sinne Man)',
#     'popularity': 1,
#     'preview_url': 'https://p.scdn.co/mp3-preview/5a1f140ce93647c88b874627f0515bc739aae64a?cid=faab70f9c2b24a689a326c3e0be9e549',
#     'track': True,
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:0R3OcHrzq3f8raukyZgTAc'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2021-09-22T07:36:25Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/gperdigo'},
#     'href': 'https://api.spotify.com/v1/users/gperdigo',
#     'id': 'gperdigo',
#     'type': 'user',
#     'uri': 'spotify:user:gperdigo'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2G7QgTep5IsJHGHm1hXygD'},
#        'href': 'https://api.spotify.com/v1/artists/2G7QgTep5IsJHGHm1hXygD',
#        'id': '2G7QgTep5IsJHGHm1hXygD',
#        'name': 'Kid Francescoli',
#        'type': 'artist',
#        'uri': 'spotify:artist:2G7QgTep5IsJHGHm1hXygD'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/4iII9nfzjxOYQFp8PyV6HD'},
#      'href': 'https://api.spotify.com/v1/albums/4iII9nfzjxOYQFp8PyV6HD',
#      'id': '4iII9nfzjxOYQFp8PyV6HD',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2737fc1ed797a7ef1dd805b5bc5',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e027fc1ed797a7ef1dd805b5bc5',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048517fc1ed797a7ef1dd805b5bc5',
#        'width': 64}],
#      'name': 'Play Me Again',
#      'release_date': '2017-03-03',
#      'release_date_precision': 'day',
#      'total_tracks': 11,
#      'type': 'album',
#      'uri': 'spotify:album:4iII9nfzjxOYQFp8PyV6HD'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2G7QgTep5IsJHGHm1hXygD'},
#       'href': 'https://api.spotify.com/v1/artists/2G7QgTep5IsJHGHm1hXygD',
#       'id': '2G7QgTep5IsJHGHm1hXygD',
#       'name': 'Kid Francescoli',
#       'type': 'artist',
#       'uri': 'spotify:artist:2G7QgTep5IsJHGHm1hXygD'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 390638,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'FRP621600280'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/24upABZ8A0sAepfu91sEYr'},
#     'href': 'https://api.spotify.com/v1/tracks/24upABZ8A0sAepfu91sEYr',
#     'id': '24upABZ8A0sAepfu91sEYr',
#     'is_local': False,
#     'name': 'Moon (And It Went Like)',
#     'popularity': 69,
#     'preview_url': 'https://p.scdn.co/mp3-preview/dcad19ab187c730cb3ad678695db21baf0137ac2?cid=faab70f9c2b24a689a326c3e0be9e549',
#     'track': True,
#     'track_number': 9,
#     'type': 'track',
#     'uri': 'spotify:track:24upABZ8A0sAepfu91sEYr'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2021-09-22T07:36:45Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/gperdigo'},
#     'href': 'https://api.spotify.com/v1/users/gperdigo',
#     'id': 'gperdigo',
#     'type': 'user',
#     'uri': 'spotify:user:gperdigo'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4aEnNH9PuU1HF3TsZTru54'},
#        'href': 'https://api.spotify.com/v1/artists/4aEnNH9PuU1HF3TsZTru54',
#        'id': '4aEnNH9PuU1HF3TsZTru54',
#        'name': 'Caribou',
#        'type': 'artist',
#        'uri': 'spotify:artist:4aEnNH9PuU1HF3TsZTru54'}],
#      'available_markets': [],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/1NqhnYAVqlHuPG2OlgKSZy'},
#      'href': 'https://api.spotify.com/v1/albums/1NqhnYAVqlHuPG2OlgKSZy',
#      'id': '1NqhnYAVqlHuPG2OlgKSZy',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273db02bfcbd6808d71afb2a3bf',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02db02bfcbd6808d71afb2a3bf',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851db02bfcbd6808d71afb2a3bf',
#        'width': 64}],
#      'name': 'Never Come Back',
#      'release_date': '2020-01-28',
#      'release_date_precision': 'day',
#      'total_tracks': 3,
#      'type': 'album',
#      'uri': 'spotify:album:1NqhnYAVqlHuPG2OlgKSZy'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4aEnNH9PuU1HF3TsZTru54'},
#       'href': 'https://api.spotify.com/v1/artists/4aEnNH9PuU1HF3TsZTru54',
#       'id': '4aEnNH9PuU1HF3TsZTru54',
#       'name': 'Caribou',
#       'type': 'artist',
#       'uri': 'spotify:artist:4aEnNH9PuU1HF3TsZTru54'}],
#     'available_markets': [],
#     'disc_number': 1,
#     'duration_ms': 305480,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'DED622000007'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/7IBrKDuBlyz3vW9JFCux10'},
#     'href': 'https://api.spotify.com/v1/tracks/7IBrKDuBlyz3vW9JFCux10',
#     'id': '7IBrKDuBlyz3vW9JFCux10',
#     'is_local': False,
#     'name': 'Never Come Back',
#     'popularity': 0,
#     'preview_url': None,
#     'track': True,
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:7IBrKDuBlyz3vW9JFCux10'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2021-09-22T07:36:57Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/gperdigo'},
#     'href': 'https://api.spotify.com/v1/users/gperdigo',
#     'id': 'gperdigo',
#     'type': 'user',
#     'uri': 'spotify:user:gperdigo'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6wH6iStAh4KIaWfuhf0NYM'},
#        'href': 'https://api.spotify.com/v1/artists/6wH6iStAh4KIaWfuhf0NYM',
#        'id': '6wH6iStAh4KIaWfuhf0NYM',
#        'name': 'Manu Chao',
#        'type': 'artist',
#        'uri': 'spotify:artist:6wH6iStAh4KIaWfuhf0NYM'}],
#      'available_markets': [],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/6sLpbLsD1LlXnlCRjt8YuE'},
#      'href': 'https://api.spotify.com/v1/albums/6sLpbLsD1LlXnlCRjt8YuE',
#      'id': '6sLpbLsD1LlXnlCRjt8YuE',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27381d487c754295e61521aadcc',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0281d487c754295e61521aadcc',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485181d487c754295e61521aadcc',
#        'width': 64}],
#      'name': 'Proxima Estacion : Esperanza',
#      'release_date': '2001',
#      'release_date_precision': 'year',
#      'total_tracks': 17,
#      'type': 'album',
#      'uri': 'spotify:album:6sLpbLsD1LlXnlCRjt8YuE'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6wH6iStAh4KIaWfuhf0NYM'},
#       'href': 'https://api.spotify.com/v1/artists/6wH6iStAh4KIaWfuhf0NYM',
#       'id': '6wH6iStAh4KIaWfuhf0NYM',
#       'name': 'Manu Chao',
#       'type': 'artist',
#       'uri': 'spotify:artist:6wH6iStAh4KIaWfuhf0NYM'}],
#     'available_markets': [],
#     'disc_number': 1,
#     'duration_ms': 114920,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'FR84R0100008'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/3ecVMxkn0sJ3nlx1uS0IVN'},
#     'href': 'https://api.spotify.com/v1/tracks/3ecVMxkn0sJ3nlx1uS0IVN',
#     'id': '3ecVMxkn0sJ3nlx1uS0IVN',
#     'is_local': False,
#     'name': 'Trapped By Love',
#     'popularity': 0,
#     'preview_url': None,
#     'track': True,
#     'track_number': 9,
#     'type': 'track',
#     'uri': 'spotify:track:3ecVMxkn0sJ3nlx1uS0IVN'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2021-09-22T07:50:42Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/1269546383'},
#     'href': 'https://api.spotify.com/v1/users/1269546383',
#     'id': '1269546383',
#     'type': 'user',
#     'uri': 'spotify:user:1269546383'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5v74mT11KGJqadf9sLw4dA'},
#        'href': 'https://api.spotify.com/v1/artists/5v74mT11KGJqadf9sLw4dA',
#        'id': '5v74mT11KGJqadf9sLw4dA',
#        'name': 'Cannonball Adderley',
#        'type': 'artist',
#        'uri': 'spotify:artist:5v74mT11KGJqadf9sLw4dA'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/5JpHin9lKOyizuJhKxaHWp'},
#      'href': 'https://api.spotify.com/v1/albums/5JpHin9lKOyizuJhKxaHWp',
#      'id': '5JpHin9lKOyizuJhKxaHWp',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27385827d636962ea87b858ab32',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0285827d636962ea87b858ab32',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485185827d636962ea87b858ab32',
#        'width': 64}],
#      'name': 'Jazz Profile: Cannonball Adderley',
#      'release_date': '1997-01-01',
#      'release_date_precision': 'day',
#      'total_tracks': 6,
#      'type': 'album',
#      'uri': 'spotify:album:5JpHin9lKOyizuJhKxaHWp'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5v74mT11KGJqadf9sLw4dA'},
#       'href': 'https://api.spotify.com/v1/artists/5v74mT11KGJqadf9sLw4dA',
#       'id': '5v74mT11KGJqadf9sLw4dA',
#       'name': 'Cannonball Adderley',
#       'type': 'artist',
#       'uri': 'spotify:artist:5v74mT11KGJqadf9sLw4dA'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 313200,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'USCA29000136'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/6NF8MZ2trxckVBr82pyyPt'},
#     'href': 'https://api.spotify.com/v1/tracks/6NF8MZ2trxckVBr82pyyPt',
#     'id': '6NF8MZ2trxckVBr82pyyPt',
#     'is_local': False,
#     'name': 'Mercy, Mercy, Mercy',
#     'popularity': 55,
#     'preview_url': None,
#     'track': True,
#     'track_number': 5,
#     'type': 'track',
#     'uri': 'spotify:track:6NF8MZ2trxckVBr82pyyPt'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2021-09-22T07:51:02Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/1269546383'},
#     'href': 'https://api.spotify.com/v1/users/1269546383',
#     'id': '1269546383',
#     'type': 'user',
#     'uri': 'spotify:user:1269546383'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3ayds6VIVBx3CU5NSNCDbq'},
#        'href': 'https://api.spotify.com/v1/artists/3ayds6VIVBx3CU5NSNCDbq',
#        'id': '3ayds6VIVBx3CU5NSNCDbq',
#        'name': 'Jacques Dutronc',
#        'type': 'artist',
#        'uri': 'spotify:artist:3ayds6VIVBx3CU5NSNCDbq'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'RW',
#       'SA',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TR',
#       'TT',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/2S4mgB4hHSszPRGoYrGJ0d'},
#      'href': 'https://api.spotify.com/v1/albums/2S4mgB4hHSszPRGoYrGJ0d',
#      'id': '2S4mgB4hHSszPRGoYrGJ0d',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273a28387fcc6e1c7ed11d82022',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02a28387fcc6e1c7ed11d82022',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851a28387fcc6e1c7ed11d82022',
#        'width': 64}],
#      'name': "L' aventurier",
#      'release_date': '1969-06-30',
#      'release_date_precision': 'day',
#      'total_tracks': 12,
#      'type': 'album',
#      'uri': 'spotify:album:2S4mgB4hHSszPRGoYrGJ0d'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3ayds6VIVBx3CU5NSNCDbq'},
#       'href': 'https://api.spotify.com/v1/artists/3ayds6VIVBx3CU5NSNCDbq',
#       'id': '3ayds6VIVBx3CU5NSNCDbq',
#       'name': 'Jacques Dutronc',
#       'type': 'artist',
#       'uri': 'spotify:artist:3ayds6VIVBx3CU5NSNCDbq'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'RW',
#      'SA',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TR',
#      'TT',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 155600,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'FRZ196900030'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/6FwkZ5lYdCUh1mzI1Bhojn'},
#     'href': 'https://api.spotify.com/v1/tracks/6FwkZ5lYdCUh1mzI1Bhojn',
#     'id': '6FwkZ5lYdCUh1mzI1Bhojn',
#     'is_local': False,
#     'name': 'Le responsable',
#     'popularity': 38,
#     'preview_url': 'https://p.scdn.co/mp3-preview/57a0e4a3ae296a7e3e75205e2d04c76f8394637a?cid=faab70f9c2b24a689a326c3e0be9e549',
#     'track': True,
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:6FwkZ5lYdCUh1mzI1Bhojn'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2021-09-22T07:51:17Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/1269546383'},
#     'href': 'https://api.spotify.com/v1/users/1269546383',
#     'id': '1269546383',
#     'type': 'user',
#     'uri': 'spotify:user:1269546383'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2AR42Ur9PcchQDtEdwkv4L'},
#        'href': 'https://api.spotify.com/v1/artists/2AR42Ur9PcchQDtEdwkv4L',
#        'id': '2AR42Ur9PcchQDtEdwkv4L',
#        'name': 'Floating Points',
#        'type': 'artist',
#        'uri': 'spotify:artist:2AR42Ur9PcchQDtEdwkv4L'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
# ...
#        'width': 64}],
#      'name': 'Eu Vou Fazer uma Macumba Pra Te Amarrar, Maldito!',
#      'release_date': '2015-02-22',
#      'release_date_precision': 'day',
#      'total_tracks': 11,
#      'type': 'album',
#      'uri': 'spotify:album:0kelpiZssyYlVNks8cHEth'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7qmf5YAQYjfjBF9C7kkjzs'},
#       'href': 'https://api.spotify.com/v1/artists/7qmf5YAQYjfjBF9C7kkjzs',
#       'id': '7qmf5YAQYjfjBF9C7kkjzs',
#       'name': 'Johnny Hooker',
#       'type': 'artist',
#       'uri': 'spotify:artist:7qmf5YAQYjfjBF9C7kkjzs'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 285000,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'uscgh1563538'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/7uSdpAkxgB0948bW7yjjJO'},
#     'href': 'https://api.spotify.com/v1/tracks/7uSdpAkxgB0948bW7yjjJO',
#     'id': '7uSdpAkxgB0948bW7yjjJO',
#     'is_local': False,
#     'name': 'Amor Marginal',
#     'popularity': 50,
#     'preview_url': 'https://p.scdn.co/mp3-preview/d763ebf13b84079b55cbee99c0c2fb29c0938ff7?cid=faab70f9c2b24a689a326c3e0be9e549',
#     'track': True,
#     'track_number': 5,
#     'type': 'track',
#     'uri': 'spotify:track:7uSdpAkxgB0948bW7yjjJO'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2021-09-22T07:53:52Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/shokoshock'},
#     'href': 'https://api.spotify.com/v1/users/shokoshock',
#     'id': 'shokoshock',
#     'type': 'user',
#     'uri': 'spotify:user:shokoshock'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0YMeriqrS3zgsX24nfY0F0'},
#        'href': 'https://api.spotify.com/v1/artists/0YMeriqrS3zgsX24nfY0F0',
#        'id': '0YMeriqrS3zgsX24nfY0F0',
#        'name': 'The Tragically Hip',
#        'type': 'artist',
#        'uri': 'spotify:artist:0YMeriqrS3zgsX24nfY0F0'}],
#      'available_markets': [],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/6fRGXiRnTyLLRDXpXkrK1n'},
#      'href': 'https://api.spotify.com/v1/albums/6fRGXiRnTyLLRDXpXkrK1n',
#      'id': '6fRGXiRnTyLLRDXpXkrK1n',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273eb5ebaaa20f7d208ce1caa14',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02eb5ebaaa20f7d208ce1caa14',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851eb5ebaaa20f7d208ce1caa14',
#        'width': 64}],
#      'name': 'Yer Favourites',
#      'release_date': '2005-01-01',
#      'release_date_precision': 'day',
#      'total_tracks': 37,
#      'type': 'album',
#      'uri': 'spotify:album:6fRGXiRnTyLLRDXpXkrK1n'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0YMeriqrS3zgsX24nfY0F0'},
#       'href': 'https://api.spotify.com/v1/artists/0YMeriqrS3zgsX24nfY0F0',
#       'id': '0YMeriqrS3zgsX24nfY0F0',
#       'name': 'The Tragically Hip',
#       'type': 'artist',
#       'uri': 'spotify:artist:0YMeriqrS3zgsX24nfY0F0'}],
#     'available_markets': [],
#     'disc_number': 1,
#     'duration_ms': 225426,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'CAM199600015'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/5nC2BQzszGGkZi7cvxFzH4'},
#     'href': 'https://api.spotify.com/v1/tracks/5nC2BQzszGGkZi7cvxFzH4',
#     'id': '5nC2BQzszGGkZi7cvxFzH4',
#     'is_local': False,
#     'name': 'Ahead By A Century',
#     'popularity': 0,
#     'preview_url': None,
#     'track': True,
#     'track_number': 6,
#     'type': 'track',
#     'uri': 'spotify:track:5nC2BQzszGGkZi7cvxFzH4'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2021-09-22T13:02:30Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/vaxgmeceb7pigybrcc3fdlhiw'},
#     'href': 'https://api.spotify.com/v1/users/vaxgmeceb7pigybrcc3fdlhiw',
#     'id': 'vaxgmeceb7pigybrcc3fdlhiw',
#     'type': 'user',
#     'uri': 'spotify:user:vaxgmeceb7pigybrcc3fdlhiw'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7zsin6IgVsR1rqSRCNYDwq'},
#        'href': 'https://api.spotify.com/v1/artists/7zsin6IgVsR1rqSRCNYDwq',
#        'id': '7zsin6IgVsR1rqSRCNYDwq',
#        'name': 'Family of the Year',
#        'type': 'artist',
#        'uri': 'spotify:artist:7zsin6IgVsR1rqSRCNYDwq'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/14SCnv027L0HidHq0URIDu'},
#      'href': 'https://api.spotify.com/v1/albums/14SCnv027L0HidHq0URIDu',
#      'id': '14SCnv027L0HidHq0URIDu',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2731980a53c08d4911caa77d249',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e021980a53c08d4911caa77d249',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048511980a53c08d4911caa77d249',
#        'width': 64}],
#      'name': 'Loma Vista',
#      'release_date': '2012-07-10',
#      'release_date_precision': 'day',
#      'total_tracks': 11,
#      'type': 'album',
#      'uri': 'spotify:album:14SCnv027L0HidHq0URIDu'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7zsin6IgVsR1rqSRCNYDwq'},
#       'href': 'https://api.spotify.com/v1/artists/7zsin6IgVsR1rqSRCNYDwq',
#       'id': '7zsin6IgVsR1rqSRCNYDwq',
#       'name': 'Family of the Year',
#       'type': 'artist',
#       'uri': 'spotify:artist:7zsin6IgVsR1rqSRCNYDwq'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 190280,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'CAN111200237'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/6GRDI9suQHikFP6euIXnpq'},
#     'href': 'https://api.spotify.com/v1/tracks/6GRDI9suQHikFP6euIXnpq',
#     'id': '6GRDI9suQHikFP6euIXnpq',
#     'is_local': False,
#     'name': 'Hero',
#     'popularity': 66,
#     'preview_url': 'https://p.scdn.co/mp3-preview/3d1f4e7938a250e489290ca27e1ebc9b511c1cf4?cid=faab70f9c2b24a689a326c3e0be9e549',
#     'track': True,
#     'track_number': 5,
#     'type': 'track',
#     'uri': 'spotify:track:6GRDI9suQHikFP6euIXnpq'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2021-09-29T14:22:09Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/8em1nqrnfspx3alyw0rz3ggn1'},
#     'href': 'https://api.spotify.com/v1/users/8em1nqrnfspx3alyw0rz3ggn1',
#     'id': '8em1nqrnfspx3alyw0rz3ggn1',
#     'type': 'user',
#     'uri': 'spotify:user:8em1nqrnfspx3alyw0rz3ggn1'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/58r1rB5t3VF5X6yXGPequV'},
#        'href': 'https://api.spotify.com/v1/artists/58r1rB5t3VF5X6yXGPequV',
#        'id': '58r1rB5t3VF5X6yXGPequV',
#        'name': 'Maverick City Music',
#        'type': 'artist',
#        'uri': 'spotify:artist:58r1rB5t3VF5X6yXGPequV'}],
#      'available_markets': [],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/0prxUuXzlIyjSJU9ej003n'},
#      'href': 'https://api.spotify.com/v1/albums/0prxUuXzlIyjSJU9ej003n',
#      'id': '0prxUuXzlIyjSJU9ej003n',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2732176cda6fb0f4db7dbb6f1fb',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e022176cda6fb0f4db7dbb6f1fb',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048512176cda6fb0f4db7dbb6f1fb',
#        'width': 64}],
#      'name': 'Maverick City Vol. 3 Part 1',
#      'release_date': '2020-04-17',
#      'release_date_precision': 'day',
#      'total_tracks': 11,
#      'type': 'album',
#      'uri': 'spotify:album:0prxUuXzlIyjSJU9ej003n'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/58r1rB5t3VF5X6yXGPequV'},
#       'href': 'https://api.spotify.com/v1/artists/58r1rB5t3VF5X6yXGPequV',
#       'id': '58r1rB5t3VF5X6yXGPequV',
#       'name': 'Maverick City Music',
#       'type': 'artist',
#       'uri': 'spotify:artist:58r1rB5t3VF5X6yXGPequV'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/5nO7Yt0Jon48sqKR6VME4T'},
#       'href': 'https://api.spotify.com/v1/artists/5nO7Yt0Jon48sqKR6VME4T',
#       'id': '5nO7Yt0Jon48sqKR6VME4T',
#       'name': 'Joe L Barnes',
#       'type': 'artist',
#       'uri': 'spotify:artist:5nO7Yt0Jon48sqKR6VME4T'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/4rc8nzClXj7sUjvsHVg6AD'},
#       'href': 'https://api.spotify.com/v1/artists/4rc8nzClXj7sUjvsHVg6AD',
#       'id': '4rc8nzClXj7sUjvsHVg6AD',
#       'name': 'Naomi Raine',
#       'type': 'artist',
#       'uri': 'spotify:artist:4rc8nzClXj7sUjvsHVg6AD'}],
#     'available_markets': [],
#     'disc_number': 1,
#     'duration_ms': 646239,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'TCAET2042835'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/0aZFEiDKLK2B4gzPaGCZVm'},
#     'href': 'https://api.spotify.com/v1/tracks/0aZFEiDKLK2B4gzPaGCZVm',
#     'id': '0aZFEiDKLK2B4gzPaGCZVm',
#     'is_local': False,
#     'name': 'Promises',
#     'popularity': 66,
#     'preview_url': None,
#     'track': True,
#     'track_number': 5,
#     'type': 'track',
#     'uri': 'spotify:track:0aZFEiDKLK2B4gzPaGCZVm'},
#    'video_thumbnail': {'url': None}}],
#  'limit': 100,
#  'next': None,
#  'offset': 0,
#  'previous': None,
#  'total': 16}

# %%
my_playlist["items"][0]["track"]["uri"]
# Out:
# 'spotify:track:5Tnx4R7Gwj1LZsfssfzchh'

# %% [markdown]
# ### Audio features
#
# You can check here an explanation of the audio features: https://developer.spotify.com/documentation/web-api/reference/tracks/get-audio-features/

# %%
sp.audio_features("spotify:track:3d9DChrdc6BOeFsbrZ3Is0")
# Out:
# [{'danceability': 0.559,
#   'energy': 0.345,
#   'key': 4,
#   'loudness': -13.496,
#   'mode': 1,
#   'speechiness': 0.0459,
#   'acousticness': 0.0576,
#   'instrumentalness': 0.000105,
#   'liveness': 0.141,
#   'valence': 0.458,
#   'tempo': 84.581,
#   'type': 'audio_features',
#   'id': '3d9DChrdc6BOeFsbrZ3Is0',
#   'uri': 'spotify:track:3d9DChrdc6BOeFsbrZ3Is0',
#   'track_href': 'https://api.spotify.com/v1/tracks/3d9DChrdc6BOeFsbrZ3Is0',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3d9DChrdc6BOeFsbrZ3Is0',
#   'duration_ms': 264307,
#   'time_signature': 4}]

# %% [markdown]
# ### Exercise: Create a function that takes a song name and returns its audio features

# %%
def get_audio_features_from_song_name(song_name):
    song_info = sp.search(q = song_name, limit = 1)
    uri = song_info['tracks']['items'][0]['uri']
    return sp.audio_features(uri)
    
af = get_audio_features_from_song_name("Lateralus")
af
# Out:
# [{'danceability': 0.387,
#   'energy': 0.677,
#   'key': 0,
#   'loudness': -8.399,
#   'mode': 1,
#   'speechiness': 0.084,
#   'acousticness': 0.00108,
#   'instrumentalness': 0.871,
#   'liveness': 0.101,
#   'valence': 0.371,
#   'tempo': 172.812,
#   'type': 'audio_features',
#   'id': '7tvuLLroI0n6uYBWuFig5d',
#   'uri': 'spotify:track:7tvuLLroI0n6uYBWuFig5d',
#   'track_href': 'https://api.spotify.com/v1/tracks/7tvuLLroI0n6uYBWuFig5d',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7tvuLLroI0n6uYBWuFig5d',
#   'duration_ms': 562707,
#   'time_signature': 3}]

# %% [markdown]
# ### Exercise: Collect a big dataframe of songs with their audio features
#
# - Start by looking for a playlist on spotify (it does not have ot be your playlist), and copy its url.
#
# - Extract the audio features for each song on your playlist.
#
# - Now collect the link of many playlists and do the same for all of them.
#
# - Structure the information as a dataframe where each row is a song and the columns are audio features.

# %%
def get_audio_features_for_playlists(playlists):
    
    playlists_audio_features = []
    for playlist in playlists:
        playlist_tracks = sp.playlist_tracks(playlist)

        for item in playlist_tracks['items']:
            song_uri = item['track']['uri']
            audio_features = sp.audio_features(song_uri)
            audio_features[0]['song_name'] = item['track']['name']
            playlists_audio_features.extend(audio_features)
    
    return pd.DataFrame(playlists_audio_features).set_index('song_name')

tool_top_tracks = "https://open.spotify.com/playlist/5SmBNuCObcy75YLIySVxHr?si=8186605e209a45b9"
playlists = [tool_top_tracks]

playlist_song_info = get_audio_features_for_playlists(playlists)
print(playlist_song_info)
# Out:
#                      danceability  energy  key  loudness  mode  speechiness  \
# song_name
# Fear Inoculum               0.319  0.5840    7   -10.122     1       0.0416
# The Grudge                  0.423  0.7950    2    -7.408     1       0.0374
# Stinkfist                   0.286  0.7280    0    -6.608     1       0.0616
# Pneuma                      0.415  0.5300    9    -9.338     0       0.0314
# The Pot                     0.469  0.7900    7    -6.889     1       0.0391
# Prison Sex                  0.490  0.7800   11    -8.535     0       0.1310
# Invincible                  0.459  0.5670    9    -9.133     0       0.0571
# Forty Six & 2               0.375  0.6820    0    -6.898     0       0.0364
# Jambi                       0.475  0.8310    9    -7.419     0       0.0505
# Pushit                      0.354  0.6260    7    -8.437     1       0.0358
# Sweat                       0.338  0.8620    9    -7.599     1       0.0548
# Culling Voices              0.253  0.4490   11   -12.066     0       0.0352
# Right In Two                0.440  0.5680    7    -8.540     1       0.0293
# Parabol                     0.283  0.0489    9   -24.949     1       0.0413
# Parabola                    0.314  0.9290    9    -6.238     1       0.1050
# Descending                  0.330  0.6110   10    -9.571     1       0.0495
# Sober                       0.385  0.6730    2    -8.182     1       0.0329
# Hooker With A Penis         0.250  0.9100    7    -7.363     1       0.1550
# Third Eye                   0.358  0.6280    7    -9.685     1       0.0556
# Opiate                      0.290  0.7280    8    -9.929     1       0.1150
# Schism                      0.567  0.7140    9    -8.512     0       0.0302
# 4°                          0.427  0.7140    9    -7.967     1       0.0520
# Vicarious                   0.506  0.8770    0    -5.730     1       0.0320
# Ænema                       0.335  0.8490    0    -6.927     1       0.3210
# 7empest                     0.323  0.8040    7    -7.397     1       0.0369
# Lateralus                   0.387  0.6770    0    -8.399     1       0.0840
#
#                      acousticness  instrumentalness  liveness  valence  \
# song_name
# Fear Inoculum            0.000959            0.5040    0.0662   0.1540
# The Grudge               0.000162            0.8430    0.2690   0.3070
# Stinkfist                0.000174            0.8360    0.1330   0.4670
# Pneuma                   0.002090            0.7500    0.1100   0.0586
# The Pot                  0.000148            0.3720    0.2820   0.4660
# Prison Sex               0.000288            0.0196    0.1080   0.3870
# Invincible               0.009890            0.7860    0.1090   0.3890
# Forty Six & 2            0.001520            0.5980    0.0897   0.3960
# Jambi                    0.000145            0.8540    0.3460   0.5210
# Pushit                   0.000510            0.5640    0.0798   0.1750
# Sweat                    0.000302            0.7870    0.0961   0.3060
# Culling Voices           0.045200            0.7890    0.1390   0.0386
# Right In Two             0.004420            0.8400    0.1190   0.2480
# Parabol                  0.545000            0.3070    0.0897   0.0886
# Parabola                 0.000020            0.5160    0.1390   0.2850
# Descending               0.002190            0.7690    0.1070   0.2410
# Sober                    0.000183            0.1490    0.0721   0.1870
# Hooker With A Penis      0.001290            0.5530    0.1490   0.2740
# Third Eye                0.005860            0.4710    0.1110   0.2620
# Opiate                   0.000495            0.4020    0.1280   0.0487
# Schism                   0.001200            0.4170    0.1860   0.1910
# 4°                       0.000376            0.6610    0.1870   0.2390
# Vicarious                0.000052            0.7760    0.0712   0.3020
# Ænema                    0.001930            0.2540    0.0928   0.2560
# 7empest                  0.000073            0.8350    0.0957   0.3840
# Lateralus                0.001080            0.8710    0.1010   0.3710
#
#                        tempo            type                      id  \
# song_name
# Fear Inoculum         88.241  audio_features  4XW5PGlQ3S4B8Bti7meocj
# The Grudge            96.045  audio_features  6ZsZxNP4Iwdyp3kd5oFFQN
# Stinkfist            171.441  audio_features  0pwObEOHolQZSldJ2q1wpy
# Pneuma               114.174  audio_features  03sEzk1VyrUZSgyhoQR0LZ
# The Pot              107.450  audio_features  1lATXTBJDHwawvT1UfxWu3
# Prison Sex           108.137  audio_features  6bBfqZW47dwndIfYQcB0VR
# Invincible            87.477  audio_features  2xKDKtJBLDPd7BF3VmSQQO
# Forty Six & 2        159.230  audio_features  6AioOohg4bQZFA4jIYQQ2r
# Jambi                110.420  audio_features  2gbPu2QNqhnnqtfK3yyeZ0
# Pushit               119.582  audio_features  4CbHM5bpfOfMNxNgVDHJRw
# Sweat                152.226  audio_features  3vjHuVFZGC0Bm2Ud0wNpgs
# Culling Voices       156.286  audio_features  3gPxMQWDMSEyPXMtzbcDdQ
# Right In Two         118.389  audio_features  0NLDZzVke3Qu7vDhWyGzRk
# Parabol               76.128  audio_features  3EeoMkZF8NhX9FdCSxG8MB
# Parabola             100.935  audio_features  1vxu8vMNshg5J8z3oA7QJZ
# Descending           172.606  audio_features  0aTiUssEOy0Mt69bsavj6K
# Sober                149.271  audio_features  6DyywdbmTzlmXBzG9ym7Rt
# Hooker With A Penis   90.835  audio_features  3S4G4SL15Cp4CvAfmye8um
# Third Eye            108.441  audio_features  2Dqg2mRbfIVKhBZleNrgmH
# Opiate               162.744  audio_features  6jxVSzwyQflnOfFp7f5EaO
# Schism               107.441  audio_features  55mJleti2WfWEFNFcBduhc
# 4°                   113.603  audio_features  1LXQ7xqksXo4q4r5oCxW7M
# Vicarious            114.589  audio_features  65ShmiE5aLBdcIGr7tHX35
# Ænema                181.716  audio_features  0nLOl4fSiBZKGFla5pLUtf
# 7empest              144.756  audio_features  0gGfmw4csswZmFPj9YK8GW
# Lateralus            172.812  audio_features  7tvuLLroI0n6uYBWuFig5d
#
#                                                       uri  \
# song_name
# Fear Inoculum        spotify:track:4XW5PGlQ3S4B8Bti7meocj
# The Grudge           spotify:track:6ZsZxNP4Iwdyp3kd5oFFQN
# Stinkfist            spotify:track:0pwObEOHolQZSldJ2q1wpy
# Pneuma               spotify:track:03sEzk1VyrUZSgyhoQR0LZ
# The Pot              spotify:track:1lATXTBJDHwawvT1UfxWu3
# Prison Sex           spotify:track:6bBfqZW47dwndIfYQcB0VR
# Invincible           spotify:track:2xKDKtJBLDPd7BF3VmSQQO
# Forty Six & 2        spotify:track:6AioOohg4bQZFA4jIYQQ2r
# Jambi                spotify:track:2gbPu2QNqhnnqtfK3yyeZ0
# Pushit               spotify:track:4CbHM5bpfOfMNxNgVDHJRw
# Sweat                spotify:track:3vjHuVFZGC0Bm2Ud0wNpgs
# Culling Voices       spotify:track:3gPxMQWDMSEyPXMtzbcDdQ
# Right In Two         spotify:track:0NLDZzVke3Qu7vDhWyGzRk
# Parabol              spotify:track:3EeoMkZF8NhX9FdCSxG8MB
# Parabola             spotify:track:1vxu8vMNshg5J8z3oA7QJZ
# Descending           spotify:track:0aTiUssEOy0Mt69bsavj6K
# Sober                spotify:track:6DyywdbmTzlmXBzG9ym7Rt
# Hooker With A Penis  spotify:track:3S4G4SL15Cp4CvAfmye8um
# Third Eye            spotify:track:2Dqg2mRbfIVKhBZleNrgmH
# Opiate               spotify:track:6jxVSzwyQflnOfFp7f5EaO
# Schism               spotify:track:55mJleti2WfWEFNFcBduhc
# 4°                   spotify:track:1LXQ7xqksXo4q4r5oCxW7M
# Vicarious            spotify:track:65ShmiE5aLBdcIGr7tHX35
# Ænema                spotify:track:0nLOl4fSiBZKGFla5pLUtf
# 7empest              spotify:track:0gGfmw4csswZmFPj9YK8GW
# Lateralus            spotify:track:7tvuLLroI0n6uYBWuFig5d
#
#                                                             track_href  \
# song_name
# Fear Inoculum        https://api.spotify.com/v1/tracks/4XW5PGlQ3S4B...
# The Grudge           https://api.spotify.com/v1/tracks/6ZsZxNP4Iwdy...
# Stinkfist            https://api.spotify.com/v1/tracks/0pwObEOHolQZ...
# Pneuma               https://api.spotify.com/v1/tracks/03sEzk1VyrUZ...
# The Pot              https://api.spotify.com/v1/tracks/1lATXTBJDHwa...
# Prison Sex           https://api.spotify.com/v1/tracks/6bBfqZW47dwn...
# Invincible           https://api.spotify.com/v1/tracks/2xKDKtJBLDPd...
# Forty Six & 2        https://api.spotify.com/v1/tracks/6AioOohg4bQZ...
# Jambi                https://api.spotify.com/v1/tracks/2gbPu2QNqhnn...
# Pushit               https://api.spotify.com/v1/tracks/4CbHM5bpfOfM...
# Sweat                https://api.spotify.com/v1/tracks/3vjHuVFZGC0B...
# Culling Voices       https://api.spotify.com/v1/tracks/3gPxMQWDMSEy...
# Right In Two         https://api.spotify.com/v1/tracks/0NLDZzVke3Qu...
# Parabol              https://api.spotify.com/v1/tracks/3EeoMkZF8NhX...
# Parabola             https://api.spotify.com/v1/tracks/1vxu8vMNshg5...
# Descending           https://api.spotify.com/v1/tracks/0aTiUssEOy0M...
# Sober                https://api.spotify.com/v1/tracks/6DyywdbmTzlm...
# Hooker With A Penis  https://api.spotify.com/v1/tracks/3S4G4SL15Cp4...
# Third Eye            https://api.spotify.com/v1/tracks/2Dqg2mRbfIVK...
# Opiate               https://api.spotify.com/v1/tracks/6jxVSzwyQfln...
# Schism               https://api.spotify.com/v1/tracks/55mJleti2WfW...
# 4°                   https://api.spotify.com/v1/tracks/1LXQ7xqksXo4...
# Vicarious            https://api.spotify.com/v1/tracks/65ShmiE5aLBd...
# Ænema                https://api.spotify.com/v1/tracks/0nLOl4fSiBZK...
# 7empest              https://api.spotify.com/v1/tracks/0gGfmw4csswZ...
# Lateralus            https://api.spotify.com/v1/tracks/7tvuLLroI0n6...
#
#                                                           analysis_url  \
# song_name
# Fear Inoculum        https://api.spotify.com/v1/audio-analysis/4XW5...
# The Grudge           https://api.spotify.com/v1/audio-analysis/6ZsZ...
# Stinkfist            https://api.spotify.com/v1/audio-analysis/0pwO...
# Pneuma               https://api.spotify.com/v1/audio-analysis/03sE...
# The Pot              https://api.spotify.com/v1/audio-analysis/1lAT...
# Prison Sex           https://api.spotify.com/v1/audio-analysis/6bBf...
# Invincible           https://api.spotify.com/v1/audio-analysis/2xKD...
# Forty Six & 2        https://api.spotify.com/v1/audio-analysis/6Aio...
# Jambi                https://api.spotify.com/v1/audio-analysis/2gbP...
# Pushit               https://api.spotify.com/v1/audio-analysis/4CbH...
# Sweat                https://api.spotify.com/v1/audio-analysis/3vjH...
# Culling Voices       https://api.spotify.com/v1/audio-analysis/3gPx...
# Right In Two         https://api.spotify.com/v1/audio-analysis/0NLD...
# Parabol              https://api.spotify.com/v1/audio-analysis/3Eeo...
# Parabola             https://api.spotify.com/v1/audio-analysis/1vxu...
# Descending           https://api.spotify.com/v1/audio-analysis/0aTi...
# Sober                https://api.spotify.com/v1/audio-analysis/6Dyy...
# Hooker With A Penis  https://api.spotify.com/v1/audio-analysis/3S4G...
# Third Eye            https://api.spotify.com/v1/audio-analysis/2Dqg...
# Opiate               https://api.spotify.com/v1/audio-analysis/6jxV...
# Schism               https://api.spotify.com/v1/audio-analysis/55mJ...
# 4°                   https://api.spotify.com/v1/audio-analysis/1LXQ...
# Vicarious            https://api.spotify.com/v1/audio-analysis/65Sh...
# Ænema                https://api.spotify.com/v1/audio-analysis/0nLO...
# 7empest              https://api.spotify.com/v1/audio-analysis/0gGf...
# Lateralus            https://api.spotify.com/v1/audio-analysis/7tvu...
#
#                      duration_ms  time_signature
# song_name
# Fear Inoculum             621027               4
# The Grudge                515080               5
# Stinkfist                 312120               4
# Pneuma                    713192               1
# The Pot                   381947               4
# Prison Sex                296320               4
# Invincible                764457               1
# Forty Six & 2             363067               4
# Jambi                     448613               3
# Pushit                    595613               3
# Sweat                     227173               4
# Culling Voices            605369               3
# Right In Two              535800               3
# Parabol                   184573               4
# Parabola                  363680               4
# Descending                817832               1
# Sober                     306853               4
# Hooker With A Penis       273827               3
# Third Eye                 831440               4
# Opiate                    510587               4
# Schism                    403533               3
# 4°                        362890               5
# Vicarious                 426680               5
# Ænema                     399267               3
# 7empest                   943529               5
# Lateralus                 562707               3
