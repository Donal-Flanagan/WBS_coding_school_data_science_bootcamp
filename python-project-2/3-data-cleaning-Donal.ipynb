# %% [markdown]
# ## Import the data

# %%
import pandas as pd
import numpy as np
import re

path = '../data/eniac/'
orderlines = pd.read_csv(path + 'orderlines.csv')
orders = pd.read_csv(path + 'orders.csv')
brands = pd.read_csv(path + 'brands.csv')
products = pd.read_csv(path + 'products.csv')

df_list = [orderlines, orders, brands, products]
files = ['orderlines','orders','brands','products']

orders['created_date'] = pd.to_datetime(orders['created_date'])
orderlines['date'] = pd.to_datetime(orderlines['date'])

# %% [markdown]
# ## Clean orders

# %%
# Remove nan values
orders_before = orders.shape[0]
orders.dropna(inplace=True)
orders_after = orders.shape[0]

rows_removed_from_orders = orders_before - orders_after
print(f'{rows_removed_from_orders} rows were removed from orders after removing NaN values')
print(f'This represents {round(rows_removed_from_orders/orders_before*100, 2)}% of the data')


# Remove 22213 order ids in orders that aren't in orderlines
orders_before = orders.shape[0]
orders = orders[orders.order_id.isin(orderlines.id_order)]
orders_after = orders.shape[0]
rows_removed_from_orders = orders_before - orders_after

# Of the order ids in orders but not in orderlines, 12304 orders have state = Place Order and 
# 9810 have state = Shopping Basket for a total of 22114.
# There are a total of 40883 orders with state = Place Order and 117809 with state = Shopping Basket.
print('\n')
print(f'{rows_removed_from_orders} rows were removed from orders after removing order_ids which do not exist in orderlines')
print(f'This represents {round(rows_removed_from_orders/orders_before*100, 2)}% of the data')

orders.to_csv(path + 'orders_clean.csv', index=False)
# Out:
# 5 rows were removed from orders after removing NaN values
# This represents 0.0% of the data
#
#
# 22213 rows were removed from orders after removing order_ids which do not exist in orderlines
# This represents 9.79% of the data

# %% [markdown]
# ## Clean products

# %%
# Drop the type and in_stock columns 
products.drop('type', axis=1, inplace=True, errors='ignore')
products.drop('in_stock', axis=1, inplace=True, errors='ignore')
#  Drop duplicate rows based on sku value
products.drop_duplicates(subset='sku', inplace=True)
# Check for products without descriptions
names_of_products_without_descriptions = products[products.desc.isna()].name.tolist()
# Add missing descriptions
missing_descriptions = [
    '2TB Mac hard drive and Nas',
    'Apple keyboard for iPad 9.7',
    'NAS server with 10GB RAM',
    'Ethernet adapter for Macbook 12',
    'Luxury power bank combined with powder, 2 mirrors - normal and 3x magnification, Illuminated under mirror with LED, Low weight and compact dimensions',
    'Battery capacity: 20,000 mAh; ultra-stable: outer shell made of durable synthetic rubber (military standard, withstands drops from up to 2 metres) ; protection: dust and splash proof: military standard iP54; battery level indicator and super fast charging; USB port can be connected to charger and other devices',
    'Smart thermostat designed to provide automatic time and temperature control of heating systems in homes and apartments. '
]
for i in range(len(names_of_products_without_descriptions)):
    products.loc[products.name == names_of_products_without_descriptions[i], 'desc'] = missing_descriptions[i]

# Clean the price and promo_price columns
def start_pipeline(df):
    '''Make a copy of the pipeline to prevent corrupting the original data'''
    return df.copy()

def remove_duplicates(df, col):
    '''Remove duplicate rows'''
    return df[~df[col].isna()]

def clean_prices(df):
        df.price = df.price.apply(lambda x : x +'.00' if x.count('.') == 0 else x)
        df.price = df.price.apply(lambda x: x  + '0' if x[-2]=='.' else x)
        df.price = df.price.apply(lambda x: str(float(x.replace('.',''))/1000) if ( (x[-4]=='.') & (x.count('.')==2)) else x)
        df.price = df.price.apply(lambda x: str(float(x.replace('.',''))/10000) if ( (x[-4]=='.') & (x.count('.')==1)) else x)
        df.price = df.price.astype(float)
        df.price = df.price.round(decimals = 2)
        return df

def split_and_join_promo_prices(df):
    '''Remove the decimal points from the promo_price strings and append .00 to the string'''
    return df.assign(promo_price=df.promo_price
                     .str.split('.')
                     .str.join('')
                     .apply(lambda x: x+'.00')
                    )

def _insert_decimal_at_string_position(s, pos):
    '''Insert a decimal point at a given position in a string'''
    s = s.split('.')
    s = s[0] + s[1]
    s = s[:pos]+'.'+s[pos:]
    return s 


def _insert_decimal_in_promo_price(row):
    '''
    If the euro value of the price is equal to the euro value of the promo_price, 
    set the promo_price equal to price and return it.
    This is because some promo_prices are slightly larger than their equivalent prices, e.g. 12.95 - 12.99
    
    Otherwise, keep moving the decimal point towards the start of the string until the promo_price is lower than the price.
    Then transform the string to a float and round it to two decimal places.
    '''
    
    decimal_position = -2
    while float(row.promo_price) > row.price:
        if round(float(row.promo_price), 0) == round(row.price, 0):
            row.promo_price = row.price
            return row.promo_price
        else:
            row.promo_price = _insert_decimal_at_string_position(row.promo_price, decimal_position)
            decimal_position += -1
    
    return round(float(row.promo_price), 2)

def transform_promo_price_to_floats(df):
    df.promo_price = [_insert_decimal_in_promo_price(row) for index, row in df.iterrows()]
    return df

def calculate_products_discounts(df):
    return df.assign(
        discount=round(df.price - df.promo_price, 2),
        discount_pc = round((df.price - df.promo_price)/df.price * 100, 2)
    )

products = (products
        .pipe(start_pipeline)
        .pipe(remove_duplicates,col='price')
        .pipe(clean_prices)
        .pipe(split_and_join_promo_prices)
        .pipe(transform_promo_price_to_floats)
        .pipe(calculate_products_discounts)
)

# Manually fix the last of the incorrect prices
products.loc[products['sku'] == 'DJI0025', ['price', 'promo_price']] = 849.00
products.loc[products['sku'] == 'TAD0008', ['price', 'promo_price']] = 179.99
products.loc[products['sku'] == 'IOT0018', ['price', 'promo_price']] = 24.99
products.loc[products['sku'] == 'APP2490', ['price', 'promo_price']] = 1599.00
products.loc[products['sku'] == 'KIN0150', ['price', 'promo_price']] = 17.28
products.loc[products['sku'] == 'REP0185', ['price', 'promo_price']] = 69.99
products.loc[products['sku'] == 'APP1477', ['price', 'promo_price']] = 490.33

products.to_csv(path + 'products_clean.csv', index=False)
products
# Out:
#            sku                                           name  \
# 0      RAI0007              Silver Rain Design mStand Support
# 1      APP0023              Apple Mac Keyboard Keypad Spanish
# 2      APP0025               Mighty Mouse Apple Mouse for Mac
# 3      APP0072  Apple Dock to USB Cable iPhone and iPod white
# 4      KIN0007    Mac Memory Kingston 2GB 667MHz DDR2 SO-DIMM
# ...        ...                                            ...
# 19321  BEL0376        Belkin Travel Support Apple Watch Black
# 19322  THU0060   Enroute Thule 14L Backpack MacBook 13 "Black
# 19323  THU0061    Enroute Thule 14L Backpack MacBook 13 "Blue
# 19324  THU0062     Enroute Thule 14L Backpack MacBook 13 "Red
# 19325  THU0063   Enroute Thule 14L Backpack MacBook 13 "Green
#
#                                                     desc  price  promo_price  \
# 0           Aluminum support compatible with all MacBook  59.99        49.99
# 1              USB ultrathin keyboard Apple Mac Spanish.  59.00        59.00
# 2                                 mouse Apple USB cable.  59.00        56.99
# 3                  IPhone dock and USB Cable Apple iPod.  25.00        23.00
# 4      2GB RAM Mac mini and iMac (2006/07) MacBook Pr...  34.99        31.99
# ...                                                  ...    ...          ...
# 19321  compact and portable stand vertically or horiz...  29.99        26.99
# 19322  Backpack with capacity of 14 liter compartment...  69.95        64.99
# 19323  Backpack with capacity of 14 liter compartment...  69.95        64.99
# 19324  Backpack with capacity of 14 liter compartment...  69.95        64.99
# 19325  Backpack with capacity of 14 liter compartment...  69.95        64.99
#
#        discount  discount_pc
# 0         10.00        16.67
# 1          0.00         0.00
# 2          2.01         3.41
# 3          2.00         8.00
# 4          3.00         8.57
# ...         ...          ...
# 19321      3.00        10.00
# 19322      4.96         7.09
# 19323      4.96         7.09
# 19324      4.96         7.09
# 19325      4.96         7.09
#
# [10534 rows x 7 columns]

# %% [markdown]
# ## Clean orderlines

# %%
# Remove 240 order ids in orderlines that aren't in orders
orderlines_before = orderlines.shape[0]
orderlines = orderlines[orderlines.id_order.isin(orders.order_id)].copy()
orderlines_after = orderlines.shape[0]
rows_removed_from_orderlines = orderlines_before - orderlines_after

print(f'{rows_removed_from_orderlines} rows were removed from orderlines after removing unmatched order_ids')
print(f'This represents {round(rows_removed_from_orderlines/orderlines_before*100, 2)}% of the data')


# Drop the product_id column because it contains no info
orderlines.drop('product_id', axis=1, inplace=True, errors='ignore')

# Transform the unit_price price column to floats
def transform_unit_price_to_floats(df):
    return (
        df.assign(unit_price = df.unit_price.str.split('.')
                  .apply(lambda x : x[0]+x[1]+'.'+x[2] if len(x)==3 else x[0]+'.'+ x[1])
                  .astype(float)
        )
    )

orderlines = (orderlines
              .pipe(start_pipeline)
              .pipe(transform_unit_price_to_floats)
             )

# Drop these corrupted orders
orderlines = orderlines.loc[~(orderlines.unit_price==6.59)]

orderlines.to_csv(path + 'orderlines_clean.csv', index=False)

orderlines
# Out:
# 240 rows were removed from orderlines after removing unmatched order_ids
# This represents 0.08% of the data
#              id  id_order  product_quantity      sku  unit_price  \
# 0       1119109    299539                 1  OTT0133       18.99
# 1       1119110    299540                 1  LGE0043      399.00
# 2       1119111    299541                 1  PAR0071      474.05
# 3       1119112    299542                 1  WDT0315       68.39
# 4       1119113    299543                 1  JBL0104       23.74
# ...         ...       ...               ...      ...         ...
# 293978  1650199    527398                 1  JBL0122       42.99
# 293979  1650200    527399                 1  PAC0653      141.58
# 293980  1650201    527400                 2  APP0698        9.99
# 293981  1650202    527388                 1  BEZ0204       19.99
# 293982  1650203    527401                 1  APP0927       13.99
#
#                       date
# 0      2017-01-01 00:07:19
# 1      2017-01-01 00:19:45
# 2      2017-01-01 00:20:57
# 3      2017-01-01 00:51:40
# 4      2017-01-01 01:06:38
# ...                    ...
# 293978 2018-03-14 13:57:25
# 293979 2018-03-14 13:57:34
# 293980 2018-03-14 13:57:41
# 293981 2018-03-14 13:58:01
# 293982 2018-03-14 13:58:36
#
# [293548 rows x 6 columns]

# %% [markdown]
# ## Merge with products to compare discounts

# %%
sales_info = (
orderlines
    .merge(products, how='inner', on='sku')
)

def calculate_sales_discounts(df):
    return (df
            .assign(
                sales_discount=round(df.price - df.unit_price, 2),
                sales_discount_pc = round((df.price - df.unit_price)/df.price * 100, 2)
            )
           )

def merge_brands(df):
    return (df
            .assign(short = lambda row: row['sku'].str[:3])
            .merge(brands, on='short')
           )

def rename_columns(df):
    return (df
            .rename(columns={'long': 'brand', 'unit_price': 'sale_price', 'id_order': 'order_id'})
           )

def merge_orders(df):
    return (df
            .merge(orders, on='order_id')
    )

def drop_deprecated_columns(df):
    return (df
            .drop(['short', 'created_date'], axis=1)
           )

def assign_product_categories(df):
    apple_regexp_dict = {
        'iPod': '^.{0,7}apple ipod',
        'iPhone':  'apple iphone',
        'iPad':  'apple ipad',
        'Mac':  'apple macbook|apple iMac|apple Mac mini|desktop computer',
    }
    
    other_regexp_dict = {        
        'Smartwatch':'withings|watch|fitbit|apple watch|smartwatch|smart watch',
        'Accessories': 'kit|strap|armband|belt|bracelet|stylus|pen|Bamboo Wacom Intuos|pencil|pen|rubber pointers|screwdriver|case|funda|housing|casing|folder|bag|backpack|cable|connector|Lightning to USB|Wall socket|power strip|adapter|battery|headset|headphones|mouse|trackpad|stand|support|protect|cover|sleeve|Screensaver|shellhub|dock|microphone|keyboard|keypad',
        'Hardware': 'Philips Hue|temperature sensor|display|monitor|camera|charger|speaker|router|repeater|Synology|nas|server|Parrot FPV Glasses|Command Pack 2 Skycontroller|Apple TV',
        'Software':  'adobe|Office 365|Office Home and Student|software|parallels',
        'Memory': 'hard disk|hard drive|flash drive|USB 2.0 key|USB 2.0 pen|SSD|pendrive|raid|SDHC|sata|memory card|Portable Hard Thunderbolt',
        'Repairs & warranties': 'repair|parts and labor|warranty|applecare|license|protection|installation',
    }
    

    df = df.assign(category = 'unknown')
    
    # Find main apple items
    for label, val in apple_regexp_dict.items(): 
        regexp = re.compile(val, flags=re.IGNORECASE)
        df = (
            df
            .assign(
                category = lambda x: np.where(
                    ((x['desc'].str.contains(regexp, regex=True))|(x['name'].str.contains(regexp, regex=True))) &
                    (x['category'] == 'unknown') & (x['brand'] == 'Apple'), 
                    label, x['category'])
            )
        )
    
    # Find other items
    for label, val in other_regexp_dict.items(): 
        regexp = re.compile(val, flags=re.IGNORECASE)
        df = (
            df
            .assign(
                category = lambda x: np.where(
                    ((x['desc'].str.contains(regexp, regex=True))|(x['name'].str.contains(regexp, regex=True))) &
                    (x['category'] == 'unknown'), label, x['category'])
            )
        )
    
    return df


sales_info = (sales_info
              .pipe(start_pipeline)
              .pipe(calculate_sales_discounts)
              .pipe(merge_brands)
              .pipe(rename_columns)
              .pipe(merge_orders)
              .pipe(drop_deprecated_columns)
              .pipe(assign_product_categories)
             )


# Drop any order which are not completed to minimise corrupted data
sales_info = sales_info.loc[sales_info.state=='Completed']

sales_info.to_csv(path + 'sales_info_clean.csv', index=False)
    
sales_info['category'].value_counts()
# Out:
# Accessories             30123
# Memory                   7183
# unknown                  7121
# Hardware                 6202
# iPhone                   3823
# Smartwatch               2913
# Mac                      2652
# iPad                     1432
# Repairs & warranties      109
# Software                   60
# iPod                       54
# Name: category, dtype: int64

# %%
pd.options.display.max_rows = 500
pd.options.display.max_columns = 500
check_df = sales_info[sales_info['category']=='unknown'][['name', 'desc']]
#check_df.groupby(check_df.columns.tolist(),as_index=False).size().sort_values('size', ascending=False)

# %%
# sales_info[sales_info['sku'].isin(['APP2348', 'APP2201', 'APP2117', 'APP2358'])]
# sales_info[sales_info['order_id']==514441]
sales_info[sales_info['sales_discount_pc']>90].sort_values('sales_discount_pc').head(500)
# Out:
#              id  order_id  product_quantity        sku  sale_price  \
# 97103   1257935    360505                 1    APP1498      829.00
# 245063  1255349    359317                 1    TRA0011       44.99
# 251754  1182971    325187                 1    SAN0138       49.99
# 251751  1150767    311402                 1    SAN0138       49.99
# 245082  1519037    473423                 1    TRA0011       43.28
# 190861  1522661    475203                 1    WAC0235       18.99
# 190860  1519901    473855                 1    WAC0235       18.99
# 186775  1527010    477240                 1    WAC0235       18.99
# 144394  1402693    424462                 1    APP2494      208.05
# 26682   1406083    329976                 1    APP2494      208.05
# 144396  1404400    425312                 1    APP2494      208.05
# 239817  1127696    302095                 1    TRA0039       42.99
# 244728  1131349    303211                 1    TRA0039       42.99
# 244743  1419170    430604                 1    TRA0039       42.11
# 245080  1438864    439928                 1    TRA0011       42.13
# 206730  1451045    445143                 1    TRA0011       42.13
# 244745  1429498    435397                 1    TRA0039       42.13
# 24665   1567723    493608                 1    JBL0147       22.99
# 24653   1452958    445960                 1    JBL0147       22.99
# 19859   1303228    382405                 2  WDT0135-A       11.84
# 265383  1453642    446237                 1    REP0365       62.99
# 265470  1426567    434054                 1    REP0362       62.99
# 251598  1277111    370047                 1  SAN0131-A       56.93
# 251766  1257273    360207                 1    SAN0138       44.99
# 251763  1245072    354461                 3    SAN0138       44.99
# 251755  1228363    346326                 1    SAN0138       44.99
# 144390  1400733    423503                 1    APP2494      180.99
# 144402  1512902    470483                 1    APP2494      180.99
# 208800  1616542    508741                 2    MOP0108        3.99
# 208696  1616569    512773                 2    MOP0108        3.99
# 208786  1616321    512680                 2    MOP0109        3.99
# 208787  1616329    512641                 2    MOP0109        3.99
# 209047  1616465    512742                 2    MOP0108        3.99
# 209046  1616455    512739                 2    MOP0108        3.99
# 208799  1616547    508741                 2    MOP0109        3.99
# 208898  1615967    512522                 2    MOP0107        3.99
# 208900  1615984    512531                 2    MOP0107        3.99
# 208802  1616631    512807                 2    MOP0109        3.99
# 208804  1616643    511204                 2    MOP0109        3.99
# 208788  1616413    512641                 2    MOP0108        3.99
# 208918  1616190    256799                 2    MOP0107        3.99
# 208916  1616180    512618                 2    MOP0107        3.99
# 208901  1615998    512536                 2    MOP0107        3.99
# 208956  1615833    512456                 2    MOP0105        4.99
# 208968  1615983    512530                 2    MOP0106        4.99
# 208944  1615816    512444                 2    MOP0106        4.99
# 208955  1615863    512456                 2    MOP0106        4.99
# 208971  1616085    512568                 2    MOP0105        4.99
# 208970  1616088    512568                 2    MOP0106        4.99
# 208994  1616047    512556                 2    MOP0105        4.99
# 208819  1616772    512871                 3    MOP0109        2.66
# 208777  1615756    512413                 3    MOP0107        2.66
# 199355  1617061    513009                20    NTE0013        1.00
# 208817  1616752    512862                 2    MOP0109        2.00
# 208773  1615825    512451                 5    MOP0107        1.60
# 208894  1615921    512498                 5    MOP0107        1.60
# 248054  1253375    358440                 1    SEV0018        0.01
# 157832  1258848    359758                 1    SEV0021        0.01
#
#                       date                                               name  \
# 97103  2017-05-30 10:19:14   Apple iPad Pro 9.7 "Wi-Fi + Cellular 32GB Silver
# 245063 2017-05-26 09:54:58  Transcend JetDrive Lite 330 64GB Macbook Pro R...
# 251754 2017-02-16 12:42:14  SanDisk Ultra microSDXC 128GB Memory Card + SD...
# 251751 2017-01-18 08:46:54  SanDisk Ultra microSDXC 128GB Memory Card + SD...
# 245082 2017-12-27 14:13:19  Transcend JetDrive Lite 330 64GB Macbook Pro R...
# 190861 2017-12-28 17:39:05               Wacom Intuos 4 Case Transport size S
# 190860 2017-12-27 19:39:43               Wacom Intuos 4 Case Transport size S
# 186775 2017-12-30 11:55:22               Wacom Intuos 4 Case Transport size S
# 144394 2017-11-10 12:02:59                                   Apple TV 4K 64GB
# 26682  2017-11-12 22:39:58                                   Apple TV 4K 64GB
# 144396 2017-11-11 15:41:30                                   Apple TV 4K 64GB
# 239817 2017-01-03 22:39:28  Transcend JetDrive Lite 130 64GB Macbook Air 13 "
# 244728 2017-01-05 14:38:24  Transcend JetDrive Lite 130 64GB Macbook Air 13 "
# 244743 2017-11-21 20:29:33  Transcend JetDrive Lite 130 64GB Macbook Air 13 "
# 245080 2017-11-24 16:12:39  Transcend JetDrive Lite 330 64GB Macbook Pro R...
# 206730 2017-11-26 12:59:50  Transcend JetDrive Lite 330 64GB Macbook Pro R...
# 244745 2017-11-23 18:30:27  Transcend JetDrive Lite 130 64GB Macbook Air 13 "
# 24665  2018-01-18 15:10:38        Headband Headphones JBL children JR300 Blue
# 24653  2017-11-26 19:14:21        Headband Headphones JBL children JR300 Blue
# 19859  2017-07-26 16:43:33  Open - Western Digital Network PC and Mac 3TB ...
# 265383 2017-11-26 21:23:18                iPad mini charging connector repair
# 265470 2017-11-23 10:54:25                           iPad mini battery repair
# 251598 2017-06-28 18:46:03     Open - SanDisk 120GB SSD Plus 25 "SATA 6Gb / s
# 251766 2017-05-29 14:00:37  SanDisk Ultra microSDXC 128GB Memory Card + SD...
# 251763 2017-05-10 12:02:09  SanDisk Ultra microSDXC 128GB Memory Card + SD...
# 251755 2017-04-15 14:21:20  SanDisk Ultra microSDXC 128GB Memory Card + SD...
# 144390 2017-11-08 17:09:31                                   Apple TV 4K 64GB
# 144402 2017-12-23 21:36:09                                   Apple TV 4K 64GB
# 208800 2018-02-16 11:16:53  Mophie Powerstation Mini Universal 4000mAh Bat...
# 208696 2018-02-16 11:25:43  Mophie Powerstation Mini Universal 4000mAh Bat...
# 208786 2018-02-16 10:09:30  Mophie Powerstation Mini Universal 4000mAh Bat...
# 208787 2018-02-16 10:13:35  Mophie Powerstation Mini Universal 4000mAh Bat...
# 209047 2018-02-16 10:52:53  Mophie Powerstation Mini Universal 4000mAh Bat...
# 209046 2018-02-16 10:50:02  Mophie Powerstation Mini Universal 4000mAh Bat...
# 208799 2018-02-16 11:17:57  Mophie Powerstation Mini Universal 4000mAh Bat...
# 208898 2018-02-16 09:03:35  Mophie Powerstation 4000mAh Battery Plus Mini ...
# 208900 2018-02-16 09:06:25  Mophie Powerstation 4000mAh Battery Plus Mini ...
# 208802 2018-02-16 11:54:59  Mophie Powerstation Mini Universal 4000mAh Bat...
# 208804 2018-02-16 11:58:55  Mophie Powerstation Mini Universal 4000mAh Bat...
# 208788 2018-02-16 10:36:40  Mophie Powerstation Mini Universal 4000mAh Bat...
# 208918 2018-02-16 09:42:27  Mophie Powerstation 4000mAh Battery Plus Mini ...
# 208916 2018-02-16 09:40:49  Mophie Powerstation 4000mAh Battery Plus Mini ...
# 208901 2018-02-16 09:08:53  Mophie Powerstation 4000mAh Battery Plus Mini ...
# 208956 2018-02-16 08:37:17  Mophie Powerstation 6000mAh battery Universal ...
# 208968 2018-02-16 09:06:25  Mophie Powerstation 6000mAh battery Universal ...
# 208944 2018-02-16 08:33:54  Mophie Powerstation 6000mAh battery Universal ...
# 208955 2018-02-16 08:42:41  Mophie Powerstation 6000mAh battery Universal ...
# 208971 2018-02-16 09:19:49  Mophie Powerstation 6000mAh battery Universal ...
# 208970 2018-02-16 09:20:26  Mophie Powerstation 6000mAh battery Universal ...
# 208994 2018-02-16 09:15:23  Mophie Powerstation 6000mAh battery Universal ...
# 208819 2018-02-16 12:56:02  Mophie Powerstation Mini Universal 4000mAh Bat...
# 208777 2018-02-16 08:21:05  Mophie Powerstation 4000mAh Battery Plus Mini ...
# 199355 2018-02-16 17:28:59    AdaptaDrive NewerTech adapter 2.5 "to 3.5" SATA
# 208817 2018-02-16 12:47:23  Mophie Powerstation Mini Universal 4000mAh Bat...
# 208773 2018-02-16 08:35:43  Mophie Powerstation 4000mAh Battery Plus Mini ...
# 208894 2018-02-16 08:54:42  Mophie Powerstation 4000mAh Battery Plus Mini ...
# 248054 2017-05-23 16:21:58                      IMac RAM installation service
# 157832 2017-05-31 13:31:24        SSD installation service MacBook Pro Retina
#
#                                                      desc    price  \
# 97103   9.7-inch Apple iPad Pro Wi-Fi + Cellular 32GB ...  8328.12
# 245063  MLC memory card 64GB for Macbooks Retina 13 in...   452.81
# 251754  And adapter card memory 128 GB microSDXC Class...   502.80
# 251751  And adapter card memory 128 GB microSDXC Class...   502.80
# 245082  MLC memory card 64GB for Macbooks Retina 13 in...   452.81
# 190861       Carrying case for graphics tablet Intuos 4 S   199.90
# 190860       Carrying case for graphics tablet Intuos 4 S   199.90
# 186775       Carrying case for graphics tablet Intuos 4 S   199.90
# 144394  Apple multimedia player with 4K resolution and...  2190.00
# 26682   Apple multimedia player with 4K resolution and...  2190.00
# 144396  Apple multimedia player with 4K resolution and...  2190.00
# 239817        MLC memory card 64GB for Macbook 13 inches.   452.81
# 244728        MLC memory card 64GB for Macbook 13 inches.   452.81
# 244743        MLC memory card 64GB for Macbook 13 inches.   452.81
# 245080  MLC memory card 64GB for Macbooks Retina 13 in...   452.81
# 206730  MLC memory card 64GB for Macbooks Retina 13 in...   452.81
# 244745        MLC memory card 64GB for Macbook 13 inches.   452.81
# 24665      Children's Headphones for iPhone iPad and iPod   249.90
# 24653      Children's Headphones for iPhone iPad and iPod   249.90
# 19859   Open WD hard drive in perfect condition design...   129.00
# 265383  Repair service including parts and labor for i...   699.90
# 265470  Repair service including parts and labor for i...   699.90
# 251598                                SSD 120GB 25 inches   635.29
# 251766  And adapter card memory 128 GB microSDXC Class...   502.80
# 251763  And adapter card memory 128 GB microSDXC Class...   502.80
# 251755  And adapter card memory 128 GB microSDXC Class...   502.80
# 144390  Apple multimedia player with 4K resolution and...  2190.00
# 144402  Apple multimedia player with 4K resolution and...  2190.00
# 208800  external battery capacity 4000mAh output volta...    69.95
# 208696  external battery capacity 4000mAh output volta...    69.95
# 208786  external battery capacity 4000mAh output volta...    69.95
# 208787  external battery capacity 4000mAh output volta...    69.95
# 209047  external battery capacity 4000mAh output volta...    69.95
# 209046  external battery capacity 4000mAh output volta...    69.95
# 208799  external battery capacity 4000mAh output volta...    69.95
# 208898  external battery capacity 4000mAh output volta...    69.95
# 208900  external battery capacity 4000mAh output volta...    69.95
# 208802  external battery capacity 4000mAh output volta...    69.95
# 208804  external battery capacity 4000mAh output volta...    69.95
# 208788  external battery capacity 4000mAh output volta...    69.95
# 208918  external battery capacity 4000mAh output volta...    69.95
# 208916  external battery capacity 4000mAh output volta...    69.95
# 208901  external battery capacity 4000mAh output volta...    69.95
# 208956  external battery capacity 6000mAh output volta...    89.95
# 208968  external battery capacity 6000mAh output volta...    89.95
# 208944  external battery capacity 6000mAh output volta...    89.95
# 208955  external battery capacity 6000mAh output volta...    89.95
# 208971  external battery capacity 6000mAh output volta...    89.95
# 208970  external battery capacity 6000mAh output volta...    89.95
# 208994  external battery capacity 6000mAh output volta...    89.95
# 208819  external battery capacity 4000mAh output volta...    69.95
# 208777  external battery capacity 4000mAh output volta...    69.95
# 199355  Adapter HDD / SSD 2.5 SATA 3.5 compatible with...    26.99
# 208817  external battery capacity 4000mAh output volta...    69.95
# 208773  external battery capacity 4000mAh output volta...    69.95
# 208894  external battery capacity 4000mAh output volta...    69.95
# 248054                  Installation of RAM in your iMac.    19.99
# 157832  Installing SSD in your MacBook Pro Retina + Da...    49.99
#
#         promo_price  discount  discount_pc  sales_discount  sales_discount_pc  \
# 97103       8328.11      0.01         0.00         7499.12              90.05
# 245063       452.81      0.00         0.00          407.82              90.06
# 251754       502.80      0.00         0.00          452.81              90.06
# 251751       502.80      0.00         0.00          452.81              90.06
# 245082       452.81      0.00         0.00          409.53              90.44
# 190861       199.90      0.00         0.00          180.91              90.50
# 190860       199.90      0.00         0.00          180.91              90.50
# 186775       199.90      0.00         0.00          180.91              90.50
# 144394      2190.00      0.00         0.00         1981.95              90.50
# 26682       2190.00      0.00         0.00         1981.95              90.50
# 144396      2190.00      0.00         0.00         1981.95              90.50
# 239817       452.81      0.00         0.00          409.82              90.51
# 244728       452.81      0.00         0.00          409.82              90.51
# 244743       452.81      0.00         0.00          410.70              90.70
# 245080       452.81      0.00         0.00          410.68              90.70
# 206730       452.81      0.00         0.00          410.68              90.70
# 244745       452.81      0.00         0.00          410.68              90.70
# 24665        249.90      0.00         0.00          226.91              90.80
# 24653        249.90      0.00         0.00          226.91              90.80
# 19859         95.59     33.41        25.90          117.16              90.82
# 265383       699.90      0.00         0.00          636.91              91.00
# 265470       699.90      0.00         0.00          636.91              91.00
# 251598       635.29      0.00         0.00          578.36              91.04
# 251766       502.80      0.00         0.00          457.81              91.05
# 251763       502.80      0.00         0.00          457.81              91.05
# 251755       502.80      0.00         0.00          457.81              91.05
# 144390      2190.00      0.00         0.00         2009.01              91.74
# 144402      2190.00      0.00         0.00         2009.01              91.74
# 208800         7.99     61.96        88.58           65.96              94.30
# 208696         7.99     61.96        88.58           65.96              94.30
# 208786        26.99     42.96        61.42           65.96              94.30
# 208787        26.99     42.96        61.42           65.96              94.30
# 209047         7.99     61.96        88.58           65.96              94.30
# 209046         7.99     61.96        88.58           65.96              94.30
# 208799        26.99     42.96        61.42           65.96              94.30
# 208898        26.99     42.96        61.42           65.96              94.30
# 208900        26.99     42.96        61.42           65.96              94.30
# 208802        26.99     42.96        61.42           65.96              94.30
# 208804        26.99     42.96        61.42           65.96              94.30
# 208788         7.99     61.96        88.58           65.96              94.30
# 208918        26.99     42.96        61.42           65.96              94.30
# 208916        26.99     42.96        61.42           65.96              94.30
# 208901        26.99     42.96        61.42           65.96              94.30
# 208956        35.99     53.96        59.99           84.96              94.45
# 208968        35.99     53.96        59.99           84.96              94.45
# 208944        35.99     53.96        59.99           84.96              94.45
# 208955        35.99     53.96        59.99           84.96              94.45
# 208971        35.99     53.96        59.99           84.96              94.45
# 208970        35.99     53.96        59.99           84.96              94.45
# 208994        35.99     53.96        59.99           84.96              94.45
# 208819        26.99     42.96        61.42           67.29              96.20
# 208777        26.99     42.96        61.42           67.29              96.20
# 199355        19.99      7.00        25.94           25.99              96.29
# 208817        26.99     42.96        61.42           67.95              97.14
# 208773        26.99     42.96        61.42           68.35              97.71
# 208894        26.99     42.96        61.42           68.35              97.71
# 248054        19.99      0.00         0.00           19.98              99.95
# 157832        49.99      0.00         0.00           49.98              99.98
#
#                   brand  total_paid      state              category
# 97103             Apple     2167.00  Completed                  iPad
# 245063         Trascend       49.98  Completed                Memory
# 251754          SanDisk       54.98  Completed           Accessories
# 251751          SanDisk       54.98  Completed           Accessories
# 245082         Trascend       47.27  Completed                Memory
# 190861            Wacom       22.98  Completed           Accessories
# 190860            Wacom       23.98  Completed           Accessories
# 186775            Wacom      110.97  Completed           Accessories
# 144394            Apple      212.04  Completed              Hardware
# 26682             Apple      541.08  Completed              Hardware
# 144396            Apple      215.04  Completed              Hardware
# 239817         Trascend       72.98  Completed                Memory
# 244728         Trascend       47.98  Completed                Memory
# 244743         Trascend       49.10  Completed                Memory
# 245080         Trascend       46.12  Completed                Memory
# 206730         Trascend       54.21  Completed                Memory
# 244745         Trascend       47.12  Completed                Memory
# 24665               JBL       26.98  Completed           Accessories
# 24653               JBL       27.98  Completed           Accessories
# 19859   Western Digital       30.67  Completed           Accessories
# 265383           Repair       72.98  Completed           Accessories
# 265470           Repair       72.98  Completed           Accessories
# 251598          SanDisk       61.92  Completed           Accessories
# 251766          SanDisk       44.99  Completed           Accessories
# 251763          SanDisk      134.97  Completed           Accessories
# 251755          SanDisk       44.99  Completed           Accessories
# 144390            Apple      200.98  Completed              Hardware
# 144402            Apple      200.98  Completed              Hardware
# 208800           Mophie       36.95  Completed           Accessories
# 208696           Mophie       67.94  Completed           Accessories
# 208786           Mophie       19.97  Completed           Accessories
# 208787           Mophie       35.95  Completed           Accessories
# 209047           Mophie       19.97  Completed           Accessories
# 209046           Mophie       19.97  Completed           Accessories
# 208799           Mophie       36.95  Completed           Accessories
# 208898           Mophie       20.97  Completed           Accessories
# 208900           Mophie       20.97  Completed           Accessories
# 208802           Mophie       20.97  Completed           Accessories
# 208804           Mophie       24.47  Completed           Accessories
# 208788           Mophie       35.95  Completed           Accessories
# 208918           Mophie       20.97  Completed           Accessories
# 208916           Mophie       20.97  Completed           Accessories
# 208901           Mophie       20.97  Completed           Accessories
# 208956           Mophie       44.95  Completed           Accessories
# 208968           Mophie       24.97  Completed           Accessories
# 208944           Mophie       24.97  Completed           Accessories
# 208955           Mophie       44.95  Completed           Accessories
# 208971           Mophie       39.96  Completed           Accessories
# 208970           Mophie       39.96  Completed           Accessories
# 208994           Mophie       24.97  Completed           Accessories
# 208819           Mophie       28.96  Completed           Accessories
# 208777           Mophie       36.95  Completed           Accessories
# 199355        NewerTech      406.80  Completed           Accessories
# 208817           Mophie       20.97  Completed           Accessories
# 208773           Mophie       52.93  Completed           Accessories
# 208894           Mophie       46.94  Completed           Accessories
# 248054          Service     2041.01  Completed  Repairs & warranties
# 157832          Service     1642.46  Completed                Memory
