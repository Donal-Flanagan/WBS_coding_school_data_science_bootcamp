# %% [markdown]
# ## Import the data

# %%
import pandas as pd
import numpy as np
import re

path = '../data/eniac/'
orderlines = pd.read_csv(path + 'orderlines.csv')
orders = pd.read_csv(path + 'orders.csv')
brands = pd.read_csv(path + 'brands.csv')
products = pd.read_csv(path + 'products.csv')

df_list = [orderlines, orders, brands, products]
files = ['orderlines','orders','brands','products']

orders['created_date'] = pd.to_datetime(orders['created_date'])
orderlines['date'] = pd.to_datetime(orderlines['date'])

# %% [markdown]
# ## Clean orders

# %%
# Remove nan values
orders_before = orders.shape[0]
orders.dropna(inplace=True)
orders_after = orders.shape[0]

rows_removed_from_orders = orders_before - orders_after
print(f'{rows_removed_from_orders} rows were removed from orders after removing NaN values')
print(f'This represents {round(rows_removed_from_orders/orders_before*100, 2)}% of the data')


# Remove 22213 order ids in orders that aren't in orderlines
orders_before = orders.shape[0]
orders = orders[orders.order_id.isin(orderlines.id_order)]
orders_after = orders.shape[0]
rows_removed_from_orders = orders_before - orders_after

# Of the order ids in orders but not in orderlines, 12304 orders have state = Place Order and 
# 9810 have state = Shopping Basket for a total of 22114.
# There are a total of 40883 orders with state = Place Order and 117809 with state = Shopping Basket.
print('\n')
print(f'{rows_removed_from_orders} rows were removed from orders after removing order_ids which do not exist in orderlines')
print(f'This represents {round(rows_removed_from_orders/orders_before*100, 2)}% of the data')

orders.to_csv(path + 'orders_clean.csv', index=False)
# Out:
# 5 rows were removed from orders after removing NaN values
# This represents 0.0% of the data
#
#
# 22213 rows were removed from orders after removing order_ids which do not exist in orderlines
# This represents 9.79% of the data

# %% [markdown]
# ## Clean products

# %%
# Drop the type and in_stock columns 
products.drop('type', axis=1, inplace=True, errors='ignore')
products.drop('in_stock', axis=1, inplace=True, errors='ignore')
#  Drop duplicate rows based on sku value
products.drop_duplicates(subset='sku', inplace=True)
# Check for products without descriptions
names_of_products_without_descriptions = products[products.desc.isna()].name.tolist()
# Add missing descriptions
missing_descriptions = [
    '2TB Mac hard drive and Nas',
    'Apple keyboard for iPad 9.7',
    'NAS server with 10GB RAM',
    'Ethernet adapter for Macbook 12',
    'Luxury power bank combined with powder, 2 mirrors - normal and 3x magnification, Illuminated under mirror with LED, Low weight and compact dimensions',
    'Battery capacity: 20,000 mAh; ultra-stable: outer shell made of durable synthetic rubber (military standard, withstands drops from up to 2 metres) ; protection: dust and splash proof: military standard iP54; battery level indicator and super fast charging; USB port can be connected to charger and other devices',
    'Smart thermostat designed to provide automatic time and temperature control of heating systems in homes and apartments. '
]
for i in range(len(names_of_products_without_descriptions)):
    products.loc[products.name == names_of_products_without_descriptions[i], 'desc'] = missing_descriptions[i]

# Clean the price and promo_price columns
def start_pipeline(df):
    '''Make a copy of the pipeline to prevent corrupting the original data'''
    return df.copy()

def remove_duplicates(df, col):
    '''Remove duplicate rows'''
    return df[~df[col].isna()]

def clean_prices(df):
        df.price = df.price.apply(lambda x : x +'.00' if x.count('.') == 0 else x)
        df.price = df.price.apply(lambda x: x  + '0' if x[-2]=='.' else x)
        df.price = df.price.apply(lambda x: str(float(x.replace('.',''))/1000) if ( (x[-4]=='.') & (x.count('.')==2)) else x)
        df.price = df.price.apply(lambda x: str(float(x.replace('.',''))/10000) if ( (x[-4]=='.') & (x.count('.')==1)) else x)
        df.price = df.price.astype(float)
        df.price = df.price.round(decimals = 2)
        return df

def split_and_join_promo_prices(df):
    '''Remove the decimal points from the promo_price strings and append .00 to the string'''
    return df.assign(promo_price=df.promo_price
                     .str.split('.')
                     .str.join('')
                     .apply(lambda x: x+'.00')
                    )

def _insert_decimal_at_string_position(s, pos):
    '''Insert a decimal point at a given position in a string'''
    s = s.split('.')
    s = s[0] + s[1]
    s = s[:pos]+'.'+s[pos:]
    return s 


def _insert_decimal_in_promo_price(row):
    '''
    If the euro value of the price is equal to the euro value of the promo_price, 
    set the promo_price equal to price and return it.
    This is because some promo_prices are slightly larger than their equivalent prices, e.g. 12.95 - 12.99
    
    Otherwise, keep moving the decimal point towards the start of the string until the promo_price is lower than the price.
    Then transform the string to a float and round it to two decimal places.
    '''
    
    decimal_position = -2
    while float(row.promo_price) > row.price:
        if round(float(row.promo_price), 0) == round(row.price, 0):
            row.promo_price = row.price
            return row.promo_price
        else:
            row.promo_price = _insert_decimal_at_string_position(row.promo_price, decimal_position)
            decimal_position += -1
    
    return round(float(row.promo_price), 2)

def transform_promo_price_to_floats(df):
    df.promo_price = [_insert_decimal_in_promo_price(row) for index, row in df.iterrows()]
    return df

def calculate_products_discounts(df):
    return df.assign(
        discount=round(df.price - df.promo_price, 2),
        discount_pc = round((df.price - df.promo_price)/df.price * 100, 2)
    )

products = (products
        .pipe(start_pipeline)
        .pipe(remove_duplicates,col='price')
        .pipe(clean_prices)
        .pipe(split_and_join_promo_prices)
        .pipe(transform_promo_price_to_floats)
        .pipe(calculate_products_discounts)
)

products.to_csv(path + 'products_clean.csv', index=False)
products
# Out:
#            sku                                           name  \
# 0      RAI0007              Silver Rain Design mStand Support
# 1      APP0023              Apple Mac Keyboard Keypad Spanish
# 2      APP0025               Mighty Mouse Apple Mouse for Mac
# 3      APP0072  Apple Dock to USB Cable iPhone and iPod white
# 4      KIN0007    Mac Memory Kingston 2GB 667MHz DDR2 SO-DIMM
# ...        ...                                            ...
# 19321  BEL0376        Belkin Travel Support Apple Watch Black
# 19322  THU0060   Enroute Thule 14L Backpack MacBook 13 "Black
# 19323  THU0061    Enroute Thule 14L Backpack MacBook 13 "Blue
# 19324  THU0062     Enroute Thule 14L Backpack MacBook 13 "Red
# 19325  THU0063   Enroute Thule 14L Backpack MacBook 13 "Green
#
#                                                     desc  price  promo_price  \
# 0           Aluminum support compatible with all MacBook  59.99        49.99
# 1              USB ultrathin keyboard Apple Mac Spanish.  59.00        59.00
# 2                                 mouse Apple USB cable.  59.00        56.99
# 3                  IPhone dock and USB Cable Apple iPod.  25.00        23.00
# 4      2GB RAM Mac mini and iMac (2006/07) MacBook Pr...  34.99        31.99
# ...                                                  ...    ...          ...
# 19321  compact and portable stand vertically or horiz...  29.99        26.99
# 19322  Backpack with capacity of 14 liter compartment...  69.95        64.99
# 19323  Backpack with capacity of 14 liter compartment...  69.95        64.99
# 19324  Backpack with capacity of 14 liter compartment...  69.95        64.99
# 19325  Backpack with capacity of 14 liter compartment...  69.95        64.99
#
#        discount  discount_pc
# 0         10.00        16.67
# 1          0.00         0.00
# 2          2.01         3.41
# 3          2.00         8.00
# 4          3.00         8.57
# ...         ...          ...
# 19321      3.00        10.00
# 19322      4.96         7.09
# 19323      4.96         7.09
# 19324      4.96         7.09
# 19325      4.96         7.09
#
# [10534 rows x 7 columns]

# %% [markdown]
# ## Clean orderlines

# %%
# Remove 240 order ids in orderlines that aren't in orders
orderlines_before = orderlines.shape[0]
orderlines = orderlines[orderlines.id_order.isin(orders.order_id)].copy()
orderlines_after = orderlines.shape[0]
rows_removed_from_orderlines = orderlines_before - orderlines_after

print(f'{rows_removed_from_orderlines} rows were removed from orderlines after removing unmatched order_ids')
print(f'This represents {round(rows_removed_from_orderlines/orderlines_before*100, 2)}% of the data')


# Drop the product_id column because it contains no info
orderlines.drop('product_id', axis=1, inplace=True, errors='ignore')

# Transform the unit_price price column to floats
def transform_unit_price_to_floats(df):
    return (
        df.assign(unit_price = df.unit_price.str.split('.')
                  .apply(lambda x : x[0]+x[1]+'.'+x[2] if len(x)==3 else x[0]+'.'+ x[1])
                  .astype(float)
        )
    )

orderlines = (orderlines
              .pipe(start_pipeline)
              .pipe(transform_unit_price_to_floats)
             )

orderlines.to_csv(path + 'orderlines_clean.csv', index=False)

orderlines
# Out:
# 240 rows were removed from orderlines after removing unmatched order_ids
# This represents 0.08% of the data
#              id  id_order  product_quantity      sku  unit_price  \
# 0       1119109    299539                 1  OTT0133       18.99
# 1       1119110    299540                 1  LGE0043      399.00
# 2       1119111    299541                 1  PAR0071      474.05
# 3       1119112    299542                 1  WDT0315       68.39
# 4       1119113    299543                 1  JBL0104       23.74
# ...         ...       ...               ...      ...         ...
# 293978  1650199    527398                 1  JBL0122       42.99
# 293979  1650200    527399                 1  PAC0653      141.58
# 293980  1650201    527400                 2  APP0698        9.99
# 293981  1650202    527388                 1  BEZ0204       19.99
# 293982  1650203    527401                 1  APP0927       13.99
#
#                       date
# 0      2017-01-01 00:07:19
# 1      2017-01-01 00:19:45
# 2      2017-01-01 00:20:57
# 3      2017-01-01 00:51:40
# 4      2017-01-01 01:06:38
# ...                    ...
# 293978 2018-03-14 13:57:25
# 293979 2018-03-14 13:57:34
# 293980 2018-03-14 13:57:41
# 293981 2018-03-14 13:58:01
# 293982 2018-03-14 13:58:36
#
# [293743 rows x 6 columns]

# %% [markdown]
# ## Merge with products to compare discounts

# %%
sales_info = (
orderlines
    .merge(products, how='inner', on='sku')
)

def calculate_sales_discounts(df):
    return (df
            .assign(
                sales_discount=round(df.price - df.unit_price, 2),
                sales_discount_pc = round((df.price - df.unit_price)/df.price * 100, 2)
            )
           )

def merge_brands(df):
    return (df
            .assign(short = lambda row: row['sku'].str[:3])
            .merge(brands, on='short')
           )

def rename_columns(df):
    return (df
            .rename(columns={'long': 'brand', 'unit_price': 'sale_price', 'id_order': 'order_id'})
           )

def merge_orders(df):
    return (df
            .merge(orders, on='order_id')
    )

def drop_deprecated_columns(df):
    return (df
            .drop(['short', 'created_date'], axis=1)
           )

def assign_product_categories(df):
    regexp_dict = {
        'ipod':'^.{0,7}apple ipod',
        'iphone': 'iphone',
        'macbook': 'macbook',
        'case':'(case|funda|housing|casing|folder|bag|backpack)',
        'cable':'cable|connector|Lightning to USB|Wall socket|power strip|adapter',
        'battery':'battery',
        'headset':'(headset|headphones)',
        'mouse':'(mouse|trackpad)',
        'stand':'(stand|support)',
        'protect':'(protect|cover|sleeve|Screensaver|shell)',
        'watch':'(^.{0,6}apple watch|smartwatch|smart watch)',
        'camera':'camera',
        'router':'router|repeater',
        'keyboard':'keyboard|keypad',
        'speaker':'speaker',
        'dock':'hub|dock',
        'microphone':'microphone',
        'server':'server',
        'RAM':'RAM|DDR3|DDR4',
        'charger':'charger',
        'display':'display|monitor',
        'NAS': 'Synology|nas',
        'adobe': 'adobe',
        'memory':'hard disk|hard drive|flash drive|USB 2.0 key|USB 2.0 pen|SSD|pendrive|raid|SDHC|sata|memory card|Portable Hard Thunderbolt',
        'warranties': 'warranty',
        'repair services':'repair|parts and labor',
        'refurbished':'(refurbished|reconditioned|like new)',
        'strap':'strap|armband|belt|bracelet',
        'stylus':'stylus|penBamboo Wacom Intuos|pencil|pen|rubber pointers',
        'tablet':'tablet|ipad',
        'screwdriver':'screwdriver',
        'Apple TV':'Apple TV',
        'drone': 'Parrot FPV Glasses|Command Pack 2 Skycontroller',
        'Microsoft Office': 'Office 365|Office Home and Student', 
        'warranties': 'warranty|applecare',
        'motion sensor lights': 'Philips Hue',
        'temperature sensors': 'temperature sensor',
    }

    df = df.assign(category = 'unknown')

    for label, val in regexp_dict.items(): 
        regexp = re.compile(val, flags=re.IGNORECASE)
        df = (
            df
            .assign(
                category = lambda x: np.where(
                    ((x['desc'].str.contains(regexp, regex=True))|(x['name'].str.contains(regexp, regex=True))) &
                    (x['category'] == 'unknown'), label, x['category'])
            )
        )
    return df


sales_info = (sales_info
              .pipe(start_pipeline)
              .pipe(calculate_sales_discounts)
              .pipe(merge_brands)
              .pipe(rename_columns)
              .pipe(merge_orders)
              .pipe(drop_deprecated_columns)
              .pipe(assign_product_categories)
             )

#sales_info.to_csv(path + 'sales_info_clean.csv', index=False)
    
sales_info['category'].value_counts()
# Out:
# /tmp/ipykernel_1126942/3875096361.py:84: UserWarning: This pattern has match groups. To actually get the groups, use str.extract.
#   ((x['desc'].str.contains(regexp, regex=True))|(x['name'].str.contains(regexp, regex=True))) &

# %%
pd.options.display.max_rows = 500

check_df = sales_info[sales_info['category']=='unknown'][['name', 'desc']]

check_df.groupby(check_df.columns.tolist(),as_index=False).size().sort_values('size', ascending=False)
# Out:
#                                                   name  \
# 138                    Wacom parts 5 points for CTH670
# 126  TP-Link TL-SG1005D Desktop Switch 5 Gigabit Et...
# 71   Ninebot by Segway electric scooter Kick Scoote...
# 113                        Sphero BB-8 Star Wars Robot
# 122  TP-Link TL-PA4010P Kit Powerline AV500 Passthr...
# 139                Whoosh DUO + ​​Cleanser 100ml + 8ml
# 131              Transcend External DVD Recorder White
# 85               Polaroid ZINK 50 Pack 50 sheets Print
# 63                Nest Learning Thermostat Intelligent
# 66                  NewerTech Complete set of 14 tools
# 46                Fibaro Single Switch embedded module
# 83       PFC Sinewave CyberPower 900VA 540W UPS System
# 82      PFC Sinewave CyberPower 1500VA 900W UPS System
# 56   Koogeek Homekit Smart Plug socket with Siri vo...
# 143  iFixit Heavy Duty Suction Cups Pack 2 suction ...
# 7                 Apple MagSafe to MagSafe converter 2
# 81      PFC Sinewave CyberPower 1300VA 780W UPS System
# 128  TP-Link TL-SG1016D Switch gigabit ethernet por...
# 146      iFixit adhesive strips Kit for iMac 21.5 "EMC
# 137                Wacom Replacement tips for Intuos 4
# 129  TP-Link TL-SG1024D Desktop Switch 24 Gigabit E...
# 140                       Whoosh GO Cleaner Spray 30ml
# 148  iHealth 50 lancets Set Compatible for glucímetros
# 120  TP-LINK TL-PA9020P Passthrough Powerline Kit 2...
# 127  TP-Link TL-SG1008D Desktop Switch 8 Gigabit Et...
# 151          iHealth box 50 Reagent Strips glucímetros
# 90   Robot miniPRO Ninebot by Segway personal trans...
# 117                       Sphero R2-D2 Star Wars Robot
# 144  iFixit Kit adhesive strips for iMac 27 "EMC an...
# 6                   Apple Airport Extreme Base Station
# 123  TP-Link TL-PA7020P Passthrough Powerline Kit 2...
# 109  Sonnet eGFX Breakaway Box 550W PCIe Thunderbol...
# 33                    D-Link GO-SW-5G Gigabit Switch 5
# 35      D-Link GO-SW-8G 8-Port Gigabit Ethernet Switch
# 136            Wacom Intuos Professional Accessory Kit
# 125  TP-Link TL-PA8030P Kit 3 Port Gigabit Powerlin...
# 65             Netatmo Pluviometer for weather station
# 60                            Mac Parallels Desktop 13
# 64      Netatmo Healthy Home Coach environmental Meter
# 124  TP-Link TL-PA8010P Kit 1 Port Gigabit Powerlin...
# 32         D-Link GO-SW-5E 5 port Fast Ethernet Switch
# 50               Gadget Dodow relaxation Shining White
# 79                      OWC ThunderBay 4 Thunderbolt 2
# 61   Mujjo Single-Layered gloves color touch screen...
# 22            D-Link DGS-1024D Gigabit Switch 24 Ports
# 5                                Apple Airport Express
# 142                           iFixit CuI ± a foam iMac
# 53     Kensington Expert Presenter Green Laser Pointer
# 114                Sphero BB-8 Trainer Star Wars Robot
# 8               Box Thunder2 Akitio PCIe Thunderbolt 2
# 121  TP-LINK TL-WPA8630 3-port Gigabit Powerline Ki...
# 91   Satechi Aluminum Card Reader USB-C to USB 3.0 ...
# 58   LMP DataStore External Enclosure 35 "USB 3.0 A...
# 57        LMP DataPort External Enclosure 2.5 "USB 3.0
# 95                  Segway personal transport MiniLite
# 68                       NewerTech windy 225 "for iMac
# 67                    NewerTech HDMI Video Accelerator
# 45                 Fibaro HomeKit Sensor Door / Window
# 115                       Sphero BB-9E Star Wars Robot
# 27   D-Link DHP-P601AV PowerLine Gigabit AV2 1000 H...
# 75   OWC HDD Installation Kit for iMac 27 "2012 and...
# 135          Wacom Color Calibrator Manager Mac and PC
# 134                       WD My Cloud Home 6TB USB 3.0
# 103  Sonnet Echo Express Thunderbolt SEII 2 PCIe ex...
# 80      Office Home and Business 2016 Software for Mac
# 54       Kensington Expert Presenter Red Laser Pointer
# 141                 Wikango 600 Spanish warning radars
# 59                            Mac Parallels Desktop 12
# 130             Tado Smart Thermostat Starter Kit (v3)
# 23    D-Link DGS-1100-16 Gigabit Smart Switch 16 ports
# 55   Kensington Presenter Expert green laser pointe...
# 44         Fan iFixit Mac mini (Mid 2011 to Late 2014)
# 132          Transcend StoreJet outer box 25 "Aluminum
# 25   D-Link DHP-601AV PowerLine Gigabit AV2 1000 HD...
# 70   Ninebot by Segway Personal Transportation Robo...
# 34             D-Link GO-SW-8E Switch 8 Ethernet ports
# 24    D-Link DGS-1100-24 Gigabit Smart Switch 24 ports
# 145                          iFixit Mac mini Tool 2010
# 62   Mujjo Single-Layered gloves color touch screen...
# 43                            Elgato Video Capture Mac
# 48          Floaty GoPro Hero & Hero 5 Session Session
# 2     Akitio Neutrino Thunder outer box D3 Thunderbolt
# 111                               Sonos Playbase Black
# 76           OWC Mercury Helios PCIe Thunderbolt Box 2
# 14                D-Link DES-1005P PoE Ethernet Switch
# 29                 D-Link DWA-140 WiFi-N USB mini plug
# 36          D-Link mydlink DCH-Z120 Home Motion Sensor
# 38           D-Link mydlink Home DCH-S220 Sirena Wi-Fi
# 19            D-Link DGS 1016D Gigabit Switch 16 Ports
# 21             D-Link DGS-1008D Gigabit Switch 8 ports
# 12      D-Link DCH-G020 Bridge / Access Point Wireless
# 37   D-Link mydlink Home DCH-S160 Sensor exhaust ló...
# 119     Sphero Ultimate Car Lightning McQueen Directed
# 41                              Elgato Game Capture HD
# 11              D-Link DAP-1620 Wi-Fi AC1200 Amplifier
# 39   D-Link mydlink Home DCH-Z110 sensor for doors ...
# 13              D-Link DES-1005D Switch 5 10 / 100Mbps
# 108  Sonnet eGFX Breakaway Box 350W PCIe Thunderbol...
# 42                       Elgato Game Capture HD 60 Pro
# 9                            Connect Sonos Zone Player
# 52                Kensington ClickSafe lock Mac and PC
# 4    Allocacoc PowerCube rewirable Regleta White / ...
# 147  iFixit fine Spatula 15 "Mac mini and iPod Classic
# 77           OWC Mercury Helios PCIe Thunderbolt Box 3
# 26   D-Link DHP-P509AV PowerLine AV 500 Passthrough...
# 101  Sonnet Echo Express SE Thunderbolt PCIe expans...
# 74   OWC Bluetooth module shielding shielding kit B...
# 1    Akitio NODE Pro PCIe Card Thunderbolt External...
# 16   D-Link DES-1016D Switch 16 10 / 100Mbps unmanaged
# 47            Fibaro Water Sensor Flood Sensor HomeKit
# 30            D-Link GO-SW-16G Gigabit Ethernet Switch
# 51                          Ik Multimedia iRig Pro DUO
# 40          D-Link mydlink Home DCH-Z510 Audible alarm
# 0              Adonith spare ball Adonit Jot Pro / Fip
# 97   Sonnet Echo Express III-D Chassis expansion Th...
# 69   Ninebot by Segway One E + Electric Unicycle White
# 86               Polaroid ZINK Printing Pack 30 Sheets
# 20    D-Link DGS-1005D Gigabit Switch 5-port Unmanaged
# 107  Sonnet Upgrade Card expansion card Echo Expres...
# 92   Satechi Reader SD / Micro SD with USB Type-C G...
# 3    Akitio Thunder2 QUAD Box Mini External thunder...
# 87   Promise Pegasus R6 24TB 3 Symply Thunderbolt E...
# 150      iHealth Ismart doors and windows Alarm Sensor
# 89            Replacement FiftyThree 2 tips + 1 eraser
# 112                               Sonos Playbase White
# 10                D-Link DAP-1330 Amplifier N300 Wi-Fi
# 102  Sonnet Echo Express Thunderbolt SE1 3 Chassis ...
# 73   Nokia Intelligent Activity Steel 36mm White Clock
# 104  Sonnet Echo Express Thunderbolt SEL 3 Chassis ...
# 105                Sonnet Presto 10GbE PCIe Card RJ-45
# 15    D-Link DES-1008D Switch 8 10 / 100Mbps unmanaged
# 72   Nokia Intelligent Activity Steel 36mm Black Clock
# 17                D-Link DES-1018P POE Ethernet Switch
# 18             D-Link DES-1024D Switch 24 10 / 100Mbps
# 118            Sphero Spider-Man MUI ± interactive eco
# 100  Sonnet Echo Express PCIe Thunderbolt Expansion...
# 98   Sonnet Echo Express III-R 2U Chassis Rack Thun...
# 78     OWC Removal Tool motherboard Mac Mini 2010-2012
# 49         G-Technology G-DRIVE ev RED reader MINI-MAG
# 94             Second hand - 16Gb Apple iPod Nano Blue
# 88                        QuarkXPress 2016 Mac Edition
# 149              iHealth Ismart Alarm Command for home
# 96    Sonnet Echo Express III-D Box PCIe Thunderbolt 3
# 133     Upper body MiniDrone Parrot Jumping Sumo White
# 106  Sonnet Upgrade Card Card 3 Echo Express Thunde...
# 99   Sonnet Echo Express III-R Box Rack PCIe Thunde...
# 28                D-Link DKVM-4U Switch 4-Port USB KVM
# 110  Sonnet eGFX Breakaway Puck Radeon RX560 Thunde...
# 93   Satechi Reader SD / Micro SD with USB Type-C P...
# 116                            Sphero Ollie Robot Blue
# 31            D-Link GO-SW-24G Gigabit Ethernet Switch
# 84       Parrot Central Cross Rolling Spider MiniDrone
#
#                                                   desc  size
# 138  Replacement tips for Bamboo Wacom Intuos and C...   221
# 126  Switch desktop and Gigabit 5-port system autom...   179
# 71   two-wheeled electric scooter with autonomous u...   178
# 113  Smartoy sphere droid BB-8 Star Wars remote Blu...   164
# 122  amplifiers internet kit with transfer speeds u...   155
# 139                    Sprays cleaners Pack 2 screens.   118
# 131      superfine external recorder and portable DVD.   115
# 85   Pack 50 sheets of print material resistant adh...    99
# 63   energy savings and comfort in your home thanks...    90
# 66            portable kit of 14 tools for Mac and PC.    81
# 46   embedded module to control your consumption ou...    76
# 83   UPS system with 540W and 900VA maximum power c...    74
# 82   UPS system with 900W maximum power and 1500VA ...    72
# 56   Koogeek plug with Apple HomeKit technology and...    71
# 143  Pack of 2 suction to remove the glass LCD scre...    67
# 7                      MagSafe to MagSafe converter 2.    66
# 81   UPS system with 780W maximum power and 1300VA ...    65
# 128  Desktop Switch with 16 ports Gigabit RJ-45 10/...    64
# 146           Kit adhesive strips for iMac 215 inches.    58
# 137  Replacement tips for digital llápices Wacom In...    53
# 129  Desktop Switch with 24 ports Gigabit RJ-45 10/...    53
# 140                              Spray screen cleaner.    51
# 148     Needles to draw blood for iHealth glucímetros.    49
# 120  speed internet amplifier kit with ultra-fast i...    48
# 127  Desktop Switch with 8 ports Gigabit system and...    46
# 151  Blood glucose test strips in the iHealth glucí...    46
# 90   Robot two-wheeled personal transport up to 25K...    45
# 117  Smartoy sphere droid R2-D2 Star Wars remote Bl...    44
# 144           Kit adhesive strips for an iMac 27 inch.    43
# 6         Base station with Wi-Fi 802.11ac technology.    41
# 123  amplifier with high speed internet up to 1000M...    40
# 109  Expansion box for graphics cards and PCIe card...    40
# 33        Dlink Switch 5 port Gigabyte for Mac and PC.    40
# 35                    Dlink Switch 8 Mac and PC ports.    40
# 136                              Intuos accessory kit.    38
# 125  amplifier with fast speed internet plug kit in...    35
# 65      Pluviometer add-on module for weather station.    32
# 60   The easiest and fastest way to run Windows on ...    31
# 64   Intelligent noise humidity control temperature...    29
# 124  amplifier with fast speed internet plug kit in...    29
# 32   D-Link GO-SW-5E 5 port 10/100 Mbps Fast Ethernet.    29
# 50   Gadget relaxation with breathing exercises sle...    28
# 79   OWC external storage box 4 bay professional Th...    28
# 61                    M size gloves for touch screens.    26
# 22                        Switch 24 10/100 / 1000Mbps.    25
# 5    Airport Express base station 802.11a / b / g / n.    25
# 142                Molded foam to hold the screen iMac    24
# 53                     laser pointer 10X bright green.    22
# 114  Smartoy sphere droid BB-8 Star Wars remote Blu...    22
# 8    Thunderbolt chassis 2 PCI Express expansion cards    21
# 121  Network Extender by Lonea Electric PLC av1200 ...    21
# 91   Card reader with SD slots for SD and USB and M...    21
# 58        external enclosure USB 3.0 discs 3.5 inches.    20
# 57          external enclosure USB 2.5 inch disks 3.0.    19
# 95   Robot two-wheeled personal transport up to 18K...    18
# 68           Suction cup 225 inches for aluminum iMac.    18
# 67    Video Accelerator HDMI connection for Mac and PC    18
# 45   multi-function sensor for doors and windows co...    18
# 115  Smartoy BB-9E sphere droid from Star Wars to B...    16
# 27      Internet amplifier kit with integrated socket.    16
# 75   Installation Kit disk iMac 27-inch HDD in 2012...    16
# 135  Accessory gauge and color accuracy on screen f...    16
# 134                 centralized storage for Mac and PC    16
# 103        Thunderbolt chassis 2 PCIe expansion cards.    15
# 80   Microsoft software licenses for home and busin...    15
# 54          Red laser pointer for presentations color.    15
# 141  Notices of fixed radar radar radar traffic lig...    15
# 59   20 Windows tools and utilities for Mac (compat...    15
# 130  Smart + bridge thermostat with LED screen app ...    15
# 23   D-Link Smart Gigabit Switch 16 ports for small...    15
# 55     laser pointer green + USB 4GB 10 times brighter    15
# 44                Fan Mac mini (Mid 2011 to Late 2014)    14
# 132         external enclosure USB 2.5 inch disks 3.0.    14
# 25         Amplifier internet with speeds of 1000Mbps.    14
# 70   Robot two-wheeled personal transport up to 25K...    14
# 34       D-Link Switch 8 Ethernet ports maximum speed.    13
# 24   D-Link Smart Gigabit Switch 24 ports ideal for...    13
# 145       Tool to remove the motherboard Mac mini 2010    12
# 62                    S size gloves for touch screens.    10
# 43             Mac USB analog video recorder hardware.    10
# 48   Specific float Session GoPro Hero to enjoy it ...    10
# 2    External connection box with Thunderbolt and U...    10
# 111  Quality sound basis for television and streami...     9
# 76   Expansion Chassis with Thunderbolt 2 PCIe conn...     9
# 14             compact switch with 5 Ethernet (PoE 1).     9
# 29   DLink Wireless 802.11N USB mini plug with spee...     9
# 36   Wireless motion sensor security system my D-Li...     9
# 38            Smart Wifi siren with 6 types of sounds.     9
# 19                        Switch 16 10/100 / 1000Mbps.     8
# 21   D-Link Switch with 8 Gigabit ports for high pe...     8
# 12                   Jumper and internet access point.     8
# 37                Wifi smart sensor prevents flooding.     8
# 119  Pilota skids and hallucinates the wheel of the...     8
# 41             Mac USB analog video recorder hardware.     8
# 11    Wireless network amplifier Dual band technology.     8
# 39                Safety sensor for doors and windows.     7
# 13                    Dlink Switch 5 Mac and PC ports.     7
# 108  Expansion box for graphics cards and PCIe card...     7
# 42                   FHD video recorder card hardware.     7
# 9    Music player and receiver to manage music from...     7
# 52                       Mac and PC padlock with keys.     7
# 4    The smartest solution for travel anywhere in t...     7
# 147  small and thin spatula 15 for Mac mini and iPo...     7
# 77   Thunderbolt expansion box 3 for half-length PC...     7
# 26      Internet amplifier kit with integrated socket.     7
# 101        Thunderbolt chassis 2 PCIe expansion cards.     6
# 74   Shielding Kit Bluetooth Module for Mac mini 2012.     6
# 1    Thunderbolt expansion unit 3 for PCI Express C...     6
# 16      D-Link DES-1016D with 16 ports for group work.     6
# 47   multi-function sensor for water leaks compatib...     6
# 30      compact switch with 16 Gigabit Ethernet ports.     6
# 51                      Ultracompact studio recording.     6
# 40   Alarm sounds 6 different sensors for my D-Link...     5
# 0        Replacement Ball Black Adonit Jot Pro / Flip.     5
# 97   Thunderbolt external box card PCIe ExpressCard...     5
# 69   Electric personal transportation robot with a ...     5
# 86   Pack of 30 print sheets resistant material and...     5
# 20      D-Link Gigabit Switch 5-port high performance.     5
# 107  Thunderbolt expansion card to SEL 3 for Echo E...     5
# 92   Card reader Satechi slots for SD and SD Micro ...     5
# 3    external enclosure 25 inch discs Thunderbolt 2...     5
# 87   Massive external storage system of 24TB (6x4TB...     4
# 150  Sensor removable doors and windows for securit...     4
# 89         2 tips + 1 draft for the pointer FiftyThree     4
# 112  Quality sound basis for television and streami...     4
# 10             Wifi network amplifier power indicator.     4
# 102     Thunderbolt Expansion Chassis 3 for PCIe Cards     4
# 73   Intelligent Steel watch with automatic trackin...     4
# 104  Thunderbolt expansion chassis 3 for low profil...     4
# 105  PCIe card with 2 RJ-45 10GBase-T ports for Mac...     4
# 15                    Dlink Switch 8 Mac and PC ports.     4
# 72   Intelligent Steel watch with automatic trackin...     4
# 17   Ethernet Switch with 18 PoE ports and 2 Gigabi...     3
# 18       Switch Dlink 24 ports Rack Mac and PC format.     3
# 118  MUI ± interactive Spider-Man eco eyes with mov...     3
# 100               Thunderbolt expansion box 3 for PCIe     3
# 98     PCIe expansion chassis for Mac via Thunderbolt.     3
# 78                     Dismounting tool Apple Mac Mini     3
# 49   High performance reader optimized to work with...     3
# 94   IPod nano music player the 8th generation used...     3
# 88   Editing software content creation and design l...     2
# 149  Command to activate and deactivate alarm range...     2
# 96   Thunderbolt expansion box 3 for PCIe cards wit...     2
# 133                 MiniDrone upper body Sumo Jumping.     2
# 106  Thunderbolt expansion card 3 for Echo Express ...     2
# 99   Expansion box through the PCIe bus format Thun...     1
# 28                            DLink 4 port KVM Switch.     1
# 110  Box Portable expansion graphics cards with Rad...     1
# 93   Card reader Satechi slots for SD and SD Micro ...     1
# 116  Smartoy of Sphero Ollie Robot remote control v...     1
# 31      Compact switch with 24 Gigabit Ethernet ports.     1
# 84             Rolling MiniDrone Central Cross Spider.     1
